# %%
# %load_ext line_profiler
import line_profiler

# %%
import os 
import importlib
import sys
import tensorflow as tf
import itertools
import numpy as np
import numba as nb
from math import sqrt, log, exp
from numpy import unravel_index
from random import choice, random, sample
np.random.seed(1337)  # for reproducibility
from keras.models import Sequential, Model, load_model
import keras.backend as K
import matplotlib.pyplot as plt
K.set_image_dim_ordering('th')
import time
# Out:
# Using TensorFlow backend.

# %%
class Ataxx:
    def __init__(self, board=None):
        if board is None:                  # if there is no initialization given
            self.data = np.zeros((7, 7), dtype=np.int8)   # then generate a board with starting init, and black(-1) takes first turn
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
            
    def reset(self, board=None):
        if board is None:
            self.data = np.zeros((7, 7), dtype=np.int8)
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
        
    def get_feature_map(self, turn, move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge
        
        # edge
        for j in range(9):
            for k in range(9):
                if j == 0 or j == 8 or k == 0 or k == 8:
                    out[0, j, k] = 1
         
        # my pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == turn:
                        out[1, j, k] = 1
        
        # op pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == -turn:
                        out[2, j, k] = 1
         
        # last move
        if not move is None:               
            out[3, move[0][0]+1, move[0][1]+1] = 1
            out[4, move[1][0]+1, move[1][1]+1] = 1
            
        # whose first
        if turn == -1:
            for j in range(9):
                for k in range(9):
                    out[5, j, k] = 1
        return np.array(out)
    
    def plot(self, is_next_move=False, turn=None):                        # plot the board
        image = self.data.copy()
        if is_next_move:
            if turn not in [-1, 1]:
                raise ValueError("Turn must be -1 or 1, or Must input a turn for next moves")
            else:
                next_moves = self.get_moves(turn)
                if len(next_moves) == 0:
                    raise ValueError("Game is over already")
                next_pos = list(zip(*next_moves))[1]
                for pos in next_pos:
                    image[pos] = turn / 2
        plt.imshow(image, cmap='gray')
        plt.xticks(range(7), range(7))
        plt.yticks(range(7), range(7))
        plt.show()
        
    def get_greedy_move(self, turn, moves=None):
        best_score = -50
        # get all possible moves if not provided
        if moves is None:
            moves, corr_dict = self.get_moves(turn)
            for item in corr_dict:
                moves.append(item)
        
        if len(moves) == 0:
            raise ValueError('No Possible Moves')
        
        best_moves = []
        # calculate greedy move
        for (x0, y0), (x1, y1) in moves:
            tmp_score = 0
            if abs(x0-x1) <= 1 and abs(y0-y1) <= 1:
                tmp_score += 1
            for dr in range(-1, 2):
                for dc in range(-1, 2):
                    try:
                        if x1+dr >= 0 and y1+dc >= 0:
                            tmp_score += self.data[x1+dr, y1+dc] == -turn
                    except:
                        pass
            if tmp_score > best_score:
                best_moves = [((x0, y0), (x1, y1))]
                best_score = tmp_score
            elif tmp_score == best_score:
                best_moves.append(((x0, y0), (x1, y1)))
        return choice(best_moves)
                
    def is_valid(self, turn, pos, get_pos=False):
        r = pos[0]
        c = pos[1]
        if self.data[r, c] != 0:
            if not get_pos:
                return False
            else:
                return
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if not get_pos:
                            return True
                        else:
                            yield new_r, new_c, dr, dc
            if not get_pos:
                return False
        
    def get_moves(self, turn):
        action_mask = np.zeros(792, dtype=np.int8)
        next_moves = []
        corr_dict = {}
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(turn, (r, c), True): # duplicate move
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if abs(dr) <= 1 and abs(dc) <=1:
                            if has_duplicate_move: 
                                cur_move = ((new_r, new_c), (r, c))
                                corr_dict[cur_move] = dup_move
                            elif self.data[new_r, new_c] == turn:
                                dup_move = ((new_r, new_c), (r, c))
                                next_moves.append(dup_move) 
                                has_duplicate_move = True
                        elif self.data[new_r, new_c] == turn:
                            cur_move = ((new_r, new_c), (r, c))
                            next_moves.append(cur_move) 
                        else:
                            continue

        return next_moves, corr_dict
        
    def move_to(self, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]
        
        if not self.is_valid(turn, pos1):
            raise ValueError("This move: " + str((pos0, pos1)) + " of turn: " + str(turn) + " is invalid") 
        elif self.data[x0, y0] != turn:
            raise ValueError("The starting position is not your piece")
        else:
            self.data[x1, y1] = turn
            if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
                self.data[x0, y0] = 0

            for dr in range(-1, 2):                  # infection mode!!!!
                for dc in range(-1, 2):
                    if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                        if self.data[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                            self.data[x1+dr, y1+dc] = turn
    
    def evaluate(self, turn, this_turn, max_score=1, min_score=0.001):
        turn_no=0
        op_no=0
        for r in range(7):
            for c in range(7):
                if self.data[r, c] == turn:
                    turn_no += 1
                elif self.data[r, c] == -turn:
                    op_no += 1
        if len(self.get_moves(this_turn)[0]) == 0:# if one of them can no longer move, count and end
            if turn_no > op_no:
                return max_score
            else:
                return -max_score
        else:
            value = turn_no - op_no
        return value * min_score
    
    @staticmethod    
    def get_manual_q(turn, board):
        '''consider linear growth of win prob with regard to n_diff
        when diff >= 10, the slope grow a bit
        when diff >= 35, consider win prob close to 1 or -1
        ''' 
        turn_no = 0
        op_no = 0
        max1=0.9
        max2=0.95
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        diff = turn_no - op_no
        if abs(diff) > 30:
            return diff / abs(diff)
        else:
            return diff / 30
        
        # ignore the rest for now
        sign = diff
        diff = abs(diff)
        if diff < 35:
            diff = (diff / 35) ** 2 * max1
        else:
            diff = max2

        if sign < 0:
            return -diff
        else:
            return diff

# %%
class PolicyValueNetwork():
    def __init__(self):
        self._sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=24))
        K.set_session(self._sess)
        
        self._model = load_model('AtaxxZero.h5')
        print("successfully loaded two models")
           
    def predict(self, feature_map, action_mask):        
        return self._sess.run(self._model.outputs, feed_dict={self._model.inputs[0]: feature_map.reshape(-1, 6, 9, 9), \
                                self._model.inputs[1]: action_mask.reshape(-1, 792), K.learning_phase(): 0})

# %%
'''These methods are for normal Min max'''
class MinMaxNormal():
    def __init__(self):
        return
    
    @staticmethod
    def evaluate(board, turn):
        turn_no = 0
        op_no = 0
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        return (turn_no - op_no)

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return False
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                        return True
            return False 

    def next_move(self, board, turn):
        next_moves = []
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                if self.is_valid(board, turn, (r, c)): # duplicate move
                    for dr in range(-2, 3):
                        for dc in range(-2, 3):
                            new_r = r+dr
                            new_c = c+dc
                            if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                                if abs(dr) <= 1 and abs(dc) <=1:
                                    if board[new_r, new_c] == turn and not has_duplicate_move:
                                        dup_move = ((new_r, new_c), (r, c))
                                        has_duplicate_move = True
                                        yield dup_move
                                elif board[new_r, new_c] == turn:
                                    cur_move = ((new_r, new_c), (r, c))
                                    yield cur_move
                                else:
                                    continue

    def has_next_move(self, board, turn):
        try:
            next(self.next_move(board, turn))
            return True
        except StopIteration:
            return False

    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board

    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
        else:
            best_move = ((0, 0), (0, 0))

        if depth == 0 or not self.has_next_move(board, turn): # start to do pruning and selecting once the recursion reaches the end
            result = self.evaluate(board, target_turn)
            return result, None
        else:
            if is_max:
                alpha = -100
            else:
                beta = 100

            for move in self.next_move(board, turn):
                result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False)
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == alpha and is_root:
                        best_moves.append(move)
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == beta and is_root:
                        best_moves.append(move)
            if is_max:
                if is_root:
                    return alpha, choice(best_moves)
                else:
                    return alpha, best_move
            else:
                if is_root:
                    return beta, choice(best_moves)
                else:
                    return beta, best_move

# %%
'''These methods are for Min max with ataxxzero'''
class MinMaxZero():
    def __init__(self):
        self._evaluator = PolicyValueNetwork()
        self._policy_dict = self.get_policy_dict()
        
    @staticmethod
    def get_policy_dict():
        '''Get the relation between policy no. and policy'''
        index=0
        policy_dict = {}
        for r in range(7):
            for c in range(7):
                for dr in range(-2, 3):
                    for dc in range(-2, 3):
                        new_r = r + dr
                        new_c = c + dc
                        if (dr != 0 or dc != 0) and (new_r < 7 and new_r >= 0) and (new_c < 7 and new_c >= 0):
                            policy_dict[((r, c), (new_r, new_c))] = index
                            index += 1
        return policy_dict

    @staticmethod
    def get_feature_map(board, turn, pre_move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge

        # edge
        for j in range(9):
            for k in range(9):
                if j == 0 or j == 8 or k == 0 or k == 8:
                    out[0, j, k] = 1

        # my pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if board[j-1, k-1] == turn:
                        out[1, j, k] = 1

        # op pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if board[j-1, k-1] == -turn:
                        out[2, j, k] = 1

        # last move
        if not pre_move is None:               
            out[3, pre_move[0][0]+1, pre_move[0][1]+1] = 1
            out[4, pre_move[1][0]+1, pre_move[1][1]+1] = 1

        # whose first
        if turn == -1:
            for j in range(9):
                for k in range(9):
                    out[5, j, k] = 1
        return out
    
    def evaluate(self, feature_map, action_mask, turn, target_turn):
        result = self._evaluator.predict(feature_map, action_mask)
        p = result[0][0]
        if turn == target_turn:
            q = result[1][0]
        else:
            q = -result[1][0]
        return p, q

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                        yield new_r, new_c, dr, dc
    
    def get_moves(self, board, turn):
        next_moves = []
        dup_moves = []
        action_mask = np.zeros(792, np.int8)
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(board, turn, (r, c)): # duplicate move
                    cur_move = ((new_r, new_c), (r, c))
                    # update action mask
                    action_mask[self._policy_dict[cur_move]] = 1
                    if abs(dr) <= 1 and abs(dc) <=1:
                        if not has_duplicate_move:
                            has_duplicate_move = True
                            next_moves.append(cur_move)
                    else:
                        next_moves.append(cur_move)

        return next_moves, action_mask
    
    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board

    @staticmethod
    def display_move_prob(move_prob):
        for move, prob in move_prob:
            print(move, prob)
    
    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True, pre_move=None):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
        else:
            best_move = ((0, 0), (0, 0))

        next_moves, action_mask = self.get_moves(board, turn)
        feature_map = self.get_feature_map(board, turn, pre_move)

        p, q = self.evaluate(feature_map, action_mask, turn, target_turn)

        if depth == 0: # start to do pruning and selecting once the recursion reaches the end
            return q, None
        elif len(next_moves) == 0:
            if (board == target_turn).sum() - (board == -target_turn).sum() > 0:
                return 1, None
            else:
                return -1, None
        else:
            # generate move corresponding p list
            move_prob = []
            all_prob = 0.0
            for move in next_moves:
                prob = p[self._policy_dict[move]]
                move_prob.append((move, prob))
                all_prob += prob
            move_prob = sorted(move_prob, key=lambda x: x[1], reverse=True)

            if is_max:
                alpha = -100
            else:
                beta = 100

            sum_prob = 0.0
            counter = 0
            counter_thresh = len(move_prob) / 15.0
            prob_thresh = (all_prob / len(move_prob)) * 0.8
            # display_move_prob(move_prob)
            for move, prob in move_prob:
                sum_prob += prob
                counter += 1
                # do searching
                try:
                    result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False, move)
                except:
                    print(move)
                    raise
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == alpha and is_root:
                        best_moves.append(move)
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == beta and is_root:
                        best_moves.append(move)

                if sum_prob >= prob_thresh and counter >= counter_thresh:
                    break

            if is_max:
                if is_root:
                    return alpha, choice(best_moves)
                else:
                    return alpha, best_move
            else:
                if is_root:
                    return beta, choice(best_moves)
                else:
                    return beta, best_move

# %%
minmax_zero = MinMaxZero()
minmax_normal = MinMaxNormal()
N = 20
N_D = 3
Z_D = 3
zero_win = 0
time_zero = []
time_normal = []
for _ in range(N):
    steps = 0
    a = Ataxx()
    turn = -1
    zero_turn = choice([-1, 1])
    print("zero chose color", zero_turn)
    best_move = None
    while True:
        steps += 1
        #a.plot()
        if turn != zero_turn:
            s = time.time()
            _, best_move = minmax_normal.min_max(a.data, turn, turn, depth=N_D)
            span = time.time() - s
            print("minmax normal, with depth", N_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_normal.append(span)
        else:
            s = time.time()
            _, best_move = minmax_zero.min_max(a.data, turn, turn, depth=Z_D, pre_move=best_move)
            span = time.time() - s
            print("minmax zero, with depth", Z_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_zero.append(span)
        a.move_to(turn, best_move[0], best_move[1])
        turn = -turn
        result = a.evaluate(zero_turn, turn)
        if result == 1:
            print("\n\n\n\n minmax zero win!! \n\n\n\n")
            zero_win += 1
            break
        elif result == -1:
            print("\n\n\n\n minmax normal win!! \n\n\n\n")
            break
print("In the previous ", N, " rounds, zero win ratio is: ", float(zero_win) / float(N))
time_zero = np.array(time_zero)
time_normal = np.array(time_normal)
print("On average, for minmax normal with depth", N_D, \
      ", each move takes time: ", time_normal.mean(),\
      "max time elapsed:", time_normal.max())
print("On average, for minmax zero with depth", Z_D, \
      ", each move takes time: ", time_zero.mean(),\
      "max time elapsed:", time_zero.max())
# Out:
# successfully loaded two models
# zero chose color -1
# minmax zero, with depth 3 move takes time:  0.4004099369049072
# minmax normal, with depth 3 move takes time:  0.15742015838623047
# minmax zero, with depth 3 move takes time:  0.05118203163146973
# minmax normal, with depth 3 move takes time:  0.40896105766296387
# minmax zero, with depth 3 move takes time:  0.07352805137634277
# minmax normal, with depth 3 move takes time:  0.4534189701080322
# minmax zero, with depth 3 move takes time:  0.06838393211364746
# minmax normal, with depth 3 move takes time:  0.36591100692749023
# minmax zero, with depth 3 move takes time:  0.0544278621673584
# minmax normal, with depth 3 move takes time:  0.4564781188964844
# minmax zero, with depth 3 move takes time:  0.08892011642456055
# minmax normal, with depth 3 move takes time:  1.069586992263794
# minmax zero, with depth 3 move takes time:  0.09245705604553223
# minmax normal, with depth 3 move takes time:  0.9402928352355957
# minmax zero, with depth 3 move takes time:  0.1081399917602539
# minmax normal, with depth 3 move takes time:  0.5838110446929932
# minmax zero, with depth 3 move takes time:  0.08866286277770996
# minmax normal, with depth 3 move takes time:  1.7441918849945068
# minmax zero, with depth 3 move takes time:  0.10054898262023926
# minmax normal, with depth 3 move takes time:  1.7474169731140137
# minmax zero, with depth 3 move takes time:  0.09650611877441406
# minmax normal, with depth 3 move takes time:  1.0466110706329346
# minmax zero, with depth 3 move takes time:  0.11955595016479492
# minmax normal, with depth 3 move takes time:  1.6469910144805908
# minmax zero, with depth 3 move takes time:  0.13286900520324707
# minmax normal, with depth 3 move takes time:  2.1129298210144043
# minmax zero, with depth 3 move takes time:  0.1596510410308838
# minmax normal, with depth 3 move takes time:  1.9445538520812988
# minmax zero, with depth 3 move takes time:  0.12018895149230957
# minmax normal, with depth 3 move takes time:  3.546105146408081
# minmax zero, with depth 3 move takes time:  0.09158205986022949
# minmax normal, with depth 3 move takes time:  1.9698262214660645
# minmax zero, with depth 3 move takes time:  0.13942503929138184
# minmax normal, with depth 3 move takes time:  1.597592830657959
# minmax zero, with depth 3 move takes time:  0.08738994598388672
# minmax normal, with depth 3 move takes time:  1.0394048690795898
# minmax zero, with depth 3 move takes time:  0.06926298141479492
# minmax normal, with depth 3 move takes time:  0.6793780326843262
# minmax zero, with depth 3 move takes time:  0.09124588966369629
# minmax normal, with depth 3 move takes time:  0.6783878803253174
# minmax zero, with depth 3 move takes time:  0.07388806343078613
# minmax normal, with depth 3 move takes time:  0.6377720832824707
# minmax zero, with depth 3 move takes time:  0.06818199157714844
# minmax normal, with depth 3 move takes time:  1.2557671070098877
# minmax zero, with depth 3 move takes time:  0.04808211326599121
# minmax normal, with depth 3 move takes time:  0.9852719306945801
# minmax zero, with depth 3 move takes time:  0.07539010047912598
# minmax normal, with depth 3 move takes time:  0.9916398525238037
# minmax zero, with depth 3 move takes time:  0.04421091079711914
# minmax normal, with depth 3 move takes time:  0.8524570465087891
# minmax zero, with depth 3 move takes time:  0.03904294967651367
# minmax normal, with depth 3 move takes time:  1.475721836090088
# minmax zero, with depth 3 move takes time:  0.03281116485595703
# minmax normal, with depth 3 move takes time:  0.8794469833374023
# minmax zero, with depth 3 move takes time:  0.03194904327392578
# minmax normal, with depth 3 move takes time:  0.8418941497802734
# minmax zero, with depth 3 move takes time:  0.03609514236450195
# minmax normal, with depth 3 move takes time:  0.5448009967803955
# minmax zero, with depth 3 move takes time:  0.03566789627075195
# minmax normal, with depth 3 move takes time:  0.5342040061950684
# minmax zero, with depth 3 move takes time:  0.0595550537109375
# minmax normal, with depth 3 move takes time:  1.2070279121398926
# minmax zero, with depth 3 move takes time:  0.0388798713684082
# minmax normal, with depth 3 move takes time:  1.1803359985351562
# minmax zero, with depth 3 move takes time:  0.05131101608276367
# minmax normal, with depth 3 move takes time:  0.9971311092376709
# minmax zero, with depth 3 move takes time:  0.044306039810180664
# minmax normal, with depth 3 move takes time:  1.4390649795532227
# minmax zero, with depth 3 move takes time:  0.06475281715393066
# minmax normal, with depth 3 move takes time:  0.7863190174102783
# minmax zero, with depth 3 move takes time:  0.03603506088256836
# minmax normal, with depth 3 move takes time:  0.7228870391845703
# minmax zero, with depth 3 move takes time:  0.022429943084716797
# minmax normal, with depth 3 move takes time:  0.39645886421203613
# minmax zero, with depth 3 move takes time:  0.03514218330383301
# minmax normal, with depth 3 move takes time:  0.20272302627563477
# minmax zero, with depth 3 move takes time:  0.013597965240478516
# minmax normal, with depth 3 move takes time:  0.1950850486755371
# minmax zero, with depth 3 move takes time:  0.01495504379272461
# minmax normal, with depth 3 move takes time:  0.0820472240447998
# minmax zero, with depth 3 move takes time:  0.007009029388427734
# minmax normal, with depth 3 move takes time:  0.05453801155090332
# minmax zero, with depth 3 move takes time:  0.008871793746948242
# minmax normal, with depth 3 move takes time:  0.04383993148803711
# minmax zero, with depth 3 move takes time:  0.010109901428222656
# minmax normal, with depth 3 move takes time:  0.0065348148345947266
# minmax zero, with depth 3 move takes time:  0.00551605224609375
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.19225215911865234
# minmax zero, with depth 3 move takes time:  0.04414987564086914
# minmax normal, with depth 3 move takes time:  0.4185910224914551
# minmax zero, with depth 3 move takes time:  0.07092499732971191
# minmax normal, with depth 3 move takes time:  0.5071301460266113
# minmax zero, with depth 3 move takes time:  0.05994415283203125
# minmax normal, with depth 3 move takes time:  0.4161679744720459
# minmax zero, with depth 3 move takes time:  0.0348360538482666
# minmax normal, with depth 3 move takes time:  0.778864860534668
# minmax zero, with depth 3 move takes time:  0.06420516967773438
# minmax normal, with depth 3 move takes time:  1.880152940750122
# minmax zero, with depth 3 move takes time:  0.0547640323638916
# minmax normal, with depth 3 move takes time:  1.272778034210205
# minmax zero, with depth 3 move takes time:  0.056218862533569336
# minmax normal, with depth 3 move takes time:  1.1691288948059082
# minmax zero, with depth 3 move takes time:  0.10291600227355957
# minmax normal, with depth 3 move takes time:  1.561755895614624
# minmax zero, with depth 3 move takes time:  0.11237096786499023
# minmax normal, with depth 3 move takes time:  1.713073968887329
# minmax zero, with depth 3 move takes time:  0.09389495849609375
# minmax normal, with depth 3 move takes time:  1.0093801021575928
# minmax zero, with depth 3 move takes time:  0.0617060661315918
# minmax normal, with depth 3 move takes time:  1.1904120445251465
# minmax zero, with depth 3 move takes time:  0.11951804161071777
# minmax normal, with depth 3 move takes time:  1.0455400943756104
# minmax zero, with depth 3 move takes time:  0.06826019287109375
# minmax normal, with depth 3 move takes time:  0.9047231674194336
# minmax zero, with depth 3 move takes time:  0.074188232421875
# minmax normal, with depth 3 move takes time:  0.8609330654144287
# minmax zero, with depth 3 move takes time:  0.044487953186035156
# minmax normal, with depth 3 move takes time:  0.7333109378814697
# minmax zero, with depth 3 move takes time:  0.05414891242980957
# minmax normal, with depth 3 move takes time:  1.3847289085388184
# minmax zero, with depth 3 move takes time:  0.06612205505371094
# minmax normal, with depth 3 move takes time:  1.0363669395446777
# minmax zero, with depth 3 move takes time:  0.1057431697845459
# minmax normal, with depth 3 move takes time:  0.9312038421630859
# minmax zero, with depth 3 move takes time:  0.06298518180847168
# minmax normal, with depth 3 move takes time:  1.439946174621582
# minmax zero, with depth 3 move takes time:  0.07201194763183594
# minmax normal, with depth 3 move takes time:  2.898340940475464
# minmax zero, with depth 3 move takes time:  0.06190800666809082
# minmax normal, with depth 3 move takes time:  0.9690120220184326
# minmax zero, with depth 3 move takes time:  0.11299395561218262
# minmax normal, with depth 3 move takes time:  0.6216781139373779
# minmax zero, with depth 3 move takes time:  0.048789024353027344
# minmax normal, with depth 3 move takes time:  0.8977499008178711
# minmax zero, with depth 3 move takes time:  0.03981614112854004
# minmax normal, with depth 3 move takes time:  0.9547429084777832
# minmax zero, with depth 3 move takes time:  0.06691813468933105
# minmax normal, with depth 3 move takes time:  0.843986988067627
# minmax zero, with depth 3 move takes time:  0.0238339900970459
# minmax normal, with depth 3 move takes time:  0.9923229217529297
# minmax zero, with depth 3 move takes time:  0.05531191825866699
# minmax normal, with depth 3 move takes time:  0.5945329666137695
# minmax zero, with depth 3 move takes time:  0.03128314018249512
# minmax normal, with depth 3 move takes time:  0.7245359420776367
# minmax zero, with depth 3 move takes time:  0.04739999771118164
# minmax normal, with depth 3 move takes time:  0.7889001369476318
# minmax zero, with depth 3 move takes time:  0.029016971588134766
# minmax normal, with depth 3 move takes time:  0.591555118560791
# minmax zero, with depth 3 move takes time:  0.02922797203063965
# minmax normal, with depth 3 move takes time:  0.6787819862365723
# minmax zero, with depth 3 move takes time:  0.03020191192626953
# minmax normal, with depth 3 move takes time:  0.742682933807373
# minmax zero, with depth 3 move takes time:  0.027371883392333984
# minmax normal, with depth 3 move takes time:  0.6771159172058105
# minmax zero, with depth 3 move takes time:  0.023545026779174805
# minmax normal, with depth 3 move takes time:  0.17622995376586914
# minmax zero, with depth 3 move takes time:  0.021166086196899414
# minmax normal, with depth 3 move takes time:  0.07366609573364258
# minmax zero, with depth 3 move takes time:  0.015519857406616211
# minmax normal, with depth 3 move takes time:  0.015820980072021484
# minmax zero, with depth 3 move takes time:  0.00428009033203125
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.19657087326049805
# minmax zero, with depth 3 move takes time:  0.04358696937561035
# minmax normal, with depth 3 move takes time:  0.427656888961792
# minmax zero, with depth 3 move takes time:  0.0678400993347168
# minmax normal, with depth 3 move takes time:  0.4947319030761719
# minmax zero, with depth 3 move takes time:  0.06114912033081055
# minmax normal, with depth 3 move takes time:  0.38458895683288574
# minmax zero, with depth 3 move takes time:  0.03393888473510742
# minmax normal, with depth 3 move takes time:  0.7404608726501465
# minmax zero, with depth 3 move takes time:  0.043817996978759766
# minmax normal, with depth 3 move takes time:  1.9465880393981934
# minmax zero, with depth 3 move takes time:  0.05736398696899414
# minmax normal, with depth 3 move takes time:  1.2651739120483398
# minmax zero, with depth 3 move takes time:  0.0607600212097168
# minmax normal, with depth 3 move takes time:  1.0202720165252686
# minmax zero, with depth 3 move takes time:  0.07198405265808105
# minmax normal, with depth 3 move takes time:  1.4465961456298828
# minmax zero, with depth 3 move takes time:  0.08157587051391602
# minmax normal, with depth 3 move takes time:  1.8171892166137695
# minmax zero, with depth 3 move takes time:  0.09595680236816406
# minmax normal, with depth 3 move takes time:  0.9590301513671875
# minmax zero, with depth 3 move takes time:  0.06292915344238281
# minmax normal, with depth 3 move takes time:  1.0259840488433838
# minmax zero, with depth 3 move takes time:  0.09801101684570312
# minmax normal, with depth 3 move takes time:  0.9028370380401611
# minmax zero, with depth 3 move takes time:  0.0750279426574707
# minmax normal, with depth 3 move takes time:  0.8954529762268066
# minmax zero, with depth 3 move takes time:  0.048416852951049805
# minmax normal, with depth 3 move takes time:  0.8007102012634277
# minmax zero, with depth 3 move takes time:  0.048957109451293945
# minmax normal, with depth 3 move takes time:  0.7833189964294434
# minmax zero, with depth 3 move takes time:  0.07095599174499512
# minmax normal, with depth 3 move takes time:  1.3776118755340576
# minmax zero, with depth 3 move takes time:  0.04266691207885742
# minmax normal, with depth 3 move takes time:  0.938025951385498
# minmax zero, with depth 3 move takes time:  0.11855387687683105
# minmax normal, with depth 3 move takes time:  0.8590571880340576
# minmax zero, with depth 3 move takes time:  0.06300711631774902
# minmax normal, with depth 3 move takes time:  1.4688429832458496
# minmax zero, with depth 3 move takes time:  0.10311293601989746
# minmax normal, with depth 3 move takes time:  2.64083194732666
# minmax zero, with depth 3 move takes time:  0.04895305633544922
# minmax normal, with depth 3 move takes time:  0.8104269504547119
# minmax zero, with depth 3 move takes time:  0.061034202575683594
# minmax normal, with depth 3 move takes time:  0.5980498790740967
# minmax zero, with depth 3 move takes time:  0.051313161849975586
# minmax normal, with depth 3 move takes time:  0.8369829654693604
# minmax zero, with depth 3 move takes time:  0.04027414321899414
# minmax normal, with depth 3 move takes time:  0.8674800395965576
# minmax zero, with depth 3 move takes time:  0.0457608699798584
# minmax normal, with depth 3 move takes time:  0.8283820152282715
# minmax zero, with depth 3 move takes time:  0.028391122817993164
# minmax normal, with depth 3 move takes time:  1.2323639392852783
# minmax zero, with depth 3 move takes time:  0.044526100158691406
# minmax normal, with depth 3 move takes time:  0.49332094192504883
# minmax zero, with depth 3 move takes time:  0.03194594383239746
# minmax normal, with depth 3 move takes time:  0.7073240280151367
# minmax zero, with depth 3 move takes time:  0.0435481071472168
# minmax normal, with depth 3 move takes time:  0.770859956741333
# minmax zero, with depth 3 move takes time:  0.03174996376037598
# minmax normal, with depth 3 move takes time:  0.5757951736450195
# minmax zero, with depth 3 move takes time:  0.02772808074951172
# minmax normal, with depth 3 move takes time:  0.741563081741333
# minmax zero, with depth 3 move takes time:  0.03095698356628418
# minmax normal, with depth 3 move takes time:  0.7232730388641357
# minmax zero, with depth 3 move takes time:  0.028885841369628906
# minmax normal, with depth 3 move takes time:  0.5768630504608154
# minmax zero, with depth 3 move takes time:  0.02780294418334961
# minmax normal, with depth 3 move takes time:  0.1822190284729004
# minmax zero, with depth 3 move takes time:  0.01770305633544922
# minmax normal, with depth 3 move takes time:  0.07580113410949707
# minmax zero, with depth 3 move takes time:  0.01320195198059082
# minmax normal, with depth 3 move takes time:  0.016384124755859375
# minmax zero, with depth 3 move takes time:  0.0037119388580322266
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.1914520263671875
# minmax zero, with depth 3 move takes time:  0.06327199935913086
# minmax normal, with depth 3 move takes time:  0.4720618724822998
# minmax zero, with depth 3 move takes time:  0.08320307731628418
# minmax normal, with depth 3 move takes time:  0.4978771209716797
# minmax zero, with depth 3 move takes time:  0.07786893844604492
# minmax normal, with depth 3 move takes time:  0.6033608913421631
# minmax zero, with depth 3 move takes time:  0.0751650333404541
# minmax normal, with depth 3 move takes time:  0.7789890766143799
# minmax zero, with depth 3 move takes time:  0.0697789192199707
# minmax normal, with depth 3 move takes time:  1.925886869430542
# minmax zero, with depth 3 move takes time:  0.06566715240478516
# minmax normal, with depth 3 move takes time:  1.3189501762390137
# minmax zero, with depth 3 move takes time:  0.06017494201660156
# minmax normal, with depth 3 move takes time:  1.0236790180206299
# minmax zero, with depth 3 move takes time:  0.07172703742980957
# minmax normal, with depth 3 move takes time:  1.561474084854126
# minmax zero, with depth 3 move takes time:  0.10659003257751465
# minmax normal, with depth 3 move takes time:  1.9173882007598877
# minmax zero, with depth 3 move takes time:  0.13962578773498535
# minmax normal, with depth 3 move takes time:  1.1548941135406494
# minmax zero, with depth 3 move takes time:  0.06470513343811035
# minmax normal, with depth 3 move takes time:  1.043076992034912
# minmax zero, with depth 3 move takes time:  0.11652588844299316
# minmax normal, with depth 3 move takes time:  0.9515769481658936
# minmax zero, with depth 3 move takes time:  0.06929492950439453
# minmax normal, with depth 3 move takes time:  0.9255199432373047
# minmax zero, with depth 3 move takes time:  0.04931998252868652
# minmax normal, with depth 3 move takes time:  0.8389251232147217
# minmax zero, with depth 3 move takes time:  0.051434993743896484
# minmax normal, with depth 3 move takes time:  0.6774580478668213
# minmax zero, with depth 3 move takes time:  0.048422813415527344
# minmax normal, with depth 3 move takes time:  1.3922538757324219
# minmax zero, with depth 3 move takes time:  0.06849503517150879
# minmax normal, with depth 3 move takes time:  1.0971989631652832
# minmax zero, with depth 3 move takes time:  0.13354706764221191
# minmax normal, with depth 3 move takes time:  0.9496629238128662
# minmax zero, with depth 3 move takes time:  0.10199189186096191
# minmax normal, with depth 3 move takes time:  1.5723860263824463
# minmax zero, with depth 3 move takes time:  0.05924701690673828
# minmax normal, with depth 3 move takes time:  2.852504014968872
# minmax zero, with depth 3 move takes time:  0.06463909149169922
# minmax normal, with depth 3 move takes time:  0.8386709690093994
# minmax zero, with depth 3 move takes time:  0.07815194129943848
# minmax normal, with depth 3 move takes time:  0.5920331478118896
# minmax zero, with depth 3 move takes time:  0.05061912536621094
# minmax normal, with depth 3 move takes time:  1.001758098602295
# minmax zero, with depth 3 move takes time:  0.04031991958618164
# minmax normal, with depth 3 move takes time:  0.8812239170074463
# minmax zero, with depth 3 move takes time:  0.04831099510192871
# minmax normal, with depth 3 move takes time:  0.7915639877319336
# minmax zero, with depth 3 move takes time:  0.027544021606445312
# minmax normal, with depth 3 move takes time:  0.9743061065673828
# minmax zero, with depth 3 move takes time:  0.0567319393157959
# minmax normal, with depth 3 move takes time:  0.5437932014465332
# minmax zero, with depth 3 move takes time:  0.059126853942871094
# minmax normal, with depth 3 move takes time:  0.7283170223236084
# minmax zero, with depth 3 move takes time:  0.054908037185668945
# minmax normal, with depth 3 move takes time:  0.822131872177124
# minmax zero, with depth 3 move takes time:  0.029614925384521484
# minmax normal, with depth 3 move takes time:  0.5811641216278076
# minmax zero, with depth 3 move takes time:  0.026706933975219727
# minmax normal, with depth 3 move takes time:  0.6764171123504639
# minmax zero, with depth 3 move takes time:  0.03242683410644531
# minmax normal, with depth 3 move takes time:  0.7267470359802246
# minmax zero, with depth 3 move takes time:  0.027278900146484375
# minmax normal, with depth 3 move takes time:  0.5166199207305908
# minmax zero, with depth 3 move takes time:  0.024302959442138672
# minmax normal, with depth 3 move takes time:  0.18052005767822266
# minmax zero, with depth 3 move takes time:  0.01911306381225586
# minmax normal, with depth 3 move takes time:  0.07482790946960449
# minmax zero, with depth 3 move takes time:  0.01372218132019043
# minmax normal, with depth 3 move takes time:  0.015861988067626953
# minmax zero, with depth 3 move takes time:  0.004221916198730469
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 3 move takes time:  0.04091691970825195
# minmax normal, with depth 3 move takes time:  0.15962791442871094
# minmax zero, with depth 3 move takes time:  0.050781965255737305
# minmax normal, with depth 3 move takes time:  0.4100379943847656
# minmax zero, with depth 3 move takes time:  0.0704808235168457
# minmax normal, with depth 3 move takes time:  0.48682713508605957
# minmax zero, with depth 3 move takes time:  0.06626105308532715
# minmax normal, with depth 3 move takes time:  0.341418981552124
# minmax zero, with depth 3 move takes time:  0.04988908767700195
# minmax normal, with depth 3 move takes time:  0.4422481060028076
# minmax zero, with depth 3 move takes time:  0.08279895782470703
# minmax normal, with depth 3 move takes time:  1.0929388999938965
# minmax zero, with depth 3 move takes time:  0.0893399715423584
# minmax normal, with depth 3 move takes time:  0.971527099609375
# minmax zero, with depth 3 move takes time:  0.11269998550415039
# minmax normal, with depth 3 move takes time:  0.5895340442657471
# minmax zero, with depth 3 move takes time:  0.09570097923278809
# minmax normal, with depth 3 move takes time:  2.012848138809204
# minmax zero, with depth 3 move takes time:  0.15049982070922852
# minmax normal, with depth 3 move takes time:  2.0370819568634033
# minmax zero, with depth 3 move takes time:  0.15903615951538086
# minmax normal, with depth 3 move takes time:  1.2423899173736572
# minmax zero, with depth 3 move takes time:  0.11717605590820312
# minmax normal, with depth 3 move takes time:  1.896162986755371
# minmax zero, with depth 3 move takes time:  0.14805388450622559
# minmax normal, with depth 3 move takes time:  2.0662782192230225
# minmax zero, with depth 3 move takes time:  0.23384404182434082
# minmax normal, with depth 3 move takes time:  2.1827030181884766
# minmax zero, with depth 3 move takes time:  0.16448593139648438
# minmax normal, with depth 3 move takes time:  4.069748878479004
# minmax zero, with depth 3 move takes time:  0.08156895637512207
# minmax normal, with depth 3 move takes time:  1.925321102142334
# minmax zero, with depth 3 move takes time:  0.11142706871032715
# minmax normal, with depth 3 move takes time:  1.4927749633789062
# minmax zero, with depth 3 move takes time:  0.07581305503845215
# minmax normal, with depth 3 move takes time:  1.0172460079193115
# minmax zero, with depth 3 move takes time:  0.07001996040344238
# minmax normal, with depth 3 move takes time:  0.7015831470489502
# minmax zero, with depth 3 move takes time:  0.09343409538269043
# minmax normal, with depth 3 move takes time:  0.7224009037017822
# minmax zero, with depth 3 move takes time:  0.07695603370666504
# minmax normal, with depth 3 move takes time:  0.6744630336761475
# minmax zero, with depth 3 move takes time:  0.09108591079711914
# minmax normal, with depth 3 move takes time:  1.3082890510559082
# minmax zero, with depth 3 move takes time:  0.051489830017089844
# minmax normal, with depth 3 move takes time:  0.9959039688110352
# minmax zero, with depth 3 move takes time:  0.07220602035522461
# minmax normal, with depth 3 move takes time:  1.0508480072021484
# minmax zero, with depth 3 move takes time:  0.053980112075805664
# minmax normal, with depth 3 move takes time:  0.9566428661346436
# minmax zero, with depth 3 move takes time:  0.04707503318786621
# minmax normal, with depth 3 move takes time:  1.6955020427703857
# minmax zero, with depth 3 move takes time:  0.028476953506469727
# minmax normal, with depth 3 move takes time:  1.0018019676208496
# minmax zero, with depth 3 move takes time:  0.03852510452270508
# minmax normal, with depth 3 move takes time:  0.9198698997497559
# minmax zero, with depth 3 move takes time:  0.045797109603881836
# minmax normal, with depth 3 move takes time:  0.6119649410247803
# minmax zero, with depth 3 move takes time:  0.03396105766296387
# minmax normal, with depth 3 move takes time:  0.565971851348877
# minmax zero, with depth 3 move takes time:  0.06371116638183594
# minmax normal, with depth 3 move takes time:  1.188338041305542
# minmax zero, with depth 3 move takes time:  0.03793692588806152
# minmax normal, with depth 3 move takes time:  1.1782360076904297
# minmax zero, with depth 3 move takes time:  0.051614999771118164
# minmax normal, with depth 3 move takes time:  1.0301299095153809
# minmax zero, with depth 3 move takes time:  0.047518014907836914
# minmax normal, with depth 3 move takes time:  1.4361131191253662
# minmax zero, with depth 3 move takes time:  0.07335805892944336
# minmax normal, with depth 3 move takes time:  0.8455898761749268
# minmax zero, with depth 3 move takes time:  0.03635716438293457
# minmax normal, with depth 3 move takes time:  0.7225711345672607
# minmax zero, with depth 3 move takes time:  0.02305293083190918
# minmax normal, with depth 3 move takes time:  0.41611385345458984
# minmax zero, with depth 3 move takes time:  0.03494882583618164
# minmax normal, with depth 3 move takes time:  0.20758700370788574
# minmax zero, with depth 3 move takes time:  0.01293802261352539
# minmax normal, with depth 3 move takes time:  0.2014148235321045
# minmax zero, with depth 3 move takes time:  0.01394796371459961
# minmax normal, with depth 3 move takes time:  0.08751487731933594
# minmax zero, with depth 3 move takes time:  0.005984067916870117
# minmax normal, with depth 3 move takes time:  0.05422711372375488
# minmax zero, with depth 3 move takes time:  0.007838964462280273
# minmax normal, with depth 3 move takes time:  0.04014301300048828
# minmax zero, with depth 3 move takes time:  0.008770942687988281
# minmax normal, with depth 3 move takes time:  0.0040819644927978516
# minmax zero, with depth 3 move takes time:  0.003576040267944336
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.1835169792175293
# minmax zero, with depth 3 move takes time:  0.04724407196044922
# minmax normal, with depth 3 move takes time:  0.43962693214416504
# minmax zero, with depth 3 move takes time:  0.07145905494689941
# minmax normal, with depth 3 move takes time:  0.512470006942749
# minmax zero, with depth 3 move takes time:  0.06310796737670898
# minmax normal, with depth 3 move takes time:  0.39345693588256836
# minmax zero, with depth 3 move takes time:  0.037322998046875
# minmax normal, with depth 3 move takes time:  0.7677898406982422
# minmax zero, with depth 3 move takes time:  0.04378008842468262
# minmax normal, with depth 3 move takes time:  1.888037919998169
# minmax zero, with depth 3 move takes time:  0.05521392822265625
# minmax normal, with depth 3 move takes time:  1.2810461521148682
# minmax zero, with depth 3 move takes time:  0.05560183525085449
# minmax normal, with depth 3 move takes time:  1.0661869049072266
# minmax zero, with depth 3 move takes time:  0.07450604438781738
# minmax normal, with depth 3 move takes time:  1.530029058456421
# minmax zero, with depth 3 move takes time:  0.07813096046447754
# minmax normal, with depth 3 move takes time:  1.8597090244293213
# minmax zero, with depth 3 move takes time:  0.13933396339416504
# minmax normal, with depth 3 move takes time:  1.0820248126983643
# minmax zero, with depth 3 move takes time:  0.06146597862243652
# minmax normal, with depth 3 move takes time:  1.1712257862091064
# minmax zero, with depth 3 move takes time:  0.09589600563049316
# minmax normal, with depth 3 move takes time:  0.9012069702148438
# minmax zero, with depth 3 move takes time:  0.07071495056152344
# minmax normal, with depth 3 move takes time:  0.8870711326599121
# minmax zero, with depth 3 move takes time:  0.045934200286865234
# minmax normal, with depth 3 move takes time:  0.7995572090148926
# minmax zero, with depth 3 move takes time:  0.04460501670837402
# minmax normal, with depth 3 move takes time:  0.7177059650421143
# minmax zero, with depth 3 move takes time:  0.049677133560180664
# minmax normal, with depth 3 move takes time:  1.303779125213623
# minmax zero, with depth 3 move takes time:  0.05893301963806152
# minmax normal, with depth 3 move takes time:  0.9802248477935791
# minmax zero, with depth 3 move takes time:  0.09082412719726562
# minmax normal, with depth 3 move takes time:  0.8570449352264404
# minmax zero, with depth 3 move takes time:  0.06141400337219238
# minmax normal, with depth 3 move takes time:  1.4955730438232422
# minmax zero, with depth 3 move takes time:  0.06845617294311523
# minmax normal, with depth 3 move takes time:  2.5070090293884277
# minmax zero, with depth 3 move takes time:  0.04799509048461914
# minmax normal, with depth 3 move takes time:  0.847538948059082
# minmax zero, with depth 3 move takes time:  0.07104110717773438
# minmax normal, with depth 3 move takes time:  0.5886790752410889
# minmax zero, with depth 3 move takes time:  0.05026698112487793
# minmax normal, with depth 3 move takes time:  0.852755069732666
# minmax zero, with depth 3 move takes time:  0.04315495491027832
# minmax normal, with depth 3 move takes time:  0.8959269523620605
# minmax zero, with depth 3 move takes time:  0.04823493957519531
# minmax normal, with depth 3 move takes time:  0.7889869213104248
# minmax zero, with depth 3 move takes time:  0.025075912475585938
# minmax normal, with depth 3 move takes time:  0.973107099533081
# minmax zero, with depth 3 move takes time:  0.04006195068359375
# minmax normal, with depth 3 move takes time:  0.4799320697784424
# minmax zero, with depth 3 move takes time:  0.030055999755859375
# minmax normal, with depth 3 move takes time:  0.7270958423614502
# minmax zero, with depth 3 move takes time:  0.04514193534851074
# minmax normal, with depth 3 move takes time:  0.6913349628448486
# minmax zero, with depth 3 move takes time:  0.030462026596069336
# minmax normal, with depth 3 move takes time:  0.5865061283111572
# minmax zero, with depth 3 move takes time:  0.025217056274414062
# minmax normal, with depth 3 move takes time:  0.680732011795044
# minmax zero, with depth 3 move takes time:  0.031889915466308594
# minmax normal, with depth 3 move takes time:  0.7103009223937988
# minmax zero, with depth 3 move takes time:  0.025632858276367188
# minmax normal, with depth 3 move takes time:  0.5212759971618652
# minmax zero, with depth 3 move takes time:  0.030766010284423828
# minmax normal, with depth 3 move takes time:  0.2805650234222412
# minmax zero, with depth 3 move takes time:  0.043524980545043945
# minmax normal, with depth 3 move takes time:  0.14026188850402832
# minmax zero, with depth 3 move takes time:  0.025738954544067383
# minmax normal, with depth 3 move takes time:  0.03426194190979004
# minmax zero, with depth 3 move takes time:  0.007964849472045898
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 3 move takes time:  0.07407498359680176
# minmax normal, with depth 3 move takes time:  0.16344690322875977
# minmax zero, with depth 3 move takes time:  0.051748037338256836
# minmax normal, with depth 3 move takes time:  0.41099095344543457
# minmax zero, with depth 3 move takes time:  0.07251405715942383
# minmax normal, with depth 3 move takes time:  0.5001649856567383
# minmax zero, with depth 3 move takes time:  0.06676101684570312
# minmax normal, with depth 3 move takes time:  0.33699798583984375
# minmax zero, with depth 3 move takes time:  0.049883127212524414
# minmax normal, with depth 3 move takes time:  0.46195316314697266
# minmax zero, with depth 3 move takes time:  0.08789181709289551
# minmax normal, with depth 3 move takes time:  1.0968389511108398
# minmax zero, with depth 3 move takes time:  0.08794116973876953
# minmax normal, with depth 3 move takes time:  0.9647078514099121
# minmax zero, with depth 3 move takes time:  0.11255788803100586
# minmax normal, with depth 3 move takes time:  0.5974400043487549
# minmax zero, with depth 3 move takes time:  0.0891411304473877
# minmax normal, with depth 3 move takes time:  1.7872920036315918
# minmax zero, with depth 3 move takes time:  0.09495711326599121
# minmax normal, with depth 3 move takes time:  1.8066480159759521
# minmax zero, with depth 3 move takes time:  0.09581398963928223
# minmax normal, with depth 3 move takes time:  1.0663199424743652
# minmax zero, with depth 3 move takes time:  0.1231839656829834
# minmax normal, with depth 3 move takes time:  1.6369819641113281
# minmax zero, with depth 3 move takes time:  0.1271679401397705
# minmax normal, with depth 3 move takes time:  2.053938865661621
# minmax zero, with depth 3 move takes time:  0.14524006843566895
# minmax normal, with depth 3 move takes time:  1.8978359699249268
# minmax zero, with depth 3 move takes time:  0.10883402824401855
# minmax normal, with depth 3 move takes time:  3.3334579467773438
# minmax zero, with depth 3 move takes time:  0.07898807525634766
# minmax normal, with depth 3 move takes time:  1.8182649612426758
# minmax zero, with depth 3 move takes time:  0.10654091835021973
# minmax normal, with depth 3 move takes time:  1.4881141185760498
# minmax zero, with depth 3 move takes time:  0.08277010917663574
# minmax normal, with depth 3 move takes time:  1.0234389305114746
# minmax zero, with depth 3 move takes time:  0.07419800758361816
# minmax normal, with depth 3 move takes time:  0.7063250541687012
# minmax zero, with depth 3 move takes time:  0.08819198608398438
# minmax normal, with depth 3 move takes time:  0.6999709606170654
# minmax zero, with depth 3 move takes time:  0.06863212585449219
# minmax normal, with depth 3 move takes time:  0.6425411701202393
# minmax zero, with depth 3 move takes time:  0.0669260025024414
# minmax normal, with depth 3 move takes time:  1.220142126083374
# minmax zero, with depth 3 move takes time:  0.04554295539855957
# minmax normal, with depth 3 move takes time:  1.0427241325378418
# minmax zero, with depth 3 move takes time:  0.07981181144714355
# minmax normal, with depth 3 move takes time:  0.9980700016021729
# minmax zero, with depth 3 move takes time:  0.038851022720336914
# minmax normal, with depth 3 move takes time:  0.8640038967132568
# minmax zero, with depth 3 move takes time:  0.05653882026672363
# minmax normal, with depth 3 move takes time:  1.6576790809631348
# minmax zero, with depth 3 move takes time:  0.029471874237060547
# minmax normal, with depth 3 move takes time:  0.9094510078430176
# minmax zero, with depth 3 move takes time:  0.029134035110473633
# minmax normal, with depth 3 move takes time:  0.8312859535217285
# minmax zero, with depth 3 move takes time:  0.03419995307922363
# minmax normal, with depth 3 move takes time:  0.5322699546813965
# minmax zero, with depth 3 move takes time:  0.03575301170349121
# minmax normal, with depth 3 move takes time:  0.5295238494873047
# minmax zero, with depth 3 move takes time:  0.055226802825927734
# minmax normal, with depth 3 move takes time:  1.1568748950958252
# minmax zero, with depth 3 move takes time:  0.03360891342163086
# minmax normal, with depth 3 move takes time:  1.1549949645996094
# minmax zero, with depth 3 move takes time:  0.04735302925109863
# minmax normal, with depth 3 move takes time:  0.9902660846710205
# minmax zero, with depth 3 move takes time:  0.042542219161987305
# minmax normal, with depth 3 move takes time:  1.3504059314727783
# minmax zero, with depth 3 move takes time:  0.05977511405944824
# minmax normal, with depth 3 move takes time:  0.7532238960266113
# minmax zero, with depth 3 move takes time:  0.0359339714050293
# minmax normal, with depth 3 move takes time:  0.6761260032653809
# minmax zero, with depth 3 move takes time:  0.02257394790649414
# minmax normal, with depth 3 move takes time:  0.39244890213012695
# minmax zero, with depth 3 move takes time:  0.02843499183654785
# minmax normal, with depth 3 move takes time:  0.20074892044067383
# minmax zero, with depth 3 move takes time:  0.013804912567138672
# minmax normal, with depth 3 move takes time:  0.1901719570159912
# minmax zero, with depth 3 move takes time:  0.014173030853271484
# minmax normal, with depth 3 move takes time:  0.08216500282287598
# minmax zero, with depth 3 move takes time:  0.006815910339355469
# minmax normal, with depth 3 move takes time:  0.051605939865112305
# minmax zero, with depth 3 move takes time:  0.008564949035644531
# minmax normal, with depth 3 move takes time:  0.038110971450805664
# minmax zero, with depth 3 move takes time:  0.008633852005004883
# minmax normal, with depth 3 move takes time:  0.003790140151977539
# minmax zero, with depth 3 move takes time:  0.0040149688720703125
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 3 move takes time:  0.04079079627990723
# minmax normal, with depth 3 move takes time:  0.1617259979248047
# minmax zero, with depth 3 move takes time:  0.05213308334350586
# minmax normal, with depth 3 move takes time:  0.4069509506225586
# minmax zero, with depth 3 move takes time:  0.07053709030151367
# minmax normal, with depth 3 move takes time:  0.4485280513763428
# minmax zero, with depth 3 move takes time:  0.06680107116699219
# minmax normal, with depth 3 move takes time:  0.3352208137512207
# minmax zero, with depth 3 move takes time:  0.05077695846557617
# minmax normal, with depth 3 move takes time:  0.43988513946533203
# minmax zero, with depth 3 move takes time:  0.08570504188537598
# minmax normal, with depth 3 move takes time:  1.090475082397461
# minmax zero, with depth 3 move takes time:  0.08701181411743164
# minmax normal, with depth 3 move takes time:  0.9211249351501465
# minmax zero, with depth 3 move takes time:  0.10380697250366211
# minmax normal, with depth 3 move takes time:  0.5676219463348389
# minmax zero, with depth 3 move takes time:  0.09022307395935059
# minmax normal, with depth 3 move takes time:  1.7310011386871338
# minmax zero, with depth 3 move takes time:  0.09825897216796875
# minmax normal, with depth 3 move takes time:  1.7433621883392334
# minmax zero, with depth 3 move takes time:  0.09365606307983398
# minmax normal, with depth 3 move takes time:  1.0512831211090088
# minmax zero, with depth 3 move takes time:  0.11813902854919434
# minmax normal, with depth 3 move takes time:  1.6324679851531982
# minmax zero, with depth 3 move takes time:  0.12948012351989746
# minmax normal, with depth 3 move takes time:  2.0300791263580322
# minmax zero, with depth 3 move takes time:  0.14394187927246094
# minmax normal, with depth 3 move takes time:  1.9009449481964111
# minmax zero, with depth 3 move takes time:  0.10574007034301758
# minmax normal, with depth 3 move takes time:  3.431210994720459
# minmax zero, with depth 3 move takes time:  0.07788777351379395
# minmax normal, with depth 3 move takes time:  1.883800983428955
# minmax zero, with depth 3 move takes time:  0.10277199745178223
# minmax normal, with depth 3 move takes time:  1.5070950984954834
# minmax zero, with depth 3 move takes time:  0.07116818428039551
# minmax normal, with depth 3 move takes time:  1.0273160934448242
# minmax zero, with depth 3 move takes time:  0.07268905639648438
# minmax normal, with depth 3 move takes time:  0.6952741146087646
# minmax zero, with depth 3 move takes time:  0.09557294845581055
# minmax normal, with depth 3 move takes time:  0.6796059608459473
# minmax zero, with depth 3 move takes time:  0.07168412208557129
# minmax normal, with depth 3 move takes time:  0.6570780277252197
# minmax zero, with depth 3 move takes time:  0.06310081481933594
# minmax normal, with depth 3 move takes time:  1.2714929580688477
# minmax zero, with depth 3 move takes time:  0.04192709922790527
# minmax normal, with depth 3 move takes time:  0.9799890518188477
# minmax zero, with depth 3 move takes time:  0.06833410263061523
# minmax normal, with depth 3 move takes time:  0.9784409999847412
# minmax zero, with depth 3 move takes time:  0.041944026947021484
# minmax normal, with depth 3 move takes time:  0.849276065826416
# minmax zero, with depth 3 move takes time:  0.035429954528808594
# minmax normal, with depth 3 move takes time:  1.4811420440673828
# minmax zero, with depth 3 move takes time:  0.028856992721557617
# minmax normal, with depth 3 move takes time:  0.8857948780059814
# minmax zero, with depth 3 move takes time:  0.03406405448913574
# minmax normal, with depth 3 move takes time:  0.8449079990386963
# minmax zero, with depth 3 move takes time:  0.03432798385620117
# minmax normal, with depth 3 move takes time:  0.5736520290374756
# minmax zero, with depth 3 move takes time:  0.03506588935852051
# minmax normal, with depth 3 move takes time:  0.5413250923156738
# minmax zero, with depth 3 move takes time:  0.06663894653320312
# minmax normal, with depth 3 move takes time:  1.229996919631958
# minmax zero, with depth 3 move takes time:  0.03792119026184082
# minmax normal, with depth 3 move takes time:  1.30491304397583
# minmax zero, with depth 3 move takes time:  0.04793715476989746
# minmax normal, with depth 3 move takes time:  1.0973100662231445
# minmax zero, with depth 3 move takes time:  0.04851698875427246
# minmax normal, with depth 3 move takes time:  1.4181230068206787
# minmax zero, with depth 3 move takes time:  0.058055877685546875
# minmax normal, with depth 3 move takes time:  0.7743320465087891
# minmax zero, with depth 3 move takes time:  0.0329289436340332
# minmax normal, with depth 3 move takes time:  0.7223000526428223
# minmax zero, with depth 3 move takes time:  0.019397974014282227
# minmax normal, with depth 3 move takes time:  0.40639305114746094
# minmax zero, with depth 3 move takes time:  0.029312849044799805
# minmax normal, with depth 3 move takes time:  0.21994590759277344
# minmax zero, with depth 3 move takes time:  0.012372016906738281
# minmax normal, with depth 3 move takes time:  0.21752190589904785
# minmax zero, with depth 3 move takes time:  0.012640953063964844
# minmax normal, with depth 3 move takes time:  0.08519506454467773
# minmax zero, with depth 3 move takes time:  0.007313966751098633
# minmax normal, with depth 3 move takes time:  0.055928945541381836
# minmax zero, with depth 3 move takes time:  0.006874799728393555
# minmax normal, with depth 3 move takes time:  0.04037308692932129
# minmax zero, with depth 3 move takes time:  0.008014917373657227
# minmax normal, with depth 3 move takes time:  0.003932952880859375
# minmax zero, with depth 3 move takes time:  0.004376888275146484
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.18975114822387695
# minmax zero, with depth 3 move takes time:  0.04308795928955078
# minmax normal, with depth 3 move takes time:  0.4279038906097412
# minmax zero, with depth 3 move takes time:  0.07230305671691895
# minmax normal, with depth 3 move takes time:  0.5030348300933838
# minmax zero, with depth 3 move takes time:  0.05294299125671387
# minmax normal, with depth 3 move takes time:  0.39153003692626953
# minmax zero, with depth 3 move takes time:  0.03421306610107422
# minmax normal, with depth 3 move takes time:  0.731644868850708
# minmax zero, with depth 3 move takes time:  0.04517388343811035
# minmax normal, with depth 3 move takes time:  1.8170270919799805
# minmax zero, with depth 3 move takes time:  0.06163501739501953
# minmax normal, with depth 3 move takes time:  1.2731351852416992
# minmax zero, with depth 3 move takes time:  0.057260990142822266
# minmax normal, with depth 3 move takes time:  1.0426020622253418
# minmax zero, with depth 3 move takes time:  0.07582783699035645
# minmax normal, with depth 3 move takes time:  1.487889051437378
# minmax zero, with depth 3 move takes time:  0.0789499282836914
# minmax normal, with depth 3 move takes time:  1.6807830333709717
# minmax zero, with depth 3 move takes time:  0.08565402030944824
# minmax normal, with depth 3 move takes time:  0.9233770370483398
# minmax zero, with depth 3 move takes time:  0.06123089790344238
# minmax normal, with depth 3 move takes time:  1.038700819015503
# minmax zero, with depth 3 move takes time:  0.09486699104309082
# minmax normal, with depth 3 move takes time:  0.9060981273651123
# minmax zero, with depth 3 move takes time:  0.07057809829711914
# minmax normal, with depth 3 move takes time:  0.9162631034851074
# minmax zero, with depth 3 move takes time:  0.045896053314208984
# minmax normal, with depth 3 move takes time:  0.8110229969024658
# minmax zero, with depth 3 move takes time:  0.0448460578918457
# minmax normal, with depth 3 move takes time:  0.6729958057403564
# minmax zero, with depth 3 move takes time:  0.0469510555267334
# minmax normal, with depth 3 move takes time:  1.2889289855957031
# minmax zero, with depth 3 move takes time:  0.04391908645629883
# minmax normal, with depth 3 move takes time:  0.9248559474945068
# minmax zero, with depth 3 move takes time:  0.08170413970947266
# minmax normal, with depth 3 move takes time:  0.8200211524963379
# minmax zero, with depth 3 move takes time:  0.06628108024597168
# minmax normal, with depth 3 move takes time:  1.3972389698028564
# minmax zero, with depth 3 move takes time:  0.06021308898925781
# minmax normal, with depth 3 move takes time:  2.438447952270508
# minmax zero, with depth 3 move takes time:  0.04771900177001953
# minmax normal, with depth 3 move takes time:  0.7976028919219971
# minmax zero, with depth 3 move takes time:  0.06216692924499512
# minmax normal, with depth 3 move takes time:  0.5844521522521973
# minmax zero, with depth 3 move takes time:  0.047831058502197266
# minmax normal, with depth 3 move takes time:  0.8332390785217285
# minmax zero, with depth 3 move takes time:  0.0414881706237793
# minmax normal, with depth 3 move takes time:  0.8696639537811279
# minmax zero, with depth 3 move takes time:  0.04709792137145996
# minmax normal, with depth 3 move takes time:  0.7909698486328125
# minmax zero, with depth 3 move takes time:  0.02345895767211914
# minmax normal, with depth 3 move takes time:  0.9688351154327393
# minmax zero, with depth 3 move takes time:  0.03790402412414551
# minmax normal, with depth 3 move takes time:  0.47084498405456543
# minmax zero, with depth 3 move takes time:  0.03049612045288086
# minmax normal, with depth 3 move takes time:  0.7065958976745605
# minmax zero, with depth 3 move takes time:  0.04254603385925293
# minmax normal, with depth 3 move takes time:  0.6926891803741455
# minmax zero, with depth 3 move takes time:  0.029886960983276367
# minmax normal, with depth 3 move takes time:  0.5766549110412598
# minmax zero, with depth 3 move takes time:  0.025054931640625
# minmax normal, with depth 3 move takes time:  0.6568930149078369
# minmax zero, with depth 3 move takes time:  0.030292034149169922
# minmax normal, with depth 3 move takes time:  0.7308468818664551
# minmax zero, with depth 3 move takes time:  0.023792028427124023
# minmax normal, with depth 3 move takes time:  0.5144920349121094
# minmax zero, with depth 3 move takes time:  0.02601003646850586
# minmax normal, with depth 3 move takes time:  0.18111896514892578
# minmax zero, with depth 3 move takes time:  0.020190000534057617
# minmax normal, with depth 3 move takes time:  0.07389998435974121
# minmax zero, with depth 3 move takes time:  0.015770912170410156
# minmax normal, with depth 3 move takes time:  0.01588892936706543
# minmax zero, with depth 3 move takes time:  0.0042362213134765625
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.18738412857055664
# minmax zero, with depth 3 move takes time:  0.04343295097351074
# minmax normal, with depth 3 move takes time:  0.42333483695983887
# minmax zero, with depth 3 move takes time:  0.06784701347351074
# minmax normal, with depth 3 move takes time:  0.4916720390319824
# minmax zero, with depth 3 move takes time:  0.055850982666015625
# minmax normal, with depth 3 move takes time:  0.38565707206726074
# minmax zero, with depth 3 move takes time:  0.043035030364990234
# minmax normal, with depth 3 move takes time:  0.7686941623687744
# minmax zero, with depth 3 move takes time:  0.049983978271484375
# minmax normal, with depth 3 move takes time:  1.9456279277801514
# minmax zero, with depth 3 move takes time:  0.05475306510925293
# minmax normal, with depth 3 move takes time:  1.531916856765747
# minmax zero, with depth 3 move takes time:  0.05620312690734863
# minmax normal, with depth 3 move takes time:  1.3133399486541748
# minmax zero, with depth 3 move takes time:  0.07911396026611328
# minmax normal, with depth 3 move takes time:  1.4661729335784912
# ...
# minmax zero, with depth 3 move takes time:  0.01254892349243164
# minmax normal, with depth 3 move takes time:  0.043489933013916016
# minmax zero, with depth 3 move takes time:  0.011416196823120117
# minmax normal, with depth 3 move takes time:  0.005349874496459961
# minmax zero, with depth 3 move takes time:  0.005238056182861328
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.22617578506469727
# minmax zero, with depth 3 move takes time:  0.07014989852905273
# minmax normal, with depth 3 move takes time:  0.43715810775756836
# minmax zero, with depth 3 move takes time:  0.07070112228393555
# minmax normal, with depth 3 move takes time:  0.5032470226287842
# minmax zero, with depth 3 move takes time:  0.058236122131347656
# minmax normal, with depth 3 move takes time:  0.3882331848144531
# minmax zero, with depth 3 move takes time:  0.03581404685974121
# minmax normal, with depth 3 move takes time:  0.7410271167755127
# minmax zero, with depth 3 move takes time:  0.04815411567687988
# minmax normal, with depth 3 move takes time:  1.8910179138183594
# minmax zero, with depth 3 move takes time:  0.10304594039916992
# minmax normal, with depth 3 move takes time:  1.7512421607971191
# minmax zero, with depth 3 move takes time:  0.054450035095214844
# minmax normal, with depth 3 move takes time:  1.0391860008239746
# minmax zero, with depth 3 move takes time:  0.07947206497192383
# minmax normal, with depth 3 move takes time:  1.4502859115600586
# minmax zero, with depth 3 move takes time:  0.07793593406677246
# minmax normal, with depth 3 move takes time:  1.8191490173339844
# minmax zero, with depth 3 move takes time:  0.13443994522094727
# minmax normal, with depth 3 move takes time:  1.092083215713501
# minmax zero, with depth 3 move takes time:  0.0982050895690918
# minmax normal, with depth 3 move takes time:  1.237130880355835
# minmax zero, with depth 3 move takes time:  0.1039280891418457
# minmax normal, with depth 3 move takes time:  0.9836041927337646
# minmax zero, with depth 3 move takes time:  0.13701987266540527
# minmax normal, with depth 3 move takes time:  0.9808659553527832
# minmax zero, with depth 3 move takes time:  0.0543971061706543
# minmax normal, with depth 3 move takes time:  0.8740119934082031
# minmax zero, with depth 3 move takes time:  0.08088207244873047
# minmax normal, with depth 3 move takes time:  0.7430269718170166
# minmax zero, with depth 3 move takes time:  0.05429983139038086
# minmax normal, with depth 3 move takes time:  1.3494668006896973
# minmax zero, with depth 3 move takes time:  0.048246145248413086
# minmax normal, with depth 3 move takes time:  0.9456329345703125
# minmax zero, with depth 3 move takes time:  0.09356188774108887
# minmax normal, with depth 3 move takes time:  0.8399801254272461
# minmax zero, with depth 3 move takes time:  0.0754709243774414
# minmax normal, with depth 3 move takes time:  1.48335599899292
# minmax zero, with depth 3 move takes time:  0.06722402572631836
# minmax normal, with depth 3 move takes time:  2.5565779209136963
# minmax zero, with depth 3 move takes time:  0.049791812896728516
# minmax normal, with depth 3 move takes time:  0.8351061344146729
# minmax zero, with depth 3 move takes time:  0.07067704200744629
# minmax normal, with depth 3 move takes time:  0.6128978729248047
# minmax zero, with depth 3 move takes time:  0.056955814361572266
# minmax normal, with depth 3 move takes time:  0.92234206199646
# minmax zero, with depth 3 move takes time:  0.04926609992980957
# minmax normal, with depth 3 move takes time:  0.9155220985412598
# minmax zero, with depth 3 move takes time:  0.05201005935668945
# minmax normal, with depth 3 move takes time:  0.8385229110717773
# minmax zero, with depth 3 move takes time:  0.025473833084106445
# minmax normal, with depth 3 move takes time:  1.0061190128326416
# minmax zero, with depth 3 move takes time:  0.04240894317626953
# minmax normal, with depth 3 move takes time:  0.48854589462280273
# minmax zero, with depth 3 move takes time:  0.0361630916595459
# minmax normal, with depth 3 move takes time:  0.7177309989929199
# minmax zero, with depth 3 move takes time:  0.04490184783935547
# minmax normal, with depth 3 move takes time:  0.672421932220459
# minmax zero, with depth 3 move takes time:  0.03345680236816406
# minmax normal, with depth 3 move takes time:  0.5669817924499512
# minmax zero, with depth 3 move takes time:  0.02716517448425293
# minmax normal, with depth 3 move takes time:  0.6568429470062256
# minmax zero, with depth 3 move takes time:  0.029851913452148438
# minmax normal, with depth 3 move takes time:  0.7501788139343262
# minmax zero, with depth 3 move takes time:  0.022903919219970703
# minmax normal, with depth 3 move takes time:  0.526839017868042
# minmax zero, with depth 3 move takes time:  0.025351762771606445
# minmax normal, with depth 3 move takes time:  0.17583203315734863
# minmax zero, with depth 3 move takes time:  0.01895594596862793
# minmax normal, with depth 3 move takes time:  0.07659101486206055
# minmax zero, with depth 3 move takes time:  0.012521028518676758
# minmax normal, with depth 3 move takes time:  0.016170978546142578
# minmax zero, with depth 3 move takes time:  0.0049550533294677734
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 3 move takes time:  0.2110300064086914
# minmax zero, with depth 3 move takes time:  0.048111915588378906
# minmax normal, with depth 3 move takes time:  0.4498929977416992
# minmax zero, with depth 3 move takes time:  0.06793999671936035
# minmax normal, with depth 3 move takes time:  0.4891011714935303
# minmax zero, with depth 3 move takes time:  0.052420854568481445
# minmax normal, with depth 3 move takes time:  0.38832902908325195
# minmax zero, with depth 3 move takes time:  0.03609919548034668
# minmax normal, with depth 3 move takes time:  0.7298758029937744
# minmax zero, with depth 3 move takes time:  0.04915809631347656
# minmax normal, with depth 3 move takes time:  1.8216509819030762
# minmax zero, with depth 3 move takes time:  0.05691885948181152
# minmax normal, with depth 3 move takes time:  1.275434970855713
# minmax zero, with depth 3 move takes time:  0.05768704414367676
# minmax normal, with depth 3 move takes time:  1.0161769390106201
# minmax zero, with depth 3 move takes time:  0.07151222229003906
# minmax normal, with depth 3 move takes time:  1.4130120277404785
# minmax zero, with depth 3 move takes time:  0.07899808883666992
# minmax normal, with depth 3 move takes time:  1.69032883644104
# minmax zero, with depth 3 move takes time:  0.08467388153076172
# minmax normal, with depth 3 move takes time:  0.9227490425109863
# minmax zero, with depth 3 move takes time:  0.061810970306396484
# minmax normal, with depth 3 move takes time:  1.0286810398101807
# minmax zero, with depth 3 move takes time:  0.09899377822875977
# minmax normal, with depth 3 move takes time:  0.889517068862915
# minmax zero, with depth 3 move takes time:  0.06989288330078125
# minmax normal, with depth 3 move takes time:  0.9216489791870117
# minmax zero, with depth 3 move takes time:  0.04625892639160156
# minmax normal, with depth 3 move takes time:  0.8269121646881104
# minmax zero, with depth 3 move takes time:  0.044569969177246094
# minmax normal, with depth 3 move takes time:  0.696465015411377
# minmax zero, with depth 3 move takes time:  0.04575705528259277
# minmax normal, with depth 3 move takes time:  1.297044038772583
# minmax zero, with depth 3 move takes time:  0.04412508010864258
# minmax normal, with depth 3 move takes time:  0.9050929546356201
# minmax zero, with depth 3 move takes time:  0.08255314826965332
# minmax normal, with depth 3 move takes time:  0.8823318481445312
# minmax zero, with depth 3 move takes time:  0.0754690170288086
# minmax normal, with depth 3 move takes time:  1.456479787826538
# minmax zero, with depth 3 move takes time:  0.06047987937927246
# minmax normal, with depth 3 move takes time:  2.4603819847106934
# minmax zero, with depth 3 move takes time:  0.04660296440124512
# minmax normal, with depth 3 move takes time:  0.793846845626831
# minmax zero, with depth 3 move takes time:  0.06447100639343262
# minmax normal, with depth 3 move takes time:  0.5751438140869141
# minmax zero, with depth 3 move takes time:  0.05179405212402344
# minmax normal, with depth 3 move takes time:  0.8450791835784912
# minmax zero, with depth 3 move takes time:  0.03843402862548828
# minmax normal, with depth 3 move takes time:  0.85489821434021
# minmax zero, with depth 3 move takes time:  0.04835700988769531
# minmax normal, with depth 3 move takes time:  0.796658992767334
# minmax zero, with depth 3 move takes time:  0.025391101837158203
# minmax normal, with depth 3 move takes time:  0.9792940616607666
# minmax zero, with depth 3 move takes time:  0.040197134017944336
# minmax normal, with depth 3 move takes time:  0.48627495765686035
# minmax zero, with depth 3 move takes time:  0.03462386131286621
# minmax normal, with depth 3 move takes time:  0.7187950611114502
# minmax zero, with depth 3 move takes time:  0.04509902000427246
# minmax normal, with depth 3 move takes time:  0.7117888927459717
# minmax zero, with depth 3 move takes time:  0.035273075103759766
# minmax normal, with depth 3 move takes time:  0.6120331287384033
# minmax zero, with depth 3 move takes time:  0.02708911895751953
# minmax normal, with depth 3 move takes time:  0.6705160140991211
# minmax zero, with depth 3 move takes time:  0.030119895935058594
# minmax normal, with depth 3 move takes time:  0.73573899269104
# minmax zero, with depth 3 move takes time:  0.027140140533447266
# minmax normal, with depth 3 move takes time:  0.5162200927734375
# minmax zero, with depth 3 move takes time:  0.0244140625
# minmax normal, with depth 3 move takes time:  0.17799901962280273
# minmax zero, with depth 3 move takes time:  0.019568920135498047
# minmax normal, with depth 3 move takes time:  0.07433104515075684
# minmax zero, with depth 3 move takes time:  0.015597105026245117
# minmax normal, with depth 3 move takes time:  0.015919208526611328
# minmax zero, with depth 3 move takes time:  0.004116058349609375
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 3 move takes time:  0.040045976638793945
# minmax normal, with depth 3 move takes time:  0.15653610229492188
# minmax zero, with depth 3 move takes time:  0.05444502830505371
# minmax normal, with depth 3 move takes time:  0.4175889492034912
# minmax zero, with depth 3 move takes time:  0.07076001167297363
# minmax normal, with depth 3 move takes time:  0.5144479274749756
# minmax zero, with depth 3 move takes time:  0.06798195838928223
# minmax normal, with depth 3 move takes time:  0.3617081642150879
# minmax zero, with depth 3 move takes time:  0.052787065505981445
# minmax normal, with depth 3 move takes time:  0.4608128070831299
# minmax zero, with depth 3 move takes time:  0.09377193450927734
# minmax normal, with depth 3 move takes time:  1.1396830081939697
# minmax zero, with depth 3 move takes time:  0.08826184272766113
# minmax normal, with depth 3 move takes time:  0.9512100219726562
# minmax zero, with depth 3 move takes time:  0.11576986312866211
# minmax normal, with depth 3 move takes time:  0.5996308326721191
# minmax zero, with depth 3 move takes time:  0.09281587600708008
# minmax normal, with depth 3 move takes time:  1.7768809795379639
# minmax zero, with depth 3 move takes time:  0.09814715385437012
# minmax normal, with depth 3 move takes time:  1.814389944076538
# minmax zero, with depth 3 move takes time:  0.0968160629272461
# minmax normal, with depth 3 move takes time:  1.044802188873291
# minmax zero, with depth 3 move takes time:  0.11793804168701172
# minmax normal, with depth 3 move takes time:  1.6336729526519775
# minmax zero, with depth 3 move takes time:  0.12788605690002441
# minmax normal, with depth 3 move takes time:  2.0688421726226807
# minmax zero, with depth 3 move takes time:  0.1435708999633789
# minmax normal, with depth 3 move takes time:  1.9601819515228271
# minmax zero, with depth 3 move takes time:  0.1054079532623291
# minmax normal, with depth 3 move takes time:  3.417479991912842
# minmax zero, with depth 3 move takes time:  0.08681893348693848
# minmax normal, with depth 3 move takes time:  1.8814480304718018
# minmax zero, with depth 3 move takes time:  0.10277080535888672
# minmax normal, with depth 3 move takes time:  1.5353028774261475
# minmax zero, with depth 3 move takes time:  0.07580089569091797
# minmax normal, with depth 3 move takes time:  1.0560481548309326
# minmax zero, with depth 3 move takes time:  0.06839799880981445
# minmax normal, with depth 3 move takes time:  0.6947479248046875
# minmax zero, with depth 3 move takes time:  0.08916211128234863
# minmax normal, with depth 3 move takes time:  0.6916601657867432
# minmax zero, with depth 3 move takes time:  0.11877202987670898
# minmax normal, with depth 3 move takes time:  0.663532018661499
# minmax zero, with depth 3 move takes time:  0.07430005073547363
# minmax normal, with depth 3 move takes time:  1.2793669700622559
# minmax zero, with depth 3 move takes time:  0.042170047760009766
# minmax normal, with depth 3 move takes time:  1.015052080154419
# minmax zero, with depth 3 move takes time:  0.0669100284576416
# minmax normal, with depth 3 move takes time:  1.000072956085205
# minmax zero, with depth 3 move takes time:  0.03921699523925781
# minmax normal, with depth 3 move takes time:  0.8786919116973877
# minmax zero, with depth 3 move takes time:  0.03757905960083008
# minmax normal, with depth 3 move takes time:  1.5125279426574707
# minmax zero, with depth 3 move takes time:  0.02800893783569336
# minmax normal, with depth 3 move takes time:  0.8730390071868896
# minmax zero, with depth 3 move takes time:  0.026818037033081055
# minmax normal, with depth 3 move takes time:  0.8465681076049805
# minmax zero, with depth 3 move takes time:  0.033689022064208984
# minmax normal, with depth 3 move takes time:  0.5328769683837891
# minmax zero, with depth 3 move takes time:  0.03389406204223633
# minmax normal, with depth 3 move takes time:  0.522913932800293
# minmax zero, with depth 3 move takes time:  0.06762504577636719
# minmax normal, with depth 3 move takes time:  1.2035748958587646
# minmax zero, with depth 3 move takes time:  0.03365302085876465
# minmax normal, with depth 3 move takes time:  1.5825519561767578
# minmax zero, with depth 3 move takes time:  0.07596111297607422
# minmax normal, with depth 3 move takes time:  1.277184009552002
# minmax zero, with depth 3 move takes time:  0.06406283378601074
# minmax normal, with depth 3 move takes time:  1.5612311363220215
# minmax zero, with depth 3 move takes time:  0.08395886421203613
# minmax normal, with depth 3 move takes time:  0.8089330196380615
# minmax zero, with depth 3 move takes time:  0.03944087028503418
# minmax normal, with depth 3 move takes time:  0.756213903427124
# minmax zero, with depth 3 move takes time:  0.019626140594482422
# minmax normal, with depth 3 move takes time:  0.4014861583709717
# minmax zero, with depth 3 move takes time:  0.03244805335998535
# minmax normal, with depth 3 move takes time:  0.20927906036376953
# minmax zero, with depth 3 move takes time:  0.013872861862182617
# minmax normal, with depth 3 move takes time:  0.19928503036499023
# minmax zero, with depth 3 move takes time:  0.011519193649291992
# minmax normal, with depth 3 move takes time:  0.08229303359985352
# minmax zero, with depth 3 move takes time:  0.0061321258544921875
# minmax normal, with depth 3 move takes time:  0.05213594436645508
# minmax zero, with depth 3 move takes time:  0.007323026657104492
# minmax normal, with depth 3 move takes time:  0.03872108459472656
# minmax zero, with depth 3 move takes time:  0.008911848068237305
# minmax normal, with depth 3 move takes time:  0.003777027130126953
# minmax zero, with depth 3 move takes time:  0.0044629573822021484
#
#
#
#
#  minmax zero win!!
#
#
#
#
# In the previous  20  rounds, zero win ratio is:  0.45
# On average, for minmax normal with depth 3 , each move takes time:  1.18610784333 max time elapsed: 4.06974887848
# On average, for minmax zero with depth 3 , each move takes time:  0.0720842040633 max time elapsed: 0.233844041824

# %%
player = MCTS(c=10, dep_lim=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-a76ff3139747> in <module>()
# ----> 1 player = MCTS(c=10, dep_lim=3)
#
# NameError: name 'MCTS' is not defined

# %%
game = Ataxx()

# %%
# %lprun -f player.further_init player.get_next_move(t_lim=3)

# %%
player.tester(mm_dep=3, BOTH=True, mode=1, times=10, dep_lim=2, rollout_times=200, verbose=False, t_lim=5)
# Out:
# mm_dep is:  3
# ####               ####
# #### start testing ####
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-fc903495e51a> in <module>()
# ----> 1 player.tester(mm_dep=3, BOTH=True, mode=1, times=10, dep_lim=2, rollout_times=200, verbose=False, t_lim=5)
#
# <ipython-input-56-b235743faec2> in tester(self, mm_dep, Q, P, BOTH, mode, times, dep_lim, rollout_times, verbose, t_lim)
#     329             out['P'] = p_ratio
#     330         if BOTH: # multiple customizations for this one
# --> 331             both_ratio = self.testing_against_min_max(                rounds=int(times), left_space=45, mm_dep=mm_dep, c=self._c, dep_lim=dep_lim, rollout_times=rollout_times, t_lim=t_lim, verbose=verbose)
#     332             print("\n\n\n                        win ratio of both is {} \n\n\n\n\n".format(both_ratio))
#     333             out['BOTH'] = both_ratio
#
# <ipython-input-56-b235743faec2> in testing_against_min_max(self, rounds, left_space, mm_dep, c, dep_lim, rollout_times, t_lim, verbose)
#     273                     tmp_s = time.time()
#     274                 if self._turn == my_turn:
# --> 275                     best_move = self.get_next_move(q_best=True, rollout_times=rollout_times, t_lim=t_lim)
#     276                     if verbose:
#     277                         print("self turn", my_turn)
#
# <ipython-input-56-b235743faec2> in get_next_move(self, q_best, rollout_times, t_lim)
#      64         global policy_list
#      65         # do mcts
# ---> 66         self.rollout(rollout_times, t_lim)
#      67
#      68         if not q_best:
#
# <ipython-input-56-b235743faec2> in rollout(self, rollout_times, t_lim, t_min)
#     211                     # expand the node only when it has never been expanded
#     212                     if tmp_node._is_expanded == False:
# --> 213                         self.expand(tmp_node, tmp_game, tmp_turn)
#     214
#     215                     # check if is leaf node, if so, update the whole tree
#
# <ipython-input-56-b235743faec2> in expand(self, node, game, turn)
#     167             new_node = TreeNode(node, p=node._children[move])
#     168             game.move_to(turn,  move[0], move[1])
# --> 169             self.further_init(new_node, game, -turn, move, get_p_array=False)
#     170             node._children[move] = new_node
#     171             # prepare to calculate p for new_node only if it has children
#
# <ipython-input-56-b235743faec2> in further_init(self, node, game, turn, prev_move, get_p_array)
#     110         node._prev_move = prev_move # tell which move led the node here
#     111         # preparing all children
# --> 112         new_moves, node._corr_dict, node._children, node._action_mask                                 = game.get_moves(turn, return_node_info=True)
#     113         # if meet end of the game, generate manual q
#     114         if node._children == {}:
#
# <ipython-input-98-abc65a526e75> in get_moves(self, turn, return_node_info)
#     138                 has_duplicate_move = False      # move within the radius of one of another friendly piece is called
#     139                 for new_r, new_c, dr, dc in self.is_valid(turn, (r, c), True): # duplicate move
# --> 140                     if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
#     141                         if abs(dr) <= 1 and abs(dc) <=1:
#     142                             if has_duplicate_move:
#
# KeyboardInterrupt:
