# %%
# %load_ext line_profiler
import line_profiler

# %%
import os 
import importlib
import sys
import tensorflow as tf
import itertools
import numpy as np
import numba as nb
from math import sqrt, log, exp
from numpy import unravel_index
from random import choice, random, sample
np.random.seed(1337)  # for reproducibility
from keras.models import Sequential, Model, load_model
import keras.backend as K
import matplotlib.pyplot as plt
K.set_image_dim_ordering('th')
import time
# Out:
# Using TensorFlow backend.

# %%
class Ataxx:
    def __init__(self, board=None):
        if board is None:                  # if there is no initialization given
            self.data = np.zeros((7, 7), dtype=np.int8)   # then generate a board with starting init, and black(-1) takes first turn
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
            
    def reset(self, board=None):
        if board is None:
            self.data = np.zeros((7, 7), dtype=np.int8)
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
        
    def get_feature_map(self, turn, move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge
        
        # edge
        for j in range(9):
            for k in range(9):
                if j == 0 or j == 8 or k == 0 or k == 8:
                    out[0, j, k] = 1
         
        # my pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == turn:
                        out[1, j, k] = 1
        
        # op pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == -turn:
                        out[2, j, k] = 1
         
        # last move
        if not move is None:               
            out[3, move[0][0]+1, move[0][1]+1] = 1
            out[4, move[1][0]+1, move[1][1]+1] = 1
            
        # whose first
        if turn == -1:
            for j in range(9):
                for k in range(9):
                    out[5, j, k] = 1
        return np.array(out)
    
    def plot(self, is_next_move=False, turn=None):                        # plot the board
        image = self.data.copy()
        if is_next_move:
            if turn not in [-1, 1]:
                raise ValueError("Turn must be -1 or 1, or Must input a turn for next moves")
            else:
                next_moves = self.get_moves(turn)
                if len(next_moves) == 0:
                    raise ValueError("Game is over already")
                next_pos = list(zip(*next_moves))[1]
                for pos in next_pos:
                    image[pos] = turn / 2
        plt.imshow(image, cmap='gray')
        plt.xticks(range(7), range(7))
        plt.yticks(range(7), range(7))
        plt.show()
        
    def get_greedy_move(self, turn, moves=None):
        best_score = -50
        # get all possible moves if not provided
        if moves is None:
            moves, corr_dict = self.get_moves(turn)
            for item in corr_dict:
                moves.append(item)
        
        if len(moves) == 0:
            raise ValueError('No Possible Moves')
        
        best_moves = []
        # calculate greedy move
        for (x0, y0), (x1, y1) in moves:
            tmp_score = 0
            if abs(x0-x1) <= 1 and abs(y0-y1) <= 1:
                tmp_score += 1
            for dr in range(-1, 2):
                for dc in range(-1, 2):
                    try:
                        if x1+dr >= 0 and y1+dc >= 0:
                            tmp_score += self.data[x1+dr, y1+dc] == -turn
                    except:
                        pass
            if tmp_score > best_score:
                best_moves = [((x0, y0), (x1, y1))]
                best_score = tmp_score
            elif tmp_score == best_score:
                best_moves.append(((x0, y0), (x1, y1)))
        return choice(best_moves)
                
    def is_valid(self, turn, pos, get_pos=False):
        r = pos[0]
        c = pos[1]
        if self.data[r, c] != 0:
            if not get_pos:
                return False
            else:
                return
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if not get_pos:
                            return True
                        else:
                            yield new_r, new_c, dr, dc
            if not get_pos:
                return False
        
    def get_moves(self, turn):
        action_mask = np.zeros(792, dtype=np.int8)
        next_moves = []
        corr_dict = {}
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(turn, (r, c), True): # duplicate move
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if abs(dr) <= 1 and abs(dc) <=1:
                            if has_duplicate_move: 
                                cur_move = ((new_r, new_c), (r, c))
                                corr_dict[cur_move] = dup_move
                            elif self.data[new_r, new_c] == turn:
                                dup_move = ((new_r, new_c), (r, c))
                                next_moves.append(dup_move) 
                                has_duplicate_move = True
                        elif self.data[new_r, new_c] == turn:
                            cur_move = ((new_r, new_c), (r, c))
                            next_moves.append(cur_move) 
                        else:
                            continue

        return next_moves, corr_dict
        
    def move_to(self, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]
        
        if not self.is_valid(turn, pos1):
            raise ValueError("This move: " + str((pos0, pos1)) + " of turn: " + str(turn) + " is invalid") 
        elif self.data[x0, y0] != turn:
            raise ValueError("The starting position is not your piece")
        else:
            self.data[x1, y1] = turn
            if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
                self.data[x0, y0] = 0

            for dr in range(-1, 2):                  # infection mode!!!!
                for dc in range(-1, 2):
                    if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                        if self.data[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                            self.data[x1+dr, y1+dc] = turn
    
    def evaluate(self, turn, this_turn, max_score=1, min_score=0.001):
        turn_no=0
        op_no=0
        for r in range(7):
            for c in range(7):
                if self.data[r, c] == turn:
                    turn_no += 1
                elif self.data[r, c] == -turn:
                    op_no += 1
        if len(self.get_moves(this_turn)[0]) == 0:# if one of them can no longer move, count and end
            if turn_no > op_no:
                return max_score
            else:
                return -max_score
        else:
            value = turn_no - op_no
        return value * min_score
    
    @staticmethod    
    def get_manual_q(turn, board):
        '''consider linear growth of win prob with regard to n_diff
        when diff >= 10, the slope grow a bit
        when diff >= 35, consider win prob close to 1 or -1
        ''' 
        turn_no = 0
        op_no = 0
        max1=0.9
        max2=0.95
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        diff = turn_no - op_no
        if abs(diff) > 30:
            return diff / abs(diff)
        else:
            return diff / 30
        
        # ignore the rest for now
        sign = diff
        diff = abs(diff)
        if diff < 35:
            diff = (diff / 35) ** 2 * max1
        else:
            diff = max2

        if sign < 0:
            return -diff
        else:
            return diff

# %%
class PolicyValueNetwork():
    def __init__(self):
        self._sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=24))
        K.set_session(self._sess)
        
        self._model = load_model('AtaxxZero.h5')
        print("successfully loaded two models")
           
    def predict(self, feature_map, action_mask):        
        return self._sess.run(self._model.outputs, feed_dict={self._model.inputs[0]: feature_map.reshape(-1, 6, 9, 9), \
                                self._model.inputs[1]: action_mask.reshape(-1, 792), K.learning_phase(): 0})

# %%
'''These methods are for normal Min max'''
class MinMaxNormal():
    def __init__(self):
        return
    
    @staticmethod
    def evaluate(board, turn):
        turn_no = 0
        op_no = 0
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        return (turn_no - op_no)

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return False
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                        return True
            return False 

    def next_move(self, board, turn):
        next_moves = []
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                if self.is_valid(board, turn, (r, c)): # duplicate move
                    for dr in range(-2, 3):
                        for dc in range(-2, 3):
                            new_r = r+dr
                            new_c = c+dc
                            if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                                if abs(dr) <= 1 and abs(dc) <=1:
                                    if board[new_r, new_c] == turn and not has_duplicate_move:
                                        dup_move = ((new_r, new_c), (r, c))
                                        has_duplicate_move = True
                                        yield dup_move
                                elif board[new_r, new_c] == turn:
                                    cur_move = ((new_r, new_c), (r, c))
                                    yield cur_move
                                else:
                                    continue

    def has_next_move(self, board, turn):
        try:
            next(self.next_move(board, turn))
            return True
        except StopIteration:
            return False

    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board

    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
        else:
            best_move = ((0, 0), (0, 0))

        if depth == 0 or not self.has_next_move(board, turn): # start to do pruning and selecting once the recursion reaches the end
            result = self.evaluate(board, target_turn)
            return result, None
        else:
            if is_max:
                alpha = -100
            else:
                beta = 100

            for move in self.next_move(board, turn):
                result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False)
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == alpha and is_root:
                        best_moves.append(move)
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == beta and is_root:
                        best_moves.append(move)
            if is_max:
                if is_root:
                    return alpha, choice(best_moves)
                else:
                    return alpha, best_move
            else:
                if is_root:
                    return beta, choice(best_moves)
                else:
                    return beta, best_move

# %%
class MinMaxZero():
    def __init__(self, p_thresh, c_thresh):
        self._evaluator = PolicyValueNetwork()
        self._policy_dict = self.get_policy_dict()
        self._p_thresh = p_thresh
        self._c_thresh = c_thresh
        
    @staticmethod
    def get_policy_dict():
        '''Get the relation between policy no. and policy'''
        index=0
        policy_dict = {}
        for r in range(7):
            for c in range(7):
                for dr in range(-2, 3):
                    for dc in range(-2, 3):
                        new_r = r + dr
                        new_c = c + dc
                        if (dr != 0 or dc != 0) and (new_r < 7 and new_r >= 0) and (new_c < 7 and new_c >= 0):
                            policy_dict[((r, c), (new_r, new_c))] = index
                            index += 1
        return policy_dict

    @staticmethod
    def get_feature_map(board, turn, pre_move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge

        # edge
        out[0, 0, :] = 1
        out[0, 8, :] = 1
        out[0, :, 0] = 1
        out[0, :, 8] = 1

        # my pieces
        out[1, 1:8, 1:8] = (board == turn)

        # op pieces
        out[2, 1:8, 1:8] = (board == -turn)
        
        # last move
        if not pre_move is None:               
            out[3, pre_move[0][0]+1, pre_move[0][1]+1] = 1
            out[4, pre_move[1][0]+1, pre_move[1][1]+1] = 1

        # whose first
        if turn == -1:
            out[5, ...] = 1
        return out
    
    def evaluate(self, feature_map, action_mask, turn, target_turn):
        result = self._evaluator.predict(feature_map, action_mask)
        p = result[0][0]
        if turn == target_turn:
            q = result[1][0]
        else:
            q = -result[1][0]
        return p, q

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return
        else:
            turn_board = board == turn
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    try:
                        assert new_r >= 0 and new_c >= 0 and turn_board[new_r, new_c]
                        yield new_r, new_c, dr, dc
                    except:
                        pass
    
    def get_moves(self, board, turn):
        next_moves = []
        dup_moves = []
        action_mask = np.zeros(792, np.int8)
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(board, turn, (r, c)): # duplicate move
                    cur_move = ((new_r, new_c), (r, c))
                    # update action mask
                    action_mask[self._policy_dict[cur_move]] = 1
                    if abs(dr) <= 1 and abs(dc) <=1:
                        if not has_duplicate_move:
                            has_duplicate_move = True
                            next_moves.append(cur_move)
                    else:
                        next_moves.append(cur_move)

        return next_moves, action_mask
    
    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board
    
    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True, \
                pre_move=None, t_lim=1):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
            self._start = time.time()
        else:
            best_move = ((0, 0), (0, 0))
        
        # get next moves
        next_moves, action_mask = self.get_moves(board, turn)
        # stop searching if the game is over
        if len(next_moves) == 0:
            diff = (board == target_turn).sum() - (board == -target_turn).sum()
            if diff > 0:
                return 1, None
            elif diff < 0:
                return -1, None
            else:
                op_next_moves, _ = self.get_moves(board, -target_turn)
                if len(op_next_moves) > 0:
                    return -1, None
                else:
                    return 1, None
        else: # otherwise calculate p and q and do the NN pruned minmax searching
            feature_map = self.get_feature_map(board, turn, pre_move)
            p, q = self.evaluate(feature_map, action_mask, turn, target_turn)
            
        if depth == 0: # once the recursion reaches the end, return the leaf node value
            return q, None
        else:
            # generate move corresponding p list
            move_prob = []
            all_prob = 0.0
            for move in next_moves:
                prob = p[self._policy_dict[move]]
                move_prob.append((move, prob))
                all_prob += prob
            move_prob = sorted(move_prob, key=lambda x: x[1], reverse=True)

            if is_max:
                alpha = -100
            else:
                beta = 100

            sum_prob = 0.0
            counter = 0
            counter_thresh = len(move_prob) / self._c_thresh
            prob_thresh = all_prob * self._p_thresh
            # display_move_prob(move_prob)
            for move, prob in move_prob:
                sum_prob += prob
                counter += 1
                # do searching
                result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False, move, t_lim)
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == alpha and is_root:
                        best_moves.append(move)
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == beta and is_root:
                        best_moves.append(move)

                if (sum_prob >= prob_thresh and counter >= counter_thresh) or time.time() - self._start >= t_lim:
                    break

            if is_max:
                if is_root:
                    return alpha, choice(best_moves)
                else:
                    return alpha, best_move
            else:
                if is_root:
                    return beta, choice(best_moves)
                else:
                    return beta, best_move

# %%
minmax_normal = MinMaxZero(1, 100)
minmax_zero = MinMaxZero(0.99, 100)
N = 20
N_D = 2
Z_D = 2
zero_win = 0
time_zero = []
time_normal = []
for _ in range(N):
    steps = 0
    a = Ataxx()
    turn = -1
    zero_turn = choice([-1, 1])
    print("zero chose color", zero_turn)
    best_move = None
    while True:
        steps += 1
        #a.plot()
        if turn != zero_turn:
            s = time.time()
            #_, best_move = minmax_normal.min_max(a.data, turn, turn, depth=N_D)
            _, best_move = minmax_normal.min_max(a.data, turn, turn, depth=N_D, pre_move=best_move, t_lim=1)
            span = time.time() - s
            print("minmax normal, with depth", N_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_normal.append(span)
        else:
            s = time.time()
            _, best_move = minmax_zero.min_max(a.data, turn, turn, depth=Z_D, pre_move=best_move, t_lim=1)
            span = time.time() - s
            print("minmax zero, with depth", Z_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_zero.append(span)
        a.move_to(turn, best_move[0], best_move[1])
        turn = -turn
        result = a.evaluate(zero_turn, turn)
        if result == 1:
            print("\n\n\n\n minmax zero win!! \n\n\n\n")
            zero_win += 1
            break
        elif result == -1:
            print("\n\n\n\n minmax normal win!! \n\n\n\n")
            break
print("In the previous ", N, " rounds, zero win ratio is: ", float(zero_win) / float(N))
time_zero = np.array(time_zero)
time_normal = np.array(time_normal)
print("On average, for minmax normal with depth", N_D, \
      ", each move takes time: ", time_normal.mean(),\
      "max time elapsed:", time_normal.max())
print("On average, for minmax zero with depth", Z_D, \
      ", each move takes time: ", time_zero.mean(),\
      "max time elapsed:", time_zero.max())
# Out:
# successfully loaded two models
# successfully loaded two models
# zero chose color -1
# minmax zero, with depth 2 move takes time:  1.178128957748413
# minmax normal, with depth 2 move takes time:  1.1354339122772217
# minmax zero, with depth 2 move takes time:  0.09509897232055664
# minmax normal, with depth 2 move takes time:  0.476917028427124
# minmax zero, with depth 2 move takes time:  0.30683302879333496
# minmax normal, with depth 2 move takes time:  0.7608990669250488
# minmax zero, with depth 2 move takes time:  0.32395505905151367
# minmax normal, with depth 2 move takes time:  1.0008909702301025
# minmax zero, with depth 2 move takes time:  0.5186049938201904
# minmax normal, with depth 2 move takes time:  1.000458002090454
# minmax zero, with depth 2 move takes time:  0.4936678409576416
# minmax normal, with depth 2 move takes time:  0.5368058681488037
# minmax zero, with depth 2 move takes time:  0.12239384651184082
# minmax normal, with depth 2 move takes time:  0.9318840503692627
# minmax zero, with depth 2 move takes time:  0.5120410919189453
# minmax normal, with depth 2 move takes time:  0.7709600925445557
# minmax zero, with depth 2 move takes time:  0.7656610012054443
# minmax normal, with depth 2 move takes time:  1.0007989406585693
# minmax zero, with depth 2 move takes time:  0.4922630786895752
# minmax normal, with depth 2 move takes time:  1.001904010772705
# minmax zero, with depth 2 move takes time:  0.7651360034942627
# minmax normal, with depth 2 move takes time:  1.000885009765625
# minmax zero, with depth 2 move takes time:  0.3687751293182373
# minmax normal, with depth 2 move takes time:  0.53627610206604
# minmax zero, with depth 2 move takes time:  0.15087604522705078
# minmax normal, with depth 2 move takes time:  0.6497848033905029
# minmax zero, with depth 2 move takes time:  0.33142995834350586
# minmax normal, with depth 2 move takes time:  0.42623305320739746
# minmax zero, with depth 2 move takes time:  0.12649011611938477
# minmax normal, with depth 2 move takes time:  0.4319169521331787
# minmax zero, with depth 2 move takes time:  0.42452406883239746
# minmax normal, with depth 2 move takes time:  0.4643430709838867
# minmax zero, with depth 2 move takes time:  0.1548750400543213
# minmax normal, with depth 2 move takes time:  0.4434471130371094
# minmax zero, with depth 2 move takes time:  0.2118360996246338
# minmax normal, with depth 2 move takes time:  0.7858150005340576
# minmax zero, with depth 2 move takes time:  0.18570709228515625
# minmax normal, with depth 2 move takes time:  0.469027042388916
# minmax zero, with depth 2 move takes time:  0.07067489624023438
# minmax normal, with depth 2 move takes time:  0.4846930503845215
# minmax zero, with depth 2 move takes time:  0.2090449333190918
# minmax normal, with depth 2 move takes time:  0.38346004486083984
# minmax zero, with depth 2 move takes time:  0.09047389030456543
# minmax normal, with depth 2 move takes time:  0.44490480422973633
# minmax zero, with depth 2 move takes time:  0.15268898010253906
# minmax normal, with depth 2 move takes time:  0.6140391826629639
# minmax zero, with depth 2 move takes time:  0.22434496879577637
# minmax normal, with depth 2 move takes time:  0.37192487716674805
# minmax zero, with depth 2 move takes time:  0.47042107582092285
# minmax normal, with depth 2 move takes time:  0.7768850326538086
# minmax zero, with depth 2 move takes time:  0.16108012199401855
# minmax normal, with depth 2 move takes time:  0.5399448871612549
# minmax zero, with depth 2 move takes time:  0.20868206024169922
# minmax normal, with depth 2 move takes time:  0.4626798629760742
# minmax zero, with depth 2 move takes time:  0.21352791786193848
# minmax normal, with depth 2 move takes time:  0.39319515228271484
# minmax zero, with depth 2 move takes time:  0.10073494911193848
# minmax normal, with depth 2 move takes time:  0.3804471492767334
# minmax zero, with depth 2 move takes time:  0.15246295928955078
# minmax normal, with depth 2 move takes time:  0.4469339847564697
# minmax zero, with depth 2 move takes time:  0.41042208671569824
# minmax normal, with depth 2 move takes time:  0.38321900367736816
# minmax zero, with depth 2 move takes time:  0.12698888778686523
# minmax normal, with depth 2 move takes time:  0.38399600982666016
# minmax zero, with depth 2 move takes time:  0.1648719310760498
# minmax normal, with depth 2 move takes time:  0.285290002822876
# minmax zero, with depth 2 move takes time:  0.19306302070617676
# minmax normal, with depth 2 move takes time:  0.4061620235443115
# minmax zero, with depth 2 move takes time:  0.11015987396240234
# minmax normal, with depth 2 move takes time:  0.276979923248291
# minmax zero, with depth 2 move takes time:  0.04958987236022949
# minmax normal, with depth 2 move takes time:  0.2657129764556885
# minmax zero, with depth 2 move takes time:  0.14915990829467773
# minmax normal, with depth 2 move takes time:  0.2528688907623291
# minmax zero, with depth 2 move takes time:  0.1351919174194336
# minmax normal, with depth 2 move takes time:  0.19818115234375
# minmax zero, with depth 2 move takes time:  0.0970458984375
# minmax normal, with depth 2 move takes time:  0.15227699279785156
# minmax zero, with depth 2 move takes time:  0.06769323348999023
# minmax normal, with depth 2 move takes time:  0.08226490020751953
# minmax zero, with depth 2 move takes time:  0.05008101463317871
# minmax normal, with depth 2 move takes time:  0.13068103790283203
# minmax zero, with depth 2 move takes time:  0.039140939712524414
# minmax normal, with depth 2 move takes time:  0.08237695693969727
# minmax zero, with depth 2 move takes time:  0.04068279266357422
# minmax normal, with depth 2 move takes time:  0.13817405700683594
# minmax zero, with depth 2 move takes time:  0.08699202537536621
# minmax normal, with depth 2 move takes time:  0.05573415756225586
# minmax zero, with depth 2 move takes time:  0.028168916702270508
# minmax normal, with depth 2 move takes time:  0.023081064224243164
# minmax zero, with depth 2 move takes time:  0.03422999382019043
# minmax normal, with depth 2 move takes time:  0.0024530887603759766
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 2 move takes time:  0.038887977600097656
# minmax normal, with depth 2 move takes time:  0.24108481407165527
# minmax zero, with depth 2 move takes time:  0.05284690856933594
# minmax normal, with depth 2 move takes time:  0.5697219371795654
# minmax zero, with depth 2 move takes time:  0.2355060577392578
# minmax normal, with depth 2 move takes time:  0.9630999565124512
# minmax zero, with depth 2 move takes time:  0.5277810096740723
# minmax normal, with depth 2 move takes time:  0.695605993270874
# minmax zero, with depth 2 move takes time:  0.9634010791778564
# minmax normal, with depth 2 move takes time:  0.910412073135376
# minmax zero, with depth 2 move takes time:  0.49564313888549805
# minmax normal, with depth 2 move takes time:  1.0045580863952637
# minmax zero, with depth 2 move takes time:  1.0010051727294922
# minmax normal, with depth 2 move takes time:  1.0024099349975586
# minmax zero, with depth 2 move takes time:  0.5333430767059326
# minmax normal, with depth 2 move takes time:  1.0017430782318115
# minmax zero, with depth 2 move takes time:  0.3561899662017822
# minmax normal, with depth 2 move takes time:  0.5955450534820557
# minmax zero, with depth 2 move takes time:  0.5355780124664307
# minmax normal, with depth 2 move takes time:  0.5772709846496582
# minmax zero, with depth 2 move takes time:  0.1963798999786377
# minmax normal, with depth 2 move takes time:  0.3876028060913086
# minmax zero, with depth 2 move takes time:  0.7870349884033203
# minmax normal, with depth 2 move takes time:  0.7627661228179932
# minmax zero, with depth 2 move takes time:  0.7646069526672363
# minmax normal, with depth 2 move takes time:  1.0024099349975586
# minmax zero, with depth 2 move takes time:  0.2663238048553467
# minmax normal, with depth 2 move takes time:  0.6833469867706299
# minmax zero, with depth 2 move takes time:  0.11481690406799316
# minmax normal, with depth 2 move takes time:  1.0022919178009033
# minmax zero, with depth 2 move takes time:  0.29991817474365234
# minmax normal, with depth 2 move takes time:  1.006037950515747
# minmax zero, with depth 2 move takes time:  0.08961105346679688
# minmax normal, with depth 2 move takes time:  0.9831562042236328
# minmax zero, with depth 2 move takes time:  0.23415899276733398
# minmax normal, with depth 2 move takes time:  0.5943460464477539
# minmax zero, with depth 2 move takes time:  0.20829200744628906
# minmax normal, with depth 2 move takes time:  1.0010020732879639
# minmax zero, with depth 2 move takes time:  0.4162869453430176
# minmax normal, with depth 2 move takes time:  0.3854329586029053
# minmax zero, with depth 2 move takes time:  0.13565301895141602
# minmax normal, with depth 2 move takes time:  0.47989606857299805
# minmax zero, with depth 2 move takes time:  0.3116419315338135
# minmax normal, with depth 2 move takes time:  0.39496707916259766
# minmax zero, with depth 2 move takes time:  0.37167811393737793
# minmax normal, with depth 2 move takes time:  0.497905969619751
# minmax zero, with depth 2 move takes time:  0.19550800323486328
# minmax normal, with depth 2 move takes time:  0.28815698623657227
# minmax zero, with depth 2 move takes time:  0.3759760856628418
# minmax normal, with depth 2 move takes time:  0.8177211284637451
# minmax zero, with depth 2 move takes time:  0.17029595375061035
# minmax normal, with depth 2 move takes time:  0.5976650714874268
# minmax zero, with depth 2 move takes time:  0.14167284965515137
# minmax normal, with depth 2 move takes time:  0.47668886184692383
# minmax zero, with depth 2 move takes time:  0.1075139045715332
# minmax normal, with depth 2 move takes time:  0.2418830394744873
# minmax zero, with depth 2 move takes time:  0.08799600601196289
# minmax normal, with depth 2 move takes time:  0.30983805656433105
# minmax zero, with depth 2 move takes time:  0.17511487007141113
# minmax normal, with depth 2 move takes time:  0.36962294578552246
# minmax zero, with depth 2 move takes time:  0.0506138801574707
# minmax normal, with depth 2 move takes time:  0.3570108413696289
# minmax zero, with depth 2 move takes time:  0.047840118408203125
# minmax normal, with depth 2 move takes time:  0.1576840877532959
# minmax zero, with depth 2 move takes time:  0.06357598304748535
# minmax normal, with depth 2 move takes time:  0.0642850399017334
# minmax zero, with depth 2 move takes time:  0.029488086700439453
# minmax normal, with depth 2 move takes time:  0.10499715805053711
# minmax zero, with depth 2 move takes time:  0.04287099838256836
# minmax normal, with depth 2 move takes time:  0.0519108772277832
# minmax zero, with depth 2 move takes time:  0.07100796699523926
# minmax normal, with depth 2 move takes time:  0.11030197143554688
# minmax zero, with depth 2 move takes time:  0.024549007415771484
# minmax normal, with depth 2 move takes time:  0.06975412368774414
# minmax zero, with depth 2 move takes time:  0.05582594871520996
# minmax normal, with depth 2 move takes time:  0.07779097557067871
# minmax zero, with depth 2 move takes time:  0.034802913665771484
# minmax normal, with depth 2 move takes time:  0.04653000831604004
# minmax zero, with depth 2 move takes time:  0.02481698989868164
# minmax normal, with depth 2 move takes time:  0.016524076461791992
# minmax zero, with depth 2 move takes time:  0.012325048446655273
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 2 move takes time:  0.03244185447692871
# minmax normal, with depth 2 move takes time:  0.19810986518859863
# minmax zero, with depth 2 move takes time:  0.04603910446166992
# minmax normal, with depth 2 move takes time:  0.4471590518951416
# minmax zero, with depth 2 move takes time:  0.1795809268951416
# minmax normal, with depth 2 move takes time:  0.8302760124206543
# minmax zero, with depth 2 move takes time:  0.4579429626464844
# minmax normal, with depth 2 move takes time:  0.6535439491271973
# minmax zero, with depth 2 move takes time:  0.793159008026123
# minmax normal, with depth 2 move takes time:  0.7281949520111084
# minmax zero, with depth 2 move takes time:  0.2986588478088379
# minmax normal, with depth 2 move takes time:  0.8634979724884033
# minmax zero, with depth 2 move takes time:  0.13179492950439453
# minmax normal, with depth 2 move takes time:  1.0005950927734375
# minmax zero, with depth 2 move takes time:  0.45349812507629395
# minmax normal, with depth 2 move takes time:  0.514185905456543
# minmax zero, with depth 2 move takes time:  0.3616459369659424
# minmax normal, with depth 2 move takes time:  0.6288290023803711
# minmax zero, with depth 2 move takes time:  0.35408997535705566
# minmax normal, with depth 2 move takes time:  0.30809998512268066
# minmax zero, with depth 2 move takes time:  0.20945096015930176
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.22051000595092773
# minmax zero, with depth 2 move takes time:  0.05362415313720703
# minmax normal, with depth 2 move takes time:  0.16270208358764648
# minmax zero, with depth 2 move takes time:  0.15239405632019043
# minmax normal, with depth 2 move takes time:  0.6015360355377197
# minmax zero, with depth 2 move takes time:  0.36658406257629395
# minmax normal, with depth 2 move takes time:  0.6256802082061768
# minmax zero, with depth 2 move takes time:  0.3623390197753906
# minmax normal, with depth 2 move takes time:  0.8047170639038086
# minmax zero, with depth 2 move takes time:  0.5675928592681885
# minmax normal, with depth 2 move takes time:  0.5700070858001709
# minmax zero, with depth 2 move takes time:  0.22318816184997559
# minmax normal, with depth 2 move takes time:  0.2799570560455322
# minmax zero, with depth 2 move takes time:  0.15195989608764648
# minmax normal, with depth 2 move takes time:  0.5980222225189209
# minmax zero, with depth 2 move takes time:  0.3323478698730469
# minmax normal, with depth 2 move takes time:  0.22407007217407227
# minmax zero, with depth 2 move takes time:  0.17753100395202637
# minmax normal, with depth 2 move takes time:  0.6303198337554932
# minmax zero, with depth 2 move takes time:  0.1922152042388916
# minmax normal, with depth 2 move takes time:  0.4798719882965088
# minmax zero, with depth 2 move takes time:  0.130234956741333
# minmax normal, with depth 2 move takes time:  0.6005520820617676
# minmax zero, with depth 2 move takes time:  0.15851783752441406
# minmax normal, with depth 2 move takes time:  0.44463205337524414
# minmax zero, with depth 2 move takes time:  0.18226289749145508
# minmax normal, with depth 2 move takes time:  0.296004056930542
# minmax zero, with depth 2 move takes time:  0.16702008247375488
# minmax normal, with depth 2 move takes time:  0.34133005142211914
# minmax zero, with depth 2 move takes time:  0.2090749740600586
# minmax normal, with depth 2 move takes time:  0.5241489410400391
# minmax zero, with depth 2 move takes time:  0.10135388374328613
# minmax normal, with depth 2 move takes time:  0.39442992210388184
# minmax zero, with depth 2 move takes time:  0.14859414100646973
# minmax normal, with depth 2 move takes time:  0.3926429748535156
# minmax zero, with depth 2 move takes time:  0.127471923828125
# minmax normal, with depth 2 move takes time:  0.4293248653411865
# minmax zero, with depth 2 move takes time:  0.0928199291229248
# minmax normal, with depth 2 move takes time:  0.415755033493042
# minmax zero, with depth 2 move takes time:  0.05981898307800293
# minmax normal, with depth 2 move takes time:  0.29633522033691406
# minmax zero, with depth 2 move takes time:  0.09801387786865234
# minmax normal, with depth 2 move takes time:  0.3181629180908203
# minmax zero, with depth 2 move takes time:  0.07155203819274902
# minmax normal, with depth 2 move takes time:  0.326793909072876
# minmax zero, with depth 2 move takes time:  0.14632487297058105
# minmax normal, with depth 2 move takes time:  0.26407790184020996
# minmax zero, with depth 2 move takes time:  0.11824488639831543
# minmax normal, with depth 2 move takes time:  0.3434481620788574
# minmax zero, with depth 2 move takes time:  0.09109783172607422
# minmax normal, with depth 2 move takes time:  0.3379480838775635
# minmax zero, with depth 2 move takes time:  0.21918892860412598
# minmax normal, with depth 2 move takes time:  0.3145020008087158
# minmax zero, with depth 2 move takes time:  0.2781689167022705
# minmax normal, with depth 2 move takes time:  0.284559965133667
# minmax zero, with depth 2 move takes time:  0.10191607475280762
# minmax normal, with depth 2 move takes time:  0.34850287437438965
# minmax zero, with depth 2 move takes time:  0.28545403480529785
# minmax normal, with depth 2 move takes time:  0.40978002548217773
# minmax zero, with depth 2 move takes time:  0.1500868797302246
# minmax normal, with depth 2 move takes time:  0.3085041046142578
# minmax zero, with depth 2 move takes time:  0.09215617179870605
# minmax normal, with depth 2 move takes time:  0.1785900592803955
# minmax zero, with depth 2 move takes time:  0.055586814880371094
# minmax normal, with depth 2 move takes time:  0.2227020263671875
# minmax zero, with depth 2 move takes time:  0.1430370807647705
# minmax normal, with depth 2 move takes time:  0.1497480869293213
# minmax zero, with depth 2 move takes time:  0.12371110916137695
# minmax normal, with depth 2 move takes time:  0.17339706420898438
# minmax zero, with depth 2 move takes time:  0.10970807075500488
# minmax normal, with depth 2 move takes time:  0.1841588020324707
# minmax zero, with depth 2 move takes time:  0.03779911994934082
# minmax normal, with depth 2 move takes time:  0.1508958339691162
# minmax zero, with depth 2 move takes time:  0.09641289710998535
# minmax normal, with depth 2 move takes time:  0.14382195472717285
# minmax zero, with depth 2 move takes time:  0.047096967697143555
# minmax normal, with depth 2 move takes time:  0.0859518051147461
# minmax zero, with depth 2 move takes time:  0.03550100326538086
# minmax normal, with depth 2 move takes time:  0.04175710678100586
# minmax zero, with depth 2 move takes time:  0.022710800170898438
# minmax normal, with depth 2 move takes time:  0.009567022323608398
# minmax zero, with depth 2 move takes time:  0.004609107971191406
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 2 move takes time:  0.038582801818847656
# minmax normal, with depth 2 move takes time:  0.2223799228668213
# minmax zero, with depth 2 move takes time:  0.04769492149353027
# minmax normal, with depth 2 move takes time:  0.476207971572876
# minmax zero, with depth 2 move takes time:  0.20135498046875
# minmax normal, with depth 2 move takes time:  0.8407158851623535
# minmax zero, with depth 2 move takes time:  0.45697689056396484
# minmax normal, with depth 2 move takes time:  0.6192348003387451
# minmax zero, with depth 2 move takes time:  0.7498610019683838
# minmax normal, with depth 2 move takes time:  0.7387900352478027
# minmax zero, with depth 2 move takes time:  0.28812289237976074
# minmax normal, with depth 2 move takes time:  0.9464259147644043
# minmax zero, with depth 2 move takes time:  0.12859010696411133
# minmax normal, with depth 2 move takes time:  1.002830982208252
# minmax zero, with depth 2 move takes time:  0.43854188919067383
# minmax normal, with depth 2 move takes time:  0.32587289810180664
# minmax zero, with depth 2 move takes time:  0.22466397285461426
# minmax normal, with depth 2 move takes time:  0.6702241897583008
# minmax zero, with depth 2 move takes time:  0.18444108963012695
# minmax normal, with depth 2 move takes time:  0.8459768295288086
# minmax zero, with depth 2 move takes time:  0.2322101593017578
# minmax normal, with depth 2 move takes time:  0.260847806930542
# minmax zero, with depth 2 move takes time:  0.20475411415100098
# minmax normal, with depth 2 move takes time:  0.2806270122528076
# minmax zero, with depth 2 move takes time:  0.1017298698425293
# minmax normal, with depth 2 move takes time:  0.23151516914367676
# minmax zero, with depth 2 move takes time:  0.2740461826324463
# minmax normal, with depth 2 move takes time:  1.0016748905181885
# minmax zero, with depth 2 move takes time:  0.16240501403808594
# minmax normal, with depth 2 move takes time:  0.9758739471435547
# minmax zero, with depth 2 move takes time:  0.27701401710510254
# minmax normal, with depth 2 move takes time:  0.6058549880981445
# minmax zero, with depth 2 move takes time:  0.2688760757446289
# minmax normal, with depth 2 move takes time:  0.3738439083099365
# minmax zero, with depth 2 move takes time:  0.1978468894958496
# minmax normal, with depth 2 move takes time:  0.3192789554595947
# minmax zero, with depth 2 move takes time:  0.19117093086242676
# minmax normal, with depth 2 move takes time:  0.472869873046875
# minmax zero, with depth 2 move takes time:  0.1862320899963379
# minmax normal, with depth 2 move takes time:  0.7621181011199951
# minmax zero, with depth 2 move takes time:  0.16737604141235352
# minmax normal, with depth 2 move takes time:  0.6951820850372314
# minmax zero, with depth 2 move takes time:  0.2661769390106201
# minmax normal, with depth 2 move takes time:  0.4890859127044678
# minmax zero, with depth 2 move takes time:  0.24006319046020508
# minmax normal, with depth 2 move takes time:  0.650468111038208
# minmax zero, with depth 2 move takes time:  0.20113110542297363
# minmax normal, with depth 2 move takes time:  0.8361899852752686
# minmax zero, with depth 2 move takes time:  0.2224140167236328
# minmax normal, with depth 2 move takes time:  0.41062307357788086
# minmax zero, with depth 2 move takes time:  0.27864599227905273
# minmax normal, with depth 2 move takes time:  0.8535840511322021
# minmax zero, with depth 2 move takes time:  0.442288875579834
# minmax normal, with depth 2 move takes time:  0.9498848915100098
# minmax zero, with depth 2 move takes time:  0.291485071182251
# minmax normal, with depth 2 move takes time:  0.6809670925140381
# minmax zero, with depth 2 move takes time:  0.44243502616882324
# minmax normal, with depth 2 move takes time:  0.9607038497924805
# minmax zero, with depth 2 move takes time:  0.4834139347076416
# minmax normal, with depth 2 move takes time:  0.7123918533325195
# minmax zero, with depth 2 move takes time:  0.07533097267150879
# minmax normal, with depth 2 move takes time:  0.5435588359832764
# minmax zero, with depth 2 move takes time:  0.1066279411315918
# minmax normal, with depth 2 move takes time:  0.4610888957977295
# minmax zero, with depth 2 move takes time:  0.28328585624694824
# minmax normal, with depth 2 move takes time:  0.8157351016998291
# minmax zero, with depth 2 move takes time:  0.06847000122070312
# minmax normal, with depth 2 move takes time:  0.673346996307373
# minmax zero, with depth 2 move takes time:  0.22734284400939941
# minmax normal, with depth 2 move takes time:  0.7142560482025146
# minmax zero, with depth 2 move takes time:  0.3565490245819092
# minmax normal, with depth 2 move takes time:  0.9352779388427734
# minmax zero, with depth 2 move takes time:  0.07332205772399902
# minmax normal, with depth 2 move takes time:  0.6292600631713867
# minmax zero, with depth 2 move takes time:  0.4061129093170166
# minmax normal, with depth 2 move takes time:  0.4307520389556885
# minmax zero, with depth 2 move takes time:  0.1474611759185791
# minmax normal, with depth 2 move takes time:  0.8266260623931885
# minmax zero, with depth 2 move takes time:  0.39214181900024414
# minmax normal, with depth 2 move takes time:  0.5855288505554199
# minmax zero, with depth 2 move takes time:  0.37856101989746094
# minmax normal, with depth 2 move takes time:  0.21565699577331543
# minmax zero, with depth 2 move takes time:  0.46851205825805664
# minmax normal, with depth 2 move takes time:  0.4316718578338623
# minmax zero, with depth 2 move takes time:  0.17069292068481445
# minmax normal, with depth 2 move takes time:  0.2435760498046875
# minmax zero, with depth 2 move takes time:  0.08728599548339844
# minmax normal, with depth 2 move takes time:  0.2214338779449463
# minmax zero, with depth 2 move takes time:  0.054366111755371094
# minmax normal, with depth 2 move takes time:  0.21258115768432617
# minmax zero, with depth 2 move takes time:  0.13119220733642578
# minmax normal, with depth 2 move takes time:  0.26750707626342773
# minmax zero, with depth 2 move takes time:  0.0696709156036377
# minmax normal, with depth 2 move takes time:  0.2817502021789551
# minmax zero, with depth 2 move takes time:  0.06939196586608887
# minmax normal, with depth 2 move takes time:  0.08791518211364746
# minmax zero, with depth 2 move takes time:  0.09221100807189941
# minmax normal, with depth 2 move takes time:  0.12260103225708008
# minmax zero, with depth 2 move takes time:  0.07485294342041016
# minmax normal, with depth 2 move takes time:  0.11285591125488281
# minmax zero, with depth 2 move takes time:  0.039568185806274414
# minmax normal, with depth 2 move takes time:  0.01938796043395996
# minmax zero, with depth 2 move takes time:  0.009219169616699219
# minmax normal, with depth 2 move takes time:  0.015323162078857422
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.22071003913879395
# minmax zero, with depth 2 move takes time:  0.06132793426513672
# minmax normal, with depth 2 move takes time:  0.18696904182434082
# minmax zero, with depth 2 move takes time:  0.17839598655700684
# minmax normal, with depth 2 move takes time:  0.6592440605163574
# minmax zero, with depth 2 move takes time:  0.494826078414917
# minmax normal, with depth 2 move takes time:  0.7674798965454102
# minmax zero, with depth 2 move takes time:  0.6294131278991699
# minmax normal, with depth 2 move takes time:  0.9453091621398926
# minmax zero, with depth 2 move takes time:  0.6440029144287109
# minmax normal, with depth 2 move takes time:  0.705733060836792
# minmax zero, with depth 2 move takes time:  0.24819302558898926
# minmax normal, with depth 2 move takes time:  0.29837489128112793
# minmax zero, with depth 2 move takes time:  0.15724587440490723
# minmax normal, with depth 2 move takes time:  0.6387350559234619
# minmax zero, with depth 2 move takes time:  0.3778080940246582
# minmax normal, with depth 2 move takes time:  0.28257203102111816
# minmax zero, with depth 2 move takes time:  0.20170092582702637
# minmax normal, with depth 2 move takes time:  0.6743581295013428
# minmax zero, with depth 2 move takes time:  0.1907949447631836
# minmax normal, with depth 2 move takes time:  0.4992098808288574
# minmax zero, with depth 2 move takes time:  0.23036694526672363
# minmax normal, with depth 2 move takes time:  0.8206899166107178
# minmax zero, with depth 2 move takes time:  0.27600884437561035
# minmax normal, with depth 2 move takes time:  0.6223170757293701
# minmax zero, with depth 2 move takes time:  0.22886991500854492
# minmax normal, with depth 2 move takes time:  0.4466581344604492
# minmax zero, with depth 2 move takes time:  0.2708711624145508
# minmax normal, with depth 2 move takes time:  0.42282581329345703
# minmax zero, with depth 2 move takes time:  0.23267412185668945
# minmax normal, with depth 2 move takes time:  0.605557918548584
# minmax zero, with depth 2 move takes time:  0.11825895309448242
# minmax normal, with depth 2 move takes time:  0.4911329746246338
# minmax zero, with depth 2 move takes time:  0.19296002388000488
# minmax normal, with depth 2 move takes time:  0.566756010055542
# minmax zero, with depth 2 move takes time:  0.1583099365234375
# minmax normal, with depth 2 move takes time:  0.5736639499664307
# minmax zero, with depth 2 move takes time:  0.10988616943359375
# minmax normal, with depth 2 move takes time:  0.5214560031890869
# minmax zero, with depth 2 move takes time:  0.07601809501647949
# minmax normal, with depth 2 move takes time:  0.38515591621398926
# minmax zero, with depth 2 move takes time:  0.13891816139221191
# minmax normal, with depth 2 move takes time:  0.38568782806396484
# minmax zero, with depth 2 move takes time:  0.08400607109069824
# minmax normal, with depth 2 move takes time:  0.41773486137390137
# minmax zero, with depth 2 move takes time:  0.19283485412597656
# minmax normal, with depth 2 move takes time:  0.3458249568939209
# minmax zero, with depth 2 move takes time:  0.14429616928100586
# minmax normal, with depth 2 move takes time:  0.4095170497894287
# minmax zero, with depth 2 move takes time:  0.08456802368164062
# minmax normal, with depth 2 move takes time:  0.38058018684387207
# minmax zero, with depth 2 move takes time:  0.1435539722442627
# minmax normal, with depth 2 move takes time:  0.305095911026001
# minmax zero, with depth 2 move takes time:  0.28512001037597656
# minmax normal, with depth 2 move takes time:  0.3006279468536377
# minmax zero, with depth 2 move takes time:  0.10693979263305664
# minmax normal, with depth 2 move takes time:  0.3433718681335449
# minmax zero, with depth 2 move takes time:  0.2684500217437744
# minmax normal, with depth 2 move takes time:  0.3691139221191406
# minmax zero, with depth 2 move takes time:  0.2207338809967041
# minmax normal, with depth 2 move takes time:  0.4806239604949951
# minmax zero, with depth 2 move takes time:  0.12324881553649902
# minmax normal, with depth 2 move takes time:  0.20186090469360352
# minmax zero, with depth 2 move takes time:  0.0564877986907959
# minmax normal, with depth 2 move takes time:  0.2224140167236328
# minmax zero, with depth 2 move takes time:  0.16141796112060547
# minmax normal, with depth 2 move takes time:  0.17690706253051758
# minmax zero, with depth 2 move takes time:  0.11959505081176758
# minmax normal, with depth 2 move takes time:  0.1682419776916504
# minmax zero, with depth 2 move takes time:  0.10899019241333008
# minmax normal, with depth 2 move takes time:  0.20830512046813965
# minmax zero, with depth 2 move takes time:  0.03682899475097656
# minmax normal, with depth 2 move takes time:  0.17804980278015137
# minmax zero, with depth 2 move takes time:  0.10922980308532715
# minmax normal, with depth 2 move takes time:  0.16143107414245605
# minmax zero, with depth 2 move takes time:  0.053340911865234375
# minmax normal, with depth 2 move takes time:  0.09529304504394531
# minmax zero, with depth 2 move takes time:  0.04376387596130371
# minmax normal, with depth 2 move takes time:  0.04918694496154785
# minmax zero, with depth 2 move takes time:  0.02588486671447754
# minmax normal, with depth 2 move takes time:  0.010416984558105469
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 2 move takes time:  0.04046297073364258
# minmax normal, with depth 2 move takes time:  0.24620389938354492
# minmax zero, with depth 2 move takes time:  0.05352210998535156
# minmax normal, with depth 2 move takes time:  0.5550520420074463
# minmax zero, with depth 2 move takes time:  0.2231919765472412
# minmax normal, with depth 2 move takes time:  0.9689419269561768
# minmax zero, with depth 2 move takes time:  0.5553460121154785
# minmax normal, with depth 2 move takes time:  0.6548128128051758
# minmax zero, with depth 2 move takes time:  1.0028331279754639
# minmax normal, with depth 2 move takes time:  1.0036940574645996
# minmax zero, with depth 2 move takes time:  0.38986682891845703
# minmax normal, with depth 2 move takes time:  1.0009639263153076
# minmax zero, with depth 2 move takes time:  0.18767309188842773
# minmax normal, with depth 2 move takes time:  1.001173973083496
# minmax zero, with depth 2 move takes time:  0.518563985824585
# minmax normal, with depth 2 move takes time:  0.3417930603027344
# minmax zero, with depth 2 move takes time:  0.6537389755249023
# minmax normal, with depth 2 move takes time:  0.34467291831970215
# minmax zero, with depth 2 move takes time:  0.43129420280456543
# minmax normal, with depth 2 move takes time:  0.5906651020050049
# minmax zero, with depth 2 move takes time:  0.4858729839324951
# minmax normal, with depth 2 move takes time:  0.32732319831848145
# minmax zero, with depth 2 move takes time:  0.2943871021270752
# minmax normal, with depth 2 move takes time:  0.3735659122467041
# minmax zero, with depth 2 move takes time:  0.4222440719604492
# minmax normal, with depth 2 move takes time:  0.35019397735595703
# minmax zero, with depth 2 move takes time:  0.5485539436340332
# minmax normal, with depth 2 move takes time:  0.5158741474151611
# minmax zero, with depth 2 move takes time:  0.21209192276000977
# minmax normal, with depth 2 move takes time:  0.652411937713623
# minmax zero, with depth 2 move takes time:  0.22652506828308105
# minmax normal, with depth 2 move takes time:  0.5103881359100342
# minmax zero, with depth 2 move takes time:  0.21538805961608887
# minmax normal, with depth 2 move takes time:  0.4427828788757324
# minmax zero, with depth 2 move takes time:  0.2707669734954834
# minmax normal, with depth 2 move takes time:  0.2591431140899658
# minmax zero, with depth 2 move takes time:  0.10333895683288574
# minmax normal, with depth 2 move takes time:  0.5456209182739258
# minmax zero, with depth 2 move takes time:  0.7552130222320557
# minmax normal, with depth 2 move takes time:  1.0047798156738281
# minmax zero, with depth 2 move takes time:  0.4260849952697754
# minmax normal, with depth 2 move takes time:  0.9393389225006104
# minmax zero, with depth 2 move takes time:  0.41690993309020996
# minmax normal, with depth 2 move takes time:  0.6155500411987305
# minmax zero, with depth 2 move takes time:  0.4403419494628906
# minmax normal, with depth 2 move takes time:  0.510565996170044
# minmax zero, with depth 2 move takes time:  0.22726202011108398
# minmax normal, with depth 2 move takes time:  0.5224311351776123
# minmax zero, with depth 2 move takes time:  0.3930330276489258
# minmax normal, with depth 2 move takes time:  0.4785420894622803
# minmax zero, with depth 2 move takes time:  0.33742594718933105
# minmax normal, with depth 2 move takes time:  0.45902395248413086
# minmax zero, with depth 2 move takes time:  0.22329306602478027
# minmax normal, with depth 2 move takes time:  0.45408082008361816
# minmax zero, with depth 2 move takes time:  0.1309061050415039
# minmax normal, with depth 2 move takes time:  0.48387622833251953
# minmax zero, with depth 2 move takes time:  0.3369109630584717
# minmax normal, with depth 2 move takes time:  0.5631680488586426
# minmax zero, with depth 2 move takes time:  0.2523040771484375
# minmax normal, with depth 2 move takes time:  0.4263648986816406
# minmax zero, with depth 2 move takes time:  0.14166998863220215
# minmax normal, with depth 2 move takes time:  0.3179631233215332
# minmax zero, with depth 2 move takes time:  0.17104697227478027
# minmax normal, with depth 2 move takes time:  0.49893999099731445
# minmax zero, with depth 2 move takes time:  0.10136795043945312
# minmax normal, with depth 2 move takes time:  0.40889811515808105
# minmax zero, with depth 2 move takes time:  0.180556058883667
# minmax normal, with depth 2 move takes time:  0.3192110061645508
# minmax zero, with depth 2 move takes time:  0.12462902069091797
# minmax normal, with depth 2 move takes time:  0.2575509548187256
# minmax zero, with depth 2 move takes time:  0.29728198051452637
# minmax normal, with depth 2 move takes time:  0.40778112411499023
# minmax zero, with depth 2 move takes time:  0.1927042007446289
# minmax normal, with depth 2 move takes time:  0.2018299102783203
# minmax zero, with depth 2 move takes time:  0.1095120906829834
# minmax normal, with depth 2 move takes time:  0.117218017578125
# minmax zero, with depth 2 move takes time:  0.08765482902526855
# minmax normal, with depth 2 move takes time:  0.11237788200378418
# minmax zero, with depth 2 move takes time:  0.046935081481933594
# minmax normal, with depth 2 move takes time:  0.07773995399475098
# minmax zero, with depth 2 move takes time:  0.05135488510131836
# minmax normal, with depth 2 move takes time:  0.1933300495147705
# minmax zero, with depth 2 move takes time:  0.03505110740661621
# minmax normal, with depth 2 move takes time:  0.07499384880065918
# minmax zero, with depth 2 move takes time:  0.01716899871826172
# minmax normal, with depth 2 move takes time:  0.060745954513549805
# minmax zero, with depth 2 move takes time:  0.04234600067138672
# minmax normal, with depth 2 move takes time:  0.02639317512512207
# minmax zero, with depth 2 move takes time:  0.02420496940612793
# minmax normal, with depth 2 move takes time:  0.017014026641845703
# minmax zero, with depth 2 move takes time:  0.008744001388549805
# minmax normal, with depth 2 move takes time:  0.013317108154296875
# minmax zero, with depth 2 move takes time:  0.004940032958984375
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# minmax zero, with depth 2 move takes time:  0.041661977767944336
# minmax normal, with depth 2 move takes time:  0.23256301879882812
# minmax zero, with depth 2 move takes time:  0.06055402755737305
# minmax normal, with depth 2 move takes time:  0.5278160572052002
# minmax zero, with depth 2 move takes time:  0.1699049472808838
# minmax normal, with depth 2 move takes time:  0.7856919765472412
# minmax zero, with depth 2 move takes time:  0.636775016784668
# minmax normal, with depth 2 move takes time:  0.6956942081451416
# minmax zero, with depth 2 move takes time:  0.8653321266174316
# minmax normal, with depth 2 move takes time:  0.9338631629943848
# minmax zero, with depth 2 move takes time:  0.37037205696105957
# minmax normal, with depth 2 move takes time:  1.0024700164794922
# minmax zero, with depth 2 move takes time:  0.17264103889465332
# minmax normal, with depth 2 move takes time:  1.0016310214996338
# minmax zero, with depth 2 move takes time:  0.5478270053863525
# minmax normal, with depth 2 move takes time:  0.4078819751739502
# minmax zero, with depth 2 move takes time:  0.24711108207702637
# minmax normal, with depth 2 move takes time:  0.5319080352783203
# minmax zero, with depth 2 move takes time:  0.23038315773010254
# minmax normal, with depth 2 move takes time:  0.9382550716400146
# minmax zero, with depth 2 move takes time:  0.36043500900268555
# minmax normal, with depth 2 move takes time:  0.3875710964202881
# minmax zero, with depth 2 move takes time:  0.19815587997436523
# minmax normal, with depth 2 move takes time:  0.2890439033508301
# minmax zero, with depth 2 move takes time:  0.11409401893615723
# minmax normal, with depth 2 move takes time:  0.30519604682922363
# minmax zero, with depth 2 move takes time:  0.34351420402526855
# minmax normal, with depth 2 move takes time:  0.9559741020202637
# minmax zero, with depth 2 move takes time:  0.10943388938903809
# minmax normal, with depth 2 move takes time:  1.0002100467681885
# minmax zero, with depth 2 move takes time:  0.23268795013427734
# minmax normal, with depth 2 move takes time:  0.5904579162597656
# minmax zero, with depth 2 move takes time:  0.26032495498657227
# minmax normal, with depth 2 move takes time:  0.5007710456848145
# minmax zero, with depth 2 move takes time:  0.1702110767364502
# minmax normal, with depth 2 move takes time:  0.42037510871887207
# minmax zero, with depth 2 move takes time:  0.23461318016052246
# minmax normal, with depth 2 move takes time:  0.7508997917175293
# minmax zero, with depth 2 move takes time:  0.28212499618530273
# minmax normal, with depth 2 move takes time:  1.0045289993286133
# minmax zero, with depth 2 move takes time:  0.2557058334350586
# minmax normal, with depth 2 move takes time:  0.8170599937438965
# minmax zero, with depth 2 move takes time:  0.2808701992034912
# minmax normal, with depth 2 move takes time:  0.4901301860809326
# minmax zero, with depth 2 move takes time:  0.23850584030151367
# minmax normal, with depth 2 move takes time:  0.6108129024505615
# minmax zero, with depth 2 move takes time:  0.15985107421875
# minmax normal, with depth 2 move takes time:  0.7292881011962891
# minmax zero, with depth 2 move takes time:  0.1939530372619629
# minmax normal, with depth 2 move takes time:  0.4195418357849121
# minmax zero, with depth 2 move takes time:  0.1902918815612793
# minmax normal, with depth 2 move takes time:  0.6719491481781006
# minmax zero, with depth 2 move takes time:  0.3608829975128174
# minmax normal, with depth 2 move takes time:  0.9724459648132324
# minmax zero, with depth 2 move takes time:  0.43509507179260254
# minmax normal, with depth 2 move takes time:  0.5531411170959473
# minmax zero, with depth 2 move takes time:  0.5689389705657959
# minmax normal, with depth 2 move takes time:  1.0009980201721191
# minmax zero, with depth 2 move takes time:  0.7617378234863281
# minmax normal, with depth 2 move takes time:  1.0023109912872314
# minmax zero, with depth 2 move takes time:  0.13561797142028809
# minmax normal, with depth 2 move takes time:  0.8841052055358887
# minmax zero, with depth 2 move takes time:  0.15816617012023926
# minmax normal, with depth 2 move takes time:  0.74934983253479
# minmax zero, with depth 2 move takes time:  0.3855738639831543
# minmax normal, with depth 2 move takes time:  1.0033960342407227
# minmax zero, with depth 2 move takes time:  0.11874079704284668
# minmax normal, with depth 2 move takes time:  0.8039109706878662
# minmax zero, with depth 2 move takes time:  0.25547099113464355
# minmax normal, with depth 2 move takes time:  0.7414870262145996
# minmax zero, with depth 2 move takes time:  0.37554001808166504
# minmax normal, with depth 2 move takes time:  0.7778468132019043
# minmax zero, with depth 2 move takes time:  0.07519388198852539
# minmax normal, with depth 2 move takes time:  0.564831018447876
# minmax zero, with depth 2 move takes time:  0.4492499828338623
# minmax normal, with depth 2 move takes time:  0.4658851623535156
# minmax zero, with depth 2 move takes time:  0.11989593505859375
# minmax normal, with depth 2 move takes time:  0.7863349914550781
# minmax zero, with depth 2 move takes time:  0.2662029266357422
# minmax normal, with depth 2 move takes time:  0.644995927810669
# minmax zero, with depth 2 move takes time:  0.2909688949584961
# minmax normal, with depth 2 move takes time:  0.21138501167297363
# minmax zero, with depth 2 move takes time:  0.5290629863739014
# minmax normal, with depth 2 move takes time:  0.44381189346313477
# minmax zero, with depth 2 move takes time:  0.16193199157714844
# minmax normal, with depth 2 move takes time:  0.21740198135375977
# minmax zero, with depth 2 move takes time:  0.07668781280517578
# minmax normal, with depth 2 move takes time:  0.2165820598602295
# minmax zero, with depth 2 move takes time:  0.049005985260009766
# minmax normal, with depth 2 move takes time:  0.19033098220825195
# minmax zero, with depth 2 move takes time:  0.10327792167663574
# minmax normal, with depth 2 move takes time:  0.2659931182861328
# minmax zero, with depth 2 move takes time:  0.13715696334838867
# minmax normal, with depth 2 move takes time:  0.3710811138153076
# minmax zero, with depth 2 move takes time:  0.11331605911254883
# minmax normal, with depth 2 move takes time:  0.07405400276184082
# minmax zero, with depth 2 move takes time:  0.08187603950500488
# minmax normal, with depth 2 move takes time:  0.12775492668151855
# minmax zero, with depth 2 move takes time:  0.11904788017272949
# minmax normal, with depth 2 move takes time:  0.19536280632019043
# minmax zero, with depth 2 move takes time:  0.04107189178466797
# minmax normal, with depth 2 move takes time:  0.01810908317565918
# minmax zero, with depth 2 move takes time:  0.00986790657043457
# minmax normal, with depth 2 move takes time:  0.014614105224609375
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.1905381679534912
# minmax zero, with depth 2 move takes time:  0.09119987487792969
# minmax normal, with depth 2 move takes time:  0.2206718921661377
# minmax zero, with depth 2 move takes time:  0.14843201637268066
# minmax normal, with depth 2 move takes time:  0.6757581233978271
# minmax zero, with depth 2 move takes time:  0.4714970588684082
# minmax normal, with depth 2 move takes time:  0.725862979888916
# minmax zero, with depth 2 move takes time:  0.44664597511291504
# minmax normal, with depth 2 move takes time:  0.9888110160827637
# minmax zero, with depth 2 move takes time:  0.6334898471832275
# minmax normal, with depth 2 move takes time:  0.6433670520782471
# minmax zero, with depth 2 move takes time:  0.2468090057373047
# minmax normal, with depth 2 move takes time:  0.2969059944152832
# minmax zero, with depth 2 move takes time:  0.16447091102600098
# minmax normal, with depth 2 move takes time:  0.767179012298584
# minmax zero, with depth 2 move takes time:  0.3392190933227539
# minmax normal, with depth 2 move takes time:  0.23014402389526367
# minmax zero, with depth 2 move takes time:  0.21215105056762695
# minmax normal, with depth 2 move takes time:  0.6573100090026855
# minmax zero, with depth 2 move takes time:  0.18555212020874023
# minmax normal, with depth 2 move takes time:  0.4801290035247803
# minmax zero, with depth 2 move takes time:  0.13068699836730957
# minmax normal, with depth 2 move takes time:  0.6535029411315918
# minmax zero, with depth 2 move takes time:  0.17346405982971191
# minmax normal, with depth 2 move takes time:  0.48662495613098145
# minmax zero, with depth 2 move takes time:  0.16446399688720703
# minmax normal, with depth 2 move takes time:  0.310230016708374
# minmax zero, with depth 2 move takes time:  0.1849830150604248
# minmax normal, with depth 2 move takes time:  0.353626012802124
# minmax zero, with depth 2 move takes time:  0.20739388465881348
# minmax normal, with depth 2 move takes time:  0.5945441722869873
# minmax zero, with depth 2 move takes time:  0.1657099723815918
# minmax normal, with depth 2 move takes time:  0.568687915802002
# minmax zero, with depth 2 move takes time:  0.15606999397277832
# minmax normal, with depth 2 move takes time:  0.4094419479370117
# minmax zero, with depth 2 move takes time:  0.12113785743713379
# minmax normal, with depth 2 move takes time:  0.4429919719696045
# minmax zero, with depth 2 move takes time:  0.07804417610168457
# minmax normal, with depth 2 move takes time:  0.401141881942749
# minmax zero, with depth 2 move takes time:  0.0720069408416748
# minmax normal, with depth 2 move takes time:  0.2950608730316162
# minmax zero, with depth 2 move takes time:  0.08192706108093262
# minmax normal, with depth 2 move takes time:  0.301785945892334
# minmax zero, with depth 2 move takes time:  0.07201719284057617
# minmax normal, with depth 2 move takes time:  0.310283899307251
# minmax zero, with depth 2 move takes time:  0.14695310592651367
# minmax normal, with depth 2 move takes time:  0.32757019996643066
# minmax zero, with depth 2 move takes time:  0.14509201049804688
# minmax normal, with depth 2 move takes time:  0.3215758800506592
# minmax zero, with depth 2 move takes time:  0.058557987213134766
# minmax normal, with depth 2 move takes time:  0.29906511306762695
# minmax zero, with depth 2 move takes time:  0.10893988609313965
# minmax normal, with depth 2 move takes time:  0.2270960807800293
# minmax zero, with depth 2 move takes time:  0.2523329257965088
# minmax normal, with depth 2 move takes time:  0.41433000564575195
# minmax zero, with depth 2 move takes time:  0.13504600524902344
# minmax normal, with depth 2 move takes time:  0.32165002822875977
# minmax zero, with depth 2 move takes time:  0.25836896896362305
# minmax normal, with depth 2 move takes time:  0.3560359477996826
# minmax zero, with depth 2 move takes time:  0.14709806442260742
# minmax normal, with depth 2 move takes time:  0.287930965423584
# minmax zero, with depth 2 move takes time:  0.0949850082397461
# minmax normal, with depth 2 move takes time:  0.1739180088043213
# minmax zero, with depth 2 move takes time:  0.05375194549560547
# minmax normal, with depth 2 move takes time:  0.1987600326538086
# minmax zero, with depth 2 move takes time:  0.1487579345703125
# minmax normal, with depth 2 move takes time:  0.22454404830932617
# minmax zero, with depth 2 move takes time:  0.14896202087402344
# minmax normal, with depth 2 move takes time:  0.14039087295532227
# minmax zero, with depth 2 move takes time:  0.0914769172668457
# minmax normal, with depth 2 move takes time:  0.17283892631530762
# minmax zero, with depth 2 move takes time:  0.03347301483154297
# minmax normal, with depth 2 move takes time:  0.15089082717895508
# minmax zero, with depth 2 move takes time:  0.09166908264160156
# minmax normal, with depth 2 move takes time:  0.13188815116882324
# minmax zero, with depth 2 move takes time:  0.04656195640563965
# minmax normal, with depth 2 move takes time:  0.08418703079223633
# minmax zero, with depth 2 move takes time:  0.0333249568939209
# minmax normal, with depth 2 move takes time:  0.038928985595703125
# minmax zero, with depth 2 move takes time:  0.020885944366455078
# minmax normal, with depth 2 move takes time:  0.008855104446411133
# minmax zero, with depth 2 move takes time:  0.0038700103759765625
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.179548978805542
# minmax zero, with depth 2 move takes time:  0.05277705192565918
# minmax normal, with depth 2 move takes time:  0.15751004219055176
# minmax zero, with depth 2 move takes time:  0.15239596366882324
# minmax normal, with depth 2 move takes time:  0.5624048709869385
# minmax zero, with depth 2 move takes time:  0.429703950881958
# minmax normal, with depth 2 move takes time:  0.6579041481018066
# minmax zero, with depth 2 move takes time:  0.3746180534362793
# minmax normal, with depth 2 move takes time:  1.00095796585083
# minmax zero, with depth 2 move takes time:  0.298367977142334
# minmax normal, with depth 2 move takes time:  0.34060192108154297
# minmax zero, with depth 2 move takes time:  0.1493968963623047
# minmax normal, with depth 2 move takes time:  0.5886399745941162
# minmax zero, with depth 2 move takes time:  0.21904897689819336
# minmax normal, with depth 2 move takes time:  0.54854416847229
# minmax zero, with depth 2 move takes time:  0.23930692672729492
# minmax normal, with depth 2 move takes time:  0.5828590393066406
# minmax zero, with depth 2 move takes time:  0.18975400924682617
# minmax normal, with depth 2 move takes time:  0.3726019859313965
# minmax zero, with depth 2 move takes time:  0.26934289932250977
# minmax normal, with depth 2 move takes time:  0.5544850826263428
# minmax zero, with depth 2 move takes time:  0.07983207702636719
# minmax normal, with depth 2 move takes time:  0.34359288215637207
# minmax zero, with depth 2 move takes time:  0.22072100639343262
# minmax normal, with depth 2 move takes time:  0.37076497077941895
# minmax zero, with depth 2 move takes time:  0.0669710636138916
# minmax normal, with depth 2 move takes time:  0.551875114440918
# minmax zero, with depth 2 move takes time:  0.2207028865814209
# minmax normal, with depth 2 move takes time:  0.4691901206970215
# minmax zero, with depth 2 move takes time:  0.2153940200805664
# minmax normal, with depth 2 move takes time:  0.3536520004272461
# minmax zero, with depth 2 move takes time:  0.13417506217956543
# minmax normal, with depth 2 move takes time:  0.44004201889038086
# minmax zero, with depth 2 move takes time:  0.1756589412689209
# minmax normal, with depth 2 move takes time:  0.3513779640197754
# minmax zero, with depth 2 move takes time:  0.15360808372497559
# minmax normal, with depth 2 move takes time:  0.3978700637817383
# minmax zero, with depth 2 move takes time:  0.0463559627532959
# minmax normal, with depth 2 move takes time:  0.2975599765777588
# minmax zero, with depth 2 move takes time:  0.18048787117004395
# minmax normal, with depth 2 move takes time:  0.41957998275756836
# minmax zero, with depth 2 move takes time:  0.22372984886169434
# minmax normal, with depth 2 move takes time:  0.691824197769165
# minmax zero, with depth 2 move takes time:  0.1980130672454834
# minmax normal, with depth 2 move takes time:  0.6570329666137695
# minmax zero, with depth 2 move takes time:  0.11915087699890137
# minmax normal, with depth 2 move takes time:  0.586094856262207
# minmax zero, with depth 2 move takes time:  0.10679197311401367
# minmax normal, with depth 2 move takes time:  0.3573148250579834
# minmax zero, with depth 2 move takes time:  0.0893559455871582
# minmax normal, with depth 2 move takes time:  0.43991899490356445
# minmax zero, with depth 2 move takes time:  0.13924598693847656
# minmax normal, with depth 2 move takes time:  0.574134111404419
# minmax zero, with depth 2 move takes time:  0.26967310905456543
# minmax normal, with depth 2 move takes time:  0.4072599411010742
# minmax zero, with depth 2 move takes time:  0.18178510665893555
# minmax normal, with depth 2 move takes time:  0.3765280246734619
# minmax zero, with depth 2 move takes time:  0.37364697456359863
# minmax normal, with depth 2 move takes time:  0.3087887763977051
# minmax zero, with depth 2 move takes time:  0.2695589065551758
# minmax normal, with depth 2 move takes time:  0.5243308544158936
# minmax zero, with depth 2 move takes time:  0.05690503120422363
# minmax normal, with depth 2 move takes time:  0.35373497009277344
# minmax zero, with depth 2 move takes time:  0.2754089832305908
# minmax normal, with depth 2 move takes time:  0.2062840461730957
# minmax zero, with depth 2 move takes time:  0.10657501220703125
# minmax normal, with depth 2 move takes time:  0.15912294387817383
# minmax zero, with depth 2 move takes time:  0.0682530403137207
# minmax normal, with depth 2 move takes time:  0.30324316024780273
# minmax zero, with depth 2 move takes time:  0.21572303771972656
# minmax normal, with depth 2 move takes time:  0.13183021545410156
# minmax zero, with depth 2 move takes time:  0.10179305076599121
# minmax normal, with depth 2 move takes time:  0.18778705596923828
# minmax zero, with depth 2 move takes time:  0.10424089431762695
# minmax normal, with depth 2 move takes time:  0.12159609794616699
# minmax zero, with depth 2 move takes time:  0.08779406547546387
# minmax normal, with depth 2 move takes time:  0.14277410507202148
# minmax zero, with depth 2 move takes time:  0.04898881912231445
# minmax normal, with depth 2 move takes time:  0.06985211372375488
# minmax zero, with depth 2 move takes time:  0.07183098793029785
# minmax normal, with depth 2 move takes time:  0.07445096969604492
# minmax zero, with depth 2 move takes time:  0.03528308868408203
# minmax normal, with depth 2 move takes time:  0.0362248420715332
# minmax zero, with depth 2 move takes time:  0.026948928833007812
# minmax normal, with depth 2 move takes time:  0.038162946701049805
# minmax zero, with depth 2 move takes time:  0.007699012756347656
# minmax normal, with depth 2 move takes time:  0.012537956237792969
# minmax zero, with depth 2 move takes time:  0.009400129318237305
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.19429421424865723
# minmax zero, with depth 2 move takes time:  0.0537109375
# minmax normal, with depth 2 move takes time:  0.16040802001953125
# minmax zero, with depth 2 move takes time:  0.1697838306427002
# minmax normal, with depth 2 move takes time:  0.5615959167480469
# minmax zero, with depth 2 move takes time:  0.36347484588623047
# minmax normal, with depth 2 move takes time:  0.6367871761322021
# minmax zero, with depth 2 move takes time:  0.39222097396850586
# minmax normal, with depth 2 move takes time:  1.001330852508545
# minmax zero, with depth 2 move takes time:  0.72707200050354
# minmax normal, with depth 2 move takes time:  0.7962350845336914
# minmax zero, with depth 2 move takes time:  0.17333698272705078
# minmax normal, with depth 2 move takes time:  0.5047390460968018
# minmax zero, with depth 2 move takes time:  0.14400100708007812
# minmax normal, with depth 2 move takes time:  0.6808209419250488
# minmax zero, with depth 2 move takes time:  0.3804290294647217
# minmax normal, with depth 2 move takes time:  0.25263404846191406
# minmax zero, with depth 2 move takes time:  0.2964780330657959
# minmax normal, with depth 2 move takes time:  0.7334809303283691
# minmax zero, with depth 2 move takes time:  0.19120311737060547
# minmax normal, with depth 2 move takes time:  0.7900121212005615
# minmax zero, with depth 2 move takes time:  0.11288213729858398
# minmax normal, with depth 2 move takes time:  0.38412904739379883
# minmax zero, with depth 2 move takes time:  0.16918206214904785
# minmax normal, with depth 2 move takes time:  0.5447618961334229
# minmax zero, with depth 2 move takes time:  0.09947705268859863
# minmax normal, with depth 2 move takes time:  1.0000901222229004
# minmax zero, with depth 2 move takes time:  0.4531428813934326
# minmax normal, with depth 2 move takes time:  0.4127209186553955
# minmax zero, with depth 2 move takes time:  0.2253551483154297
# minmax normal, with depth 2 move takes time:  1.0000829696655273
# minmax zero, with depth 2 move takes time:  0.30440783500671387
# minmax normal, with depth 2 move takes time:  0.46863508224487305
# minmax zero, with depth 2 move takes time:  0.28426384925842285
# minmax normal, with depth 2 move takes time:  0.5865190029144287
# minmax zero, with depth 2 move takes time:  0.33085012435913086
# minmax normal, with depth 2 move takes time:  0.7196910381317139
# minmax zero, with depth 2 move takes time:  0.4925720691680908
# minmax normal, with depth 2 move takes time:  0.6726479530334473
# minmax zero, with depth 2 move takes time:  0.5069179534912109
# minmax normal, with depth 2 move takes time:  0.5254628658294678
# minmax zero, with depth 2 move takes time:  0.6686229705810547
# minmax normal, with depth 2 move takes time:  1.0040309429168701
# minmax zero, with depth 2 move takes time:  0.3333618640899658
# minmax normal, with depth 2 move takes time:  0.9352259635925293
# minmax zero, with depth 2 move takes time:  0.18303990364074707
# minmax normal, with depth 2 move takes time:  0.6216678619384766
# minmax zero, with depth 2 move takes time:  0.0770258903503418
# minmax normal, with depth 2 move takes time:  0.9501128196716309
# minmax zero, with depth 2 move takes time:  0.28017592430114746
# minmax normal, with depth 2 move takes time:  0.5873160362243652
# minmax zero, with depth 2 move takes time:  0.4237489700317383
# minmax normal, with depth 2 move takes time:  0.7743799686431885
# minmax zero, with depth 2 move takes time:  0.3748359680175781
# minmax normal, with depth 2 move takes time:  0.6356439590454102
# minmax zero, with depth 2 move takes time:  0.44534993171691895
# minmax normal, with depth 2 move takes time:  0.780019998550415
# minmax zero, with depth 2 move takes time:  0.3718249797821045
# minmax normal, with depth 2 move takes time:  0.5100650787353516
# minmax zero, with depth 2 move takes time:  0.366487979888916
# minmax normal, with depth 2 move takes time:  1.000298023223877
# minmax zero, with depth 2 move takes time:  0.3508479595184326
# minmax normal, with depth 2 move takes time:  0.7314741611480713
# minmax zero, with depth 2 move takes time:  0.22601318359375
# minmax normal, with depth 2 move takes time:  0.3891441822052002
# minmax zero, with depth 2 move takes time:  0.2838289737701416
# minmax normal, with depth 2 move takes time:  0.5115511417388916
# minmax zero, with depth 2 move takes time:  0.1544787883758545
# minmax normal, with depth 2 move takes time:  0.44794201850891113
# minmax zero, with depth 2 move takes time:  0.23400115966796875
# minmax normal, with depth 2 move takes time:  0.5608730316162109
# minmax zero, with depth 2 move takes time:  0.1622920036315918
# minmax normal, with depth 2 move takes time:  0.39139699935913086
# minmax zero, with depth 2 move takes time:  0.16319918632507324
# minmax normal, with depth 2 move takes time:  0.3401498794555664
# minmax zero, with depth 2 move takes time:  0.561039924621582
# minmax normal, with depth 2 move takes time:  0.6482598781585693
# minmax zero, with depth 2 move takes time:  0.31476712226867676
# minmax normal, with depth 2 move takes time:  0.32396411895751953
# minmax zero, with depth 2 move takes time:  0.09704709053039551
# minmax normal, with depth 2 move takes time:  0.3769869804382324
# minmax zero, with depth 2 move takes time:  0.1478419303894043
# minmax normal, with depth 2 move takes time:  0.2812538146972656
# minmax zero, with depth 2 move takes time:  0.19141101837158203
# minmax normal, with depth 2 move takes time:  0.21626710891723633
# minmax zero, with depth 2 move takes time:  0.09615778923034668
# minmax normal, with depth 2 move takes time:  0.0976250171661377
# minmax zero, with depth 2 move takes time:  0.0473179817199707
# minmax normal, with depth 2 move takes time:  0.06916213035583496
# minmax zero, with depth 2 move takes time:  0.02063608169555664
# minmax normal, with depth 2 move takes time:  0.017830848693847656
# minmax zero, with depth 2 move takes time:  0.016044139862060547
# minmax normal, with depth 2 move takes time:  0.017093896865844727
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# minmax normal, with depth 2 move takes time:  0.23238611221313477
# minmax zero, with depth 2 move takes time:  0.06832599639892578
# minmax normal, with depth 2 move takes time:  0.21002483367919922
# minmax zero, with depth 2 move takes time:  0.19911813735961914
# minmax normal, with depth 2 move takes time:  0.7415730953216553
# minmax zero, with depth 2 move takes time:  0.4598560333251953
# minmax normal, with depth 2 move takes time:  0.8283529281616211
# minmax zero, with depth 2 move takes time:  0.4508509635925293
# minmax normal, with depth 2 move takes time:  1.0016930103302002
# minmax zero, with depth 2 move takes time:  0.577610969543457
# minmax normal, with depth 2 move takes time:  0.637239933013916
# minmax zero, with depth 2 move takes time:  0.22352910041809082
# minmax normal, with depth 2 move takes time:  0.8606538772583008
# minmax zero, with depth 2 move takes time:  0.13790416717529297
# minmax normal, with depth 2 move takes time:  0.8434469699859619
# minmax zero, with depth 2 move takes time:  0.10828304290771484
# minmax normal, with depth 2 move takes time:  0.8976960182189941
# minmax zero, with depth 2 move takes time:  0.3657820224761963
# minmax normal, with depth 2 move takes time:  0.2789950370788574

# %%
a = Ataxx()
# %lprun -f minmax_zero.min_max _, best_move = minmax_zero.min_max(a.data, turn, turn, depth=6, pre_move=best_move, t_lim=100)
