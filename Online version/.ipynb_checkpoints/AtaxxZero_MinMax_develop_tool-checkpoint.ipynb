# %%
# %load_ext line_profiler
import line_profiler

# %%
import os 
import importlib
import sys
import tensorflow as tf
import itertools
import numpy as np
import numba as nb
from math import sqrt, log, exp
from numpy import unravel_index
from random import choice, random, sample
np.random.seed(1337)  # for reproducibility
from keras.models import Sequential, Model, load_model
import keras.backend as K
import matplotlib.pyplot as plt
K.set_image_dim_ordering('th')
import time
# Out:
# Using TensorFlow backend.

# %%
class Ataxx:
    def __init__(self, board=None):
        if board is None:                  # if there is no initialization given
            self.data = np.zeros((7, 7), dtype=np.int8)   # then generate a board with starting init, and black(-1) takes first turn
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
            
    def reset(self, board=None):
        if board is None:
            self.data = np.zeros((7, 7), dtype=np.int8)
            self.data[0, 0] = -1           
            self.data[6, 6] = -1
            self.data[0, 6] = 1
            self.data[6, 0] = 1
        else:
            self.data = board.copy()
        
    def get_feature_map(self, turn, move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge
        
        # edge
        for j in range(9):
            for k in range(9):
                if j == 0 or j == 8 or k == 0 or k == 8:
                    out[0, j, k] = 1
         
        # my pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == turn:
                        out[1, j, k] = 1
        
        # op pieces
        for j in range(9):
            for k in range(9):
                if j > 0 and j < 8 and k > 0 and k < 8:
                    if self.data[j-1, k-1] == -turn:
                        out[2, j, k] = 1
         
        # last move
        if not move is None:               
            out[3, move[0][0]+1, move[0][1]+1] = 1
            out[4, move[1][0]+1, move[1][1]+1] = 1
            
        # whose first
        if turn == -1:
            for j in range(9):
                for k in range(9):
                    out[5, j, k] = 1
        return np.array(out)
    
    def plot(self, is_next_move=False, turn=None):                        # plot the board
        image = self.data.copy()
        if is_next_move:
            if turn not in [-1, 1]:
                raise ValueError("Turn must be -1 or 1, or Must input a turn for next moves")
            else:
                next_moves = self.get_moves(turn)
                if len(next_moves) == 0:
                    raise ValueError("Game is over already")
                next_pos = list(zip(*next_moves))[1]
                for pos in next_pos:
                    image[pos] = turn / 2
        plt.imshow(image, cmap='gray')
        plt.xticks(range(7), range(7))
        plt.yticks(range(7), range(7))
        plt.show()
        
    def get_greedy_move(self, turn, moves=None):
        best_score = -50
        # get all possible moves if not provided
        if moves is None:
            moves, corr_dict = self.get_moves(turn)
            for item in corr_dict:
                moves.append(item)
        
        if len(moves) == 0:
            raise ValueError('No Possible Moves')
        
        best_moves = []
        # calculate greedy move
        for (x0, y0), (x1, y1) in moves:
            tmp_score = 0
            if abs(x0-x1) <= 1 and abs(y0-y1) <= 1:
                tmp_score += 1
            for dr in range(-1, 2):
                for dc in range(-1, 2):
                    try:
                        if x1+dr >= 0 and y1+dc >= 0:
                            tmp_score += self.data[x1+dr, y1+dc] == -turn
                    except:
                        pass
            if tmp_score > best_score:
                best_moves = [((x0, y0), (x1, y1))]
                best_score = tmp_score
            elif tmp_score == best_score:
                best_moves.append(((x0, y0), (x1, y1)))
        return choice(best_moves)
                
    def is_valid(self, turn, pos, get_pos=False):
        r = pos[0]
        c = pos[1]
        if self.data[r, c] != 0:
            if not get_pos:
                return False
            else:
                return
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if not get_pos:
                            return True
                        else:
                            yield new_r, new_c, dr, dc
            if not get_pos:
                return False
        
    def get_moves(self, turn):
        action_mask = np.zeros(792, dtype=np.int8)
        next_moves = []
        corr_dict = {}
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(turn, (r, c), True): # duplicate move
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and self.data[new_r, new_c] == turn:
                        if abs(dr) <= 1 and abs(dc) <=1:
                            if has_duplicate_move: 
                                cur_move = ((new_r, new_c), (r, c))
                                corr_dict[cur_move] = dup_move
                            elif self.data[new_r, new_c] == turn:
                                dup_move = ((new_r, new_c), (r, c))
                                next_moves.append(dup_move) 
                                has_duplicate_move = True
                        elif self.data[new_r, new_c] == turn:
                            cur_move = ((new_r, new_c), (r, c))
                            next_moves.append(cur_move) 
                        else:
                            continue

        return next_moves, corr_dict
        
    def move_to(self, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]
        
        if not self.is_valid(turn, pos1):
            raise ValueError("This move: " + str((pos0, pos1)) + " of turn: " + str(turn) + " is invalid") 
        elif self.data[x0, y0] != turn:
            raise ValueError("The starting position is not your piece")
        else:
            self.data[x1, y1] = turn
            if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
                self.data[x0, y0] = 0

            for dr in range(-1, 2):                  # infection mode!!!!
                for dc in range(-1, 2):
                    if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                        if self.data[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                            self.data[x1+dr, y1+dc] = turn
    
    def evaluate(self, turn, this_turn, max_score=1, min_score=0.001):
        turn_no=0
        op_no=0
        for r in range(7):
            for c in range(7):
                if self.data[r, c] == turn:
                    turn_no += 1
                elif self.data[r, c] == -turn:
                    op_no += 1
        if len(self.get_moves(this_turn)[0]) == 0:# if one of them can no longer move, count and end
            if turn_no > op_no:
                return max_score
            else:
                return -max_score
        else:
            value = turn_no - op_no
        return value * min_score
    
    @staticmethod    
    def get_manual_q(turn, board):
        '''consider linear growth of win prob with regard to n_diff
        when diff >= 10, the slope grow a bit
        when diff >= 35, consider win prob close to 1 or -1
        ''' 
        turn_no = 0
        op_no = 0
        max1=0.9
        max2=0.95
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        diff = turn_no - op_no
        if abs(diff) > 30:
            return diff / abs(diff)
        else:
            return diff / 30
        
        # ignore the rest for now
        sign = diff
        diff = abs(diff)
        if diff < 35:
            diff = (diff / 35) ** 2 * max1
        else:
            diff = max2

        if sign < 0:
            return -diff
        else:
            return diff

# %%
class PolicyValueNetwork():
    def __init__(self, model_name):
        self._sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=24))
        K.set_session(self._sess)
        
        self._model = load_model(model_name)
        print("successfully loaded the model")
           
    def predict(self, feature_map, action_mask):        
        return self._sess.run(self._model.outputs, feed_dict={self._model.inputs[0]: feature_map.reshape(-1, 6, 9, 9), \
                                self._model.inputs[1]: action_mask.reshape(-1, 792), K.learning_phase(): 0})

# %%
'''These methods are for normal Min max'''
class MinMaxNormal():
    def __init__(self):
        return
    
    @staticmethod
    def evaluate(board, turn):
        turn_no = 0
        op_no = 0
        # get no diff of turns
        for r in range(7):
            for c in range(7):
                if board[r, c] == turn:
                    turn_no += 1
                elif board[r, c] == -turn:
                    op_no += 1
        return (turn_no - op_no)

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return False
        else:
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                        return True
            return False 

    def next_move(self, board, turn):
        next_moves = []
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                if self.is_valid(board, turn, (r, c)): # duplicate move
                    for dr in range(-2, 3):
                        for dc in range(-2, 3):
                            new_r = r+dr
                            new_c = c+dc
                            if new_r >= 0 and new_c >= 0 and new_r < 7 and new_c < 7 and board[new_r, new_c] == turn:
                                if abs(dr) <= 1 and abs(dc) <=1:
                                    if board[new_r, new_c] == turn and not has_duplicate_move:
                                        dup_move = ((new_r, new_c), (r, c))
                                        has_duplicate_move = True
                                        yield dup_move
                                elif board[new_r, new_c] == turn:
                                    cur_move = ((new_r, new_c), (r, c))
                                    yield cur_move
                                else:
                                    continue

    def has_next_move(self, board, turn):
        try:
            next(self.next_move(board, turn))
            return True
        except StopIteration:
            return False

    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board

    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
        else:
            best_move = ((0, 0), (0, 0))

        if depth == 0 or not self.has_next_move(board, turn): # start to do pruning and selecting once the recursion reaches the end
            result = self.evaluate(board, target_turn)
            return result, None
        else:
            if is_max:
                alpha = -100
            else:
                beta = 100

            for move in self.next_move(board, turn):
                result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False)
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == alpha and is_root:
                        best_moves.append(move)
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        if is_root:
                            best_moves = [move]
                        else:
                            best_move = move
                    elif result == beta and is_root:
                        best_moves.append(move)
            if is_max:
                if is_root:
                    return alpha, choice(best_moves)
                else:
                    return alpha, best_move
            else:
                if is_root:
                    return beta, choice(best_moves)
                else:
                    return beta, best_move

# %%
class MinMaxZero():
    def __init__(self, p_thresh, c_thresh, model_name="AtaxxZero.h5"):
        self._evaluator = PolicyValueNetwork(model_name)
        self._policy_dict = self.get_policy_dict()
        self._p_thresh = p_thresh
        self._c_thresh = c_thresh
        
    @staticmethod
    def get_policy_dict():
        '''Get the relation between policy no. and policy'''
        index=0
        policy_dict = {}
        for r in range(7):
            for c in range(7):
                for dr in range(-2, 3):
                    for dc in range(-2, 3):
                        new_r = r + dr
                        new_c = c + dc
                        if (dr != 0 or dc != 0) and (new_r < 7 and new_r >= 0) and (new_c < 7 and new_c >= 0):
                            policy_dict[((r, c), (new_r, new_c))] = index
                            index += 1
        return policy_dict

    @staticmethod
    def get_feature_map(board, turn, pre_move):
        out = np.zeros((6, 9, 9), dtype=np.int8)
        # define 1 edge

        # edge
        out[0, 0, :] = 1
        out[0, 8, :] = 1
        out[0, :, 0] = 1
        out[0, :, 8] = 1

        # my pieces
        out[1, 1:8, 1:8] = (board == turn)

        # op pieces
        out[2, 1:8, 1:8] = (board == -turn)
        
        # last move
        if not pre_move is None:               
            out[3, pre_move[0][0]+1, pre_move[0][1]+1] = 1
            out[4, pre_move[1][0]+1, pre_move[1][1]+1] = 1

        # whose first
        if turn == -1:
            out[5, ...] = 1
        return out
    
    def evaluate(self, feature_map, action_mask, turn, target_turn):
        result = self._evaluator.predict(feature_map, action_mask)
        p = result[0][0]
        if turn == target_turn:
            q = result[1][0][0]
        else:
            q = -result[1][0][0]
        return p, q

    @staticmethod
    def is_valid(board, turn, pos):
        r = pos[0]
        c = pos[1]
        if board[r, c] != 0:
            return
        else:
            turn_board = board == turn
            for dr in range(-2, 3):
                for dc in range(-2, 3):
                    new_r = r+dr
                    new_c = c+dc
                    try:
                        assert new_r >= 0 and new_c >= 0 and turn_board[new_r, new_c]
                        yield new_r, new_c, dr, dc
                    except:
                        pass
    
    def get_moves(self, board, turn):
        next_moves = []
        dup_moves = []
        action_mask = np.zeros(792, np.int8)
        for r in range(7):
            for c in range(7):
                has_duplicate_move = False      # move within the radius of one of another friendly piece is called
                for new_r, new_c, dr, dc in self.is_valid(board, turn, (r, c)): # duplicate move
                    cur_move = ((new_r, new_c), (r, c))
                    # update action mask
                    action_mask[self._policy_dict[cur_move]] = 1
                    if abs(dr) <= 1 and abs(dc) <=1:
                        if not has_duplicate_move:
                            has_duplicate_move = True
                            next_moves.append(cur_move)
                    else:
                        next_moves.append(cur_move)

        return next_moves, action_mask
    
    @staticmethod
    def move_to(board, turn, pos0, pos1):
        x0 = pos0[0]
        y0 = pos0[1]
        x1 = pos1[0]
        y1 = pos1[1]

        board = board.copy()
        board[x1, y1] = turn
        if abs(x0 - x1) > 1 or abs(y0 - y1) > 1:   # jump move
            board[x0, y0] = 0

        for dr in range(-1, 2):                  # infection mode!!!!
            for dc in range(-1, 2):
                if x1+dr >= 0 and y1+dc >= 0 and x1+dr < 7 and y1+dc < 7:
                    if board[x1+dr, y1+dc] == -turn:  # convert any piece of the opponent to 'turn'
                        board[x1+dr, y1+dc] = turn
        return board
    
    def min_max(self, board, turn, target_turn, depth=3, alpha=-100, beta=100, is_max=True, is_root=True, \
                pre_move=None, t_lim=1):
        '''A recursive alpha beta pruning min_max function
        return: board evaluation, chosen move
        NB. for board evaluation, if the searching was pruned, it will return 100 for a minimizer and -100 for a maximizer'''
        if is_root:
            best_moves = []
            self._start = time.time()
        else:
            best_move = ((0, 0), (0, 0))
        
        # get next moves
        next_moves, action_mask = self.get_moves(board, turn)
        # stop searching if the game is over
        if len(next_moves) == 0:
            diff = (board == target_turn).sum() - (board == -target_turn).sum()
            if diff > 0:
                return 1, None
            elif diff < 0:
                return -1, None
            else:
                turn_no = (board == turn).sum()
                if turn == -target_turn:
                    turn_no = 49 - turn_no # set turn_no to represent the number of target turn pieces
                if turn_no >= 45:
                    return 1, None
                else:
                    return -1, None
        else: # otherwise calculate p and q and do the NN pruned minmax searching
            feature_map = self.get_feature_map(board, turn, pre_move)
            p, q = self.evaluate(feature_map, action_mask, turn, target_turn)
            
        if depth == 0: # once the recursion reaches the end, return the leaf node value
            return q, None
        else:
            # generate move corresponding p list
            move_prob = []
            all_prob = 0.0
            for move in next_moves:
                prob = p[self._policy_dict[move]]
                move_prob.append((move, prob))
                all_prob += prob
            move_prob = sorted(move_prob, key=lambda x: x[1], reverse=True)

            if is_max:
                alpha = -100
            else:
                beta = 100

            sum_prob = 0.0
            counter = 0
            counter_thresh = len(move_prob) / self._c_thresh
            prob_thresh = all_prob * self._p_thresh
            # display_move_prob(move_prob)
            for move, prob in move_prob:
                sum_prob += prob
                counter += 1
                # do searching
                result, _ = self.min_max(self.move_to(board, turn, move[0], move[1]), \
                                    -turn, target_turn, depth-1, alpha, beta, not is_max, False, move, t_lim)
                # record all the move and its alpha value
                if is_root:
                    try:
                        move_value.append((move, result))
                    except:
                        move_value = [(move, result)]
                # prun the searching tree or update alpha and beta respectively
                if is_max:
                    if result >= beta:
                        return 100, None
                    elif result > alpha:
                        alpha = result
                        best_move = move
                else:
                    if result <= alpha:
                        return -100, None
                    elif result < beta:
                        beta = result
                        best_move = move

                if (sum_prob >= prob_thresh and counter >= counter_thresh) or time.time() - self._start >= t_lim:
                    break
                    
            if is_root: # incorporate ramdom characteristic
                move_value = sorted(move_value, key=lambda x: x[1], reverse=True)
                max_value = alpha
                for move, value in move_value:
                    if value >= max_value - 0.1 * abs(max_value):
                        try:
                            best_move.append(move)
                        except:
                            best_move = [move]
                    else:
                        break
                # print(len(best_move))
                best_move = choice(best_move)

            if is_max:
                return alpha, best_move
            else:
                return beta, best_move

# %%
def actor(mm_obj, board, turn, depth, pre_move):
    try:
        _, best_move = mm_obj.min_max(board, turn, turn, depth=depth, pre_move=pre_move, t_lim=3)
    except:
        _, best_move = mm_obj.min_max(board, turn, turn, depth=depth)
    return best_move

# %%
def actor_compare(minmax_normal, minmax_zero, N_D, Z_D, rounds):
    zero_win = 0
    time_zero = []
    time_normal = []
    for r in range(rounds):
        print("Round:", r)
        steps = 0
        a = Ataxx()
        turn = -1
        zero_turn = choice([-1, 1])
        #print("zero chose color", zero_turn)
        best_move = None
        while True:
            steps += 1
            #a.plot()
            if turn != zero_turn:
                s = time.time()
                best_move = actor(minmax_normal, a.data, turn, N_D, best_move)
                span = time.time() - s
                # print("minmax normal, with depth", N_D, "move takes time: ", span)
                time_normal.append(span)
            else:
                s = time.time()
                best_move = actor(minmax_zero, a.data, turn, Z_D, best_move)
                span = time.time() - s
                # print("minmax zero, with depth", Z_D, "move takes time: ", span)
                time_zero.append(span)
            a.move_to(turn, best_move[0], best_move[1])
            turn = -turn
            result = a.evaluate(zero_turn, turn)
            if result == 1:
                print("minmax zero win!!")
                zero_win += 1
                break
            elif result == -1:
                #print("minmax normal win!!')
                break
    print("In the previous ", N, " rounds, zero win ratio is: ", float(zero_win) / float(N))
    time_zero = np.array(time_zero)
    time_normal = np.array(time_normal)
    print("On average, for minmax normal with depth", N_D, \
          ", each move takes time: ", time_normal.mean(),\
          "max time elapsed:", time_normal.max())
    print("On average, for minmax zero with depth", Z_D, \
          ", each move takes time: ", time_zero.mean(),\
          "max time elapsed:", time_zero.max())

# %%
# minmax_normal = MinMaxZero(0.9, 100, "AtaxxZero_91.2p_82.4q.h5")
minmax_normal = MinMaxNormal()
minmax_zero = MinMaxZero(0.9, 100, "AtaxxZero_91.2p_82.4q.h5")
actor_compare(minmax_normal, minmax_zero, 2, 2, 5)
# Out:
# successfully loaded two models
# Round: 0
# Round: 1
# Round: 2
# Round: 3

# %%
#minmax_normal = MinMaxZero(0.9, 100, "AtaxxZero_91.2p_82.4q.h5")
minmax_normal = MinMaxNormal()
minmax_zero = MinMaxZero(0.9, 100, "AtaxxZero_91.2p_82.4q.h5")
N = 100
N_D = 2
Z_D = 2
zero_win = 0
time_zero = []
time_normal = []
for _ in range(N):
    steps = 0
    a = Ataxx()
    turn = -1
    zero_turn = choice([-1, 1])
    print("zero chose color", zero_turn)
    best_move = None
    while True:
        steps += 1
        #a.plot()
        if turn != zero_turn:
            s = time.time()
            best_move = actor(minmax_normal, a.data, turn, N_D, best_move)
            span = time.time() - s
            # print("minmax normal, with depth", N_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_normal.append(span)
        else:
            s = time.time()
            best_move = actor(minmax_zero, a.data, turn, Z_D, best_move)
            span = time.time() - s
            # print("minmax zero, with depth", Z_D, "move takes time: ", span)
            if steps > 10 and steps < 60:
                time_zero.append(span)
        a.move_to(turn, best_move[0], best_move[1])
        turn = -turn
        result = a.evaluate(zero_turn, turn)
        if result == 1:
            print("\n\n\n\n minmax zero win!! \n\n\n\n")
            zero_win += 1
            break
        elif result == -1:
            print("\n\n\n\n minmax normal win!! \n\n\n\n")
            break
print("In the previous ", N, " rounds, zero win ratio is: ", float(zero_win) / float(N))
time_zero = np.array(time_zero)
time_normal = np.array(time_normal)
print("On average, for minmax normal with depth", N_D, \
      ", each move takes time: ", time_normal.mean(),\
      "max time elapsed:", time_normal.max())
print("On average, for minmax zero with depth", Z_D, \
      ", each move takes time: ", time_zero.mean(),\
      "max time elapsed:", time_zero.max())
# Out:
# successfully loaded two models
# successfully loaded two models
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  2.7939300537109375
# 1
# minmax normal, with depth 1 move takes time:  2.767418146133423
# 1
# minmax zero, with depth 1 move takes time:  0.008023977279663086
# 1
# minmax normal, with depth 1 move takes time:  0.07401585578918457
# 1
# minmax zero, with depth 1 move takes time:  0.024341106414794922
# 1
# minmax normal, with depth 1 move takes time:  0.06837606430053711
# 1
# minmax zero, with depth 1 move takes time:  0.006119966506958008
# 2
# minmax normal, with depth 1 move takes time:  0.04987287521362305
# 2
# minmax zero, with depth 1 move takes time:  0.043168067932128906
# 2
# minmax normal, with depth 1 move takes time:  0.026424884796142578
# 5
# minmax zero, with depth 1 move takes time:  0.029422998428344727
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.008610010147094727
# 1
# minmax normal, with depth 1 move takes time:  0.046241044998168945
# 1
# minmax zero, with depth 1 move takes time:  0.007451057434082031
# 1
# minmax normal, with depth 1 move takes time:  0.0838019847869873
# 1
# minmax zero, with depth 1 move takes time:  0.02487015724182129
# 1
# minmax normal, with depth 1 move takes time:  0.06644392013549805
# 1
# minmax zero, with depth 1 move takes time:  0.0058650970458984375
# 2
# minmax normal, with depth 1 move takes time:  0.04577994346618652
# 2
# minmax zero, with depth 1 move takes time:  0.03138399124145508
# 1
# minmax normal, with depth 1 move takes time:  0.022837162017822266
# 5
# minmax zero, with depth 1 move takes time:  0.02572011947631836
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.007722139358520508
# 1
# minmax normal, with depth 1 move takes time:  0.04558897018432617
# 1
# minmax zero, with depth 1 move takes time:  0.010873079299926758
# 1
# minmax normal, with depth 1 move takes time:  0.07431387901306152
# 1
# minmax zero, with depth 1 move takes time:  0.020563125610351562
# 1
# minmax normal, with depth 1 move takes time:  0.07549619674682617
# 1
# minmax zero, with depth 1 move takes time:  0.005288839340209961
# 2
# minmax normal, with depth 1 move takes time:  0.0440061092376709
# 2
# minmax zero, with depth 1 move takes time:  0.03134799003601074
# 2
# minmax normal, with depth 1 move takes time:  0.0259552001953125
# 1
# minmax zero, with depth 1 move takes time:  0.09906697273254395
# 1
# minmax normal, with depth 1 move takes time:  0.022125959396362305
# 3
# minmax zero, with depth 1 move takes time:  0.07275390625
# 1
# minmax normal, with depth 1 move takes time:  0.029896974563598633
# 4
# minmax zero, with depth 1 move takes time:  0.07924604415893555
# 1
# minmax normal, with depth 1 move takes time:  0.07732200622558594
# 2
# minmax zero, with depth 1 move takes time:  0.014666080474853516
# 4
# minmax normal, with depth 1 move takes time:  0.13855218887329102
# 4
# minmax zero, with depth 1 move takes time:  0.019067049026489258
# 1
# minmax normal, with depth 1 move takes time:  0.03503298759460449
# 1
# minmax zero, with depth 1 move takes time:  0.022309064865112305
# 1
# minmax normal, with depth 1 move takes time:  0.09105682373046875
# 1
# minmax zero, with depth 1 move takes time:  0.03129887580871582
# 1
# minmax normal, with depth 1 move takes time:  0.0828709602355957
# 2
# minmax zero, with depth 1 move takes time:  0.013975858688354492
# 1
# minmax normal, with depth 1 move takes time:  0.0886240005493164
# 2
# minmax zero, with depth 1 move takes time:  0.027873992919921875
# 2
# minmax normal, with depth 1 move takes time:  0.1268000602722168
# 2
# minmax zero, with depth 1 move takes time:  0.031523942947387695
# 1
# minmax normal, with depth 1 move takes time:  0.1254270076751709
# 1
# minmax zero, with depth 1 move takes time:  0.028622150421142578
# 1
# minmax normal, with depth 1 move takes time:  0.12722396850585938
# 1
# minmax zero, with depth 1 move takes time:  0.028335094451904297
# 1
# minmax normal, with depth 1 move takes time:  0.10118389129638672
# 1
# minmax zero, with depth 1 move takes time:  0.029640913009643555
# 1
# minmax normal, with depth 1 move takes time:  0.16312813758850098
# 2
# minmax zero, with depth 1 move takes time:  0.028657197952270508
# 2
# minmax normal, with depth 1 move takes time:  0.10031604766845703
# 1
# minmax zero, with depth 1 move takes time:  0.0160520076751709
# 2
# minmax normal, with depth 1 move takes time:  0.13337397575378418
# 1
# minmax zero, with depth 1 move takes time:  0.04674410820007324
# 1
# minmax normal, with depth 1 move takes time:  0.1677110195159912
# 1
# minmax zero, with depth 1 move takes time:  0.026242971420288086
# 1
# minmax normal, with depth 1 move takes time:  0.2260749340057373
# 2
# minmax zero, with depth 1 move takes time:  0.04277610778808594
# 2
# minmax normal, with depth 1 move takes time:  0.09394598007202148
# 2
# minmax zero, with depth 1 move takes time:  0.05333399772644043
# 2
# minmax normal, with depth 1 move takes time:  0.12910795211791992
# 1
# minmax zero, with depth 1 move takes time:  0.02814197540283203
# 1
# minmax normal, with depth 1 move takes time:  0.1439061164855957
# 1
# minmax zero, with depth 1 move takes time:  0.04495811462402344
# 2
# minmax normal, with depth 1 move takes time:  0.2306368350982666
# 1
# minmax zero, with depth 1 move takes time:  0.04747819900512695
# 2
# minmax normal, with depth 1 move takes time:  0.20049595832824707
# 1
# minmax zero, with depth 1 move takes time:  0.009323835372924805
# 2
# minmax normal, with depth 1 move takes time:  0.18453001976013184
# 2
# minmax zero, with depth 1 move takes time:  0.01301884651184082
# 1
# minmax normal, with depth 1 move takes time:  0.18378615379333496
# 1
# minmax zero, with depth 1 move takes time:  0.013365030288696289
# 1
# minmax normal, with depth 1 move takes time:  0.17752909660339355
# 1
# minmax zero, with depth 1 move takes time:  0.04146003723144531
# 1
# minmax normal, with depth 1 move takes time:  0.20366501808166504
# 2
# minmax zero, with depth 1 move takes time:  0.012881040573120117
# 3
# minmax normal, with depth 1 move takes time:  0.1878509521484375
# 2
# minmax zero, with depth 1 move takes time:  0.028816938400268555
# 1
# minmax normal, with depth 1 move takes time:  0.130051851272583
# 1
# minmax zero, with depth 1 move takes time:  0.08048319816589355
# 1
# minmax normal, with depth 1 move takes time:  0.1213071346282959
# 1
# minmax zero, with depth 1 move takes time:  0.021759986877441406
# 1
# minmax normal, with depth 1 move takes time:  0.1509261131286621
# 1
# minmax zero, with depth 1 move takes time:  0.014938116073608398
# 1
# minmax normal, with depth 1 move takes time:  0.14015698432922363
# 2
# minmax zero, with depth 1 move takes time:  0.023768901824951172
# 1
# minmax normal, with depth 1 move takes time:  0.13116002082824707
# 1
# minmax zero, with depth 1 move takes time:  0.017524003982543945
# 1
# minmax normal, with depth 1 move takes time:  0.06944990158081055
# 1
# minmax zero, with depth 1 move takes time:  0.023559093475341797
# 1
# minmax normal, with depth 1 move takes time:  0.0696258544921875
# 1
# minmax zero, with depth 1 move takes time:  0.003942966461181641
# 1
# minmax normal, with depth 1 move takes time:  0.1093440055847168
# 1
# minmax zero, with depth 1 move takes time:  0.020142078399658203
# 2
# minmax normal, with depth 1 move takes time:  0.0920250415802002
# 4
# minmax zero, with depth 1 move takes time:  0.02349090576171875
# 1
# minmax normal, with depth 1 move takes time:  0.07189011573791504
# 1
# minmax zero, with depth 1 move takes time:  0.020265817642211914
# 2
# minmax normal, with depth 1 move takes time:  0.08524489402770996
# 3
# minmax zero, with depth 1 move takes time:  0.01823115348815918
# 1
# minmax normal, with depth 1 move takes time:  0.06441593170166016
# 1
# minmax zero, with depth 1 move takes time:  0.014817953109741211
# 2
# minmax normal, with depth 1 move takes time:  0.09090495109558105
# 2
# minmax zero, with depth 1 move takes time:  0.005068063735961914
# 1
# minmax normal, with depth 1 move takes time:  0.061456918716430664
# 4
# minmax zero, with depth 1 move takes time:  0.014138936996459961
# 1
# minmax normal, with depth 1 move takes time:  0.07801508903503418
# 2
# minmax zero, with depth 1 move takes time:  0.008881092071533203
# 1
# minmax normal, with depth 1 move takes time:  0.05879497528076172
# 1
# minmax zero, with depth 1 move takes time:  0.005828857421875
# 1
# minmax normal, with depth 1 move takes time:  0.0444788932800293
# 2
# minmax zero, with depth 1 move takes time:  0.006072044372558594
# 1
# minmax normal, with depth 1 move takes time:  0.062376976013183594
# 1
# minmax zero, with depth 1 move takes time:  0.007437944412231445
# 1
# minmax normal, with depth 1 move takes time:  0.05345892906188965
# 2
# minmax zero, with depth 1 move takes time:  0.00864100456237793
# 1
# minmax normal, with depth 1 move takes time:  0.04457807540893555
# 1
# minmax zero, with depth 1 move takes time:  0.00716710090637207
# 2
# minmax normal, with depth 1 move takes time:  0.043540000915527344
# 1
# minmax zero, with depth 1 move takes time:  0.0038127899169921875
# 18
# minmax normal, with depth 1 move takes time:  0.026762008666992188
# 1
# minmax zero, with depth 1 move takes time:  0.0066068172454833984
# 3
# minmax normal, with depth 1 move takes time:  0.015450000762939453
# 2
# minmax zero, with depth 1 move takes time:  0.006790876388549805
# 5
# minmax normal, with depth 1 move takes time:  0.008769989013671875
# 1
# minmax zero, with depth 1 move takes time:  0.006217002868652344
# 3
# minmax normal, with depth 1 move takes time:  0.0054509639739990234
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.05032706260681152
# 2
# minmax zero, with depth 1 move takes time:  0.00813913345336914
# 4
# minmax normal, with depth 1 move takes time:  0.06663298606872559
# 1
# minmax zero, with depth 1 move takes time:  0.010257959365844727
# 1
# minmax normal, with depth 1 move takes time:  0.08339500427246094
# 2
# minmax zero, with depth 1 move takes time:  0.018805980682373047
# 1
# minmax normal, with depth 1 move takes time:  0.06894993782043457
# 1
# minmax zero, with depth 1 move takes time:  0.007148027420043945
# 1
# minmax normal, with depth 1 move takes time:  0.044175148010253906
# 4
# minmax zero, with depth 1 move takes time:  0.03765296936035156
# 1
# minmax normal, with depth 1 move takes time:  0.022265911102294922
# 2
# minmax zero, with depth 1 move takes time:  0.009425878524780273
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.047263145446777344
# 2
# minmax zero, with depth 1 move takes time:  0.007565021514892578
# 1
# minmax normal, with depth 1 move takes time:  0.06878399848937988
# 1
# minmax zero, with depth 1 move takes time:  0.01011204719543457
# 2
# minmax normal, with depth 1 move takes time:  0.09371304512023926
# 1
# minmax zero, with depth 1 move takes time:  0.009603023529052734
# 1
# minmax normal, with depth 1 move takes time:  0.06415915489196777
# 1
# minmax zero, with depth 1 move takes time:  0.03452610969543457
# 5
# minmax normal, with depth 1 move takes time:  0.044512033462524414
# 2
# minmax zero, with depth 1 move takes time:  0.04857778549194336
# 1
# minmax normal, with depth 1 move takes time:  0.0303800106048584
# 4
# minmax zero, with depth 1 move takes time:  0.012314081192016602
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.046485185623168945
# 2
# minmax zero, with depth 1 move takes time:  0.008795976638793945
# 1
# minmax normal, with depth 1 move takes time:  0.0675809383392334
# 1
# minmax zero, with depth 1 move takes time:  0.010475873947143555
# 2
# minmax normal, with depth 1 move takes time:  0.09412598609924316
# 1
# minmax zero, with depth 1 move takes time:  0.02044200897216797
# 2
# minmax normal, with depth 1 move takes time:  0.06649994850158691
# 1
# minmax zero, with depth 1 move takes time:  0.011056900024414062
# 1
# minmax normal, with depth 1 move takes time:  0.04971504211425781
# 3
# minmax zero, with depth 1 move takes time:  0.028786897659301758
# 1
# minmax normal, with depth 1 move takes time:  0.04553508758544922
# 1
# minmax zero, with depth 1 move takes time:  0.013216018676757812
# 5
# minmax normal, with depth 1 move takes time:  0.02669692039489746
# 2
# minmax zero, with depth 1 move takes time:  0.09151101112365723
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.008878946304321289
# 1
# minmax normal, with depth 1 move takes time:  0.046858787536621094
# 2
# minmax zero, with depth 1 move takes time:  0.00906682014465332
# 1
# minmax normal, with depth 1 move takes time:  0.07604384422302246
# 1
# minmax zero, with depth 1 move takes time:  0.019981861114501953
# 1
# minmax normal, with depth 1 move takes time:  0.0701899528503418
# 1
# minmax zero, with depth 1 move takes time:  0.005577802658081055
# 2
# minmax normal, with depth 1 move takes time:  0.045617103576660156
# 2
# minmax zero, with depth 1 move takes time:  0.04262995719909668
# 2
# minmax normal, with depth 1 move takes time:  0.02481698989868164
# 2
# minmax zero, with depth 1 move takes time:  0.1288139820098877
# 2
# minmax normal, with depth 1 move takes time:  0.021631956100463867
# 1
# minmax zero, with depth 1 move takes time:  0.01547694206237793
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.04903388023376465
# 2
# minmax zero, with depth 1 move takes time:  0.009023904800415039
# 1
# minmax normal, with depth 1 move takes time:  0.06186795234680176
# 1
# minmax zero, with depth 1 move takes time:  0.013338088989257812
# 2
# minmax normal, with depth 1 move takes time:  0.09467887878417969
# 1
# minmax zero, with depth 1 move takes time:  0.015031814575195312
# 2
# minmax normal, with depth 1 move takes time:  0.06567096710205078
# 1
# minmax zero, with depth 1 move takes time:  0.007699012756347656
# 1
# minmax normal, with depth 1 move takes time:  0.05099296569824219
# 3
# minmax zero, with depth 1 move takes time:  0.025187969207763672
# 1
# minmax normal, with depth 1 move takes time:  0.08087015151977539
# 1
# minmax zero, with depth 1 move takes time:  0.012941837310791016
# 1
# minmax normal, with depth 1 move takes time:  0.08392500877380371
# 1
# minmax zero, with depth 1 move takes time:  0.0054171085357666016
# 1
# minmax normal, with depth 1 move takes time:  0.11524295806884766
# 1
# minmax zero, with depth 1 move takes time:  0.038548946380615234
# 1
# minmax normal, with depth 1 move takes time:  0.07897520065307617
# 1
# minmax zero, with depth 1 move takes time:  0.04950308799743652
# 1
# minmax normal, with depth 1 move takes time:  0.09380888938903809
# 2
# minmax zero, with depth 1 move takes time:  0.009749889373779297
# 2
# minmax normal, with depth 1 move takes time:  0.10489416122436523
# 1
# minmax zero, with depth 1 move takes time:  0.012243986129760742
# 1
# minmax normal, with depth 1 move takes time:  0.11333417892456055
# 1
# minmax zero, with depth 1 move takes time:  0.020099878311157227
# 1
# minmax normal, with depth 1 move takes time:  0.14698410034179688
# 1
# minmax zero, with depth 1 move takes time:  0.02429795265197754
# 1
# minmax normal, with depth 1 move takes time:  0.12119102478027344
# 1
# minmax zero, with depth 1 move takes time:  0.005866050720214844
# 1
# minmax normal, with depth 1 move takes time:  0.1343529224395752
# 1
# minmax zero, with depth 1 move takes time:  0.06898999214172363
# 1
# minmax normal, with depth 1 move takes time:  0.16345906257629395
# 1
# minmax zero, with depth 1 move takes time:  0.007132053375244141
# 1
# minmax normal, with depth 1 move takes time:  0.1564347743988037
# 1
# minmax zero, with depth 1 move takes time:  0.016087770462036133
# 1
# minmax normal, with depth 1 move takes time:  0.08074498176574707
# 1
# minmax zero, with depth 1 move takes time:  0.02362799644470215
# 1
# minmax normal, with depth 1 move takes time:  0.10994291305541992
# 1
# minmax zero, with depth 1 move takes time:  0.017239093780517578
# 1
# minmax normal, with depth 1 move takes time:  0.16499710083007812
# 1
# minmax zero, with depth 1 move takes time:  0.006546974182128906
# 1
# minmax normal, with depth 1 move takes time:  0.11435699462890625
# 1
# minmax zero, with depth 1 move takes time:  0.01624894142150879
# 2
# minmax normal, with depth 1 move takes time:  0.1750168800354004
# 2
# minmax zero, with depth 1 move takes time:  0.04196500778198242
# 3
# minmax normal, with depth 1 move takes time:  0.18891596794128418
# 1
# minmax zero, with depth 1 move takes time:  0.02523183822631836
# 1
# minmax normal, with depth 1 move takes time:  0.22087597846984863
# 1
# minmax zero, with depth 1 move takes time:  0.015353918075561523
# 2
# minmax normal, with depth 1 move takes time:  0.18355417251586914
# 1
# minmax zero, with depth 1 move takes time:  0.010955095291137695
# 2
# minmax normal, with depth 1 move takes time:  0.1320650577545166
# 1
# minmax zero, with depth 1 move takes time:  0.004785060882568359
# 2
# minmax normal, with depth 1 move takes time:  0.08747410774230957
# 3
# minmax zero, with depth 1 move takes time:  0.028343915939331055
# 1
# minmax normal, with depth 1 move takes time:  0.08007502555847168
# 1
# minmax zero, with depth 1 move takes time:  0.009647130966186523
# 1
# minmax normal, with depth 1 move takes time:  0.11992096900939941
# 1
# minmax zero, with depth 1 move takes time:  0.009937047958374023
# 1
# minmax normal, with depth 1 move takes time:  0.0917670726776123
# 2
# minmax zero, with depth 1 move takes time:  0.0221560001373291
# 1
# minmax normal, with depth 1 move takes time:  0.09886288642883301
# 1
# minmax zero, with depth 1 move takes time:  0.004127979278564453
# 2
# minmax normal, with depth 1 move takes time:  0.10065388679504395
# 2
# minmax zero, with depth 1 move takes time:  0.018544912338256836
# 2
# minmax normal, with depth 1 move takes time:  0.09226584434509277
# 1
# minmax zero, with depth 1 move takes time:  0.011861801147460938
# 1
# minmax normal, with depth 1 move takes time:  0.06474590301513672
# 1
# minmax zero, with depth 1 move takes time:  0.01742720603942871
# 3
# minmax normal, with depth 1 move takes time:  0.05679202079772949
# 1
# minmax zero, with depth 1 move takes time:  0.004202127456665039
# 3
# minmax normal, with depth 1 move takes time:  0.05969500541687012
# 1
# minmax zero, with depth 1 move takes time:  0.00391387939453125
# 2
# minmax normal, with depth 1 move takes time:  0.05159401893615723
# 3
# minmax zero, with depth 1 move takes time:  0.017781972885131836
# 4
# minmax normal, with depth 1 move takes time:  0.0406489372253418
# 3
# minmax zero, with depth 1 move takes time:  0.01341104507446289
# 2
# minmax normal, with depth 1 move takes time:  0.03915905952453613
# 2
# minmax zero, with depth 1 move takes time:  0.007668972015380859
# 2
# minmax normal, with depth 1 move takes time:  0.055006980895996094
# 1
# minmax zero, with depth 1 move takes time:  0.007950067520141602
# 15
# minmax normal, with depth 1 move takes time:  0.043115854263305664
# 1
# minmax zero, with depth 1 move takes time:  0.00423884391784668
# 18
# minmax normal, with depth 1 move takes time:  0.036115169525146484
# 1
# minmax zero, with depth 1 move takes time:  0.003844022750854492
# 15
# minmax normal, with depth 1 move takes time:  0.02346205711364746
# 3
# minmax zero, with depth 1 move takes time:  0.007678985595703125
# 15
# minmax normal, with depth 1 move takes time:  0.024219036102294922
# 1
# minmax zero, with depth 1 move takes time:  0.0030100345611572266
# 14
# minmax normal, with depth 1 move takes time:  0.024899959564208984
# 1
# minmax zero, with depth 1 move takes time:  0.0029129981994628906
# 4
# minmax normal, with depth 1 move takes time:  0.01220393180847168
# 3
# minmax zero, with depth 1 move takes time:  0.010776996612548828
# 5
# minmax normal, with depth 1 move takes time:  0.016270160675048828
# 1
# minmax zero, with depth 1 move takes time:  0.0033152103424072266
# 4
# minmax normal, with depth 1 move takes time:  0.0060961246490478516
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.04631781578063965
# 2
# minmax zero, with depth 1 move takes time:  0.009968996047973633
# 1
# minmax normal, with depth 1 move takes time:  0.06255388259887695
# 1
# minmax zero, with depth 1 move takes time:  0.012739896774291992
# 2
# minmax normal, with depth 1 move takes time:  0.09774899482727051
# 1
# minmax zero, with depth 1 move takes time:  0.007623910903930664
# 1
# minmax normal, with depth 1 move takes time:  0.0648341178894043
# 1
# minmax zero, with depth 1 move takes time:  0.03293609619140625
# 5
# minmax normal, with depth 1 move takes time:  0.04281306266784668
# 2
# minmax zero, with depth 1 move takes time:  0.04900002479553223
# 1
# minmax normal, with depth 1 move takes time:  0.03548598289489746
# 4
# minmax zero, with depth 1 move takes time:  0.011336803436279297
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.00896906852722168
# 1
# minmax normal, with depth 1 move takes time:  0.04520297050476074
# 1
# minmax zero, with depth 1 move takes time:  0.009176015853881836
# 1
# minmax normal, with depth 1 move takes time:  0.07469797134399414
# 1
# minmax zero, with depth 1 move takes time:  0.020751953125
# 1
# minmax normal, with depth 1 move takes time:  0.06984996795654297
# 1
# minmax zero, with depth 1 move takes time:  0.005126953125
# 2
# minmax normal, with depth 1 move takes time:  0.04422307014465332
# 2
# minmax zero, with depth 1 move takes time:  0.031552791595458984
# 2
# minmax normal, with depth 1 move takes time:  0.02774214744567871
# 1
# minmax zero, with depth 1 move takes time:  0.09835505485534668
# 1
# minmax normal, with depth 1 move takes time:  0.02321910858154297
# 3
# minmax zero, with depth 1 move takes time:  0.07446098327636719
# 2
# minmax normal, with depth 1 move takes time:  0.030636072158813477
# 3
# minmax zero, with depth 1 move takes time:  0.08080315589904785
# 1
# minmax normal, with depth 1 move takes time:  0.07390117645263672
# 1
# minmax zero, with depth 1 move takes time:  0.010029077529907227
# 1
# minmax normal, with depth 1 move takes time:  0.08108997344970703
# 1
# minmax zero, with depth 1 move takes time:  0.03228402137756348
# 1
# minmax normal, with depth 1 move takes time:  0.17927002906799316
# 1
# minmax zero, with depth 1 move takes time:  0.023568153381347656
# 1
# minmax normal, with depth 1 move takes time:  0.09739899635314941
# 1
# minmax zero, with depth 1 move takes time:  0.021139144897460938
# 1
# minmax normal, with depth 1 move takes time:  0.07045292854309082
# 7
# minmax zero, with depth 1 move takes time:  0.09014606475830078
# 5
# minmax normal, with depth 1 move takes time:  0.14619994163513184
# 6
# minmax zero, with depth 1 move takes time:  0.016857147216796875
# 5
# minmax normal, with depth 1 move takes time:  0.1307380199432373
# 3
# minmax zero, with depth 1 move takes time:  0.04378509521484375
# 1
# minmax normal, with depth 1 move takes time:  0.046491146087646484
# 3
# minmax zero, with depth 1 move takes time:  0.009282827377319336
# 2
# minmax normal, with depth 1 move takes time:  0.07239103317260742
# 3
# minmax zero, with depth 1 move takes time:  0.02440786361694336
# 1
# minmax normal, with depth 1 move takes time:  0.07908010482788086
# 2
# minmax zero, with depth 1 move takes time:  0.04849505424499512
# 2
# minmax normal, with depth 1 move takes time:  0.04831290245056152
# 5
# minmax zero, with depth 1 move takes time:  0.07000303268432617
# 1
# minmax normal, with depth 1 move takes time:  0.06371116638183594
# 1
# minmax zero, with depth 1 move takes time:  0.042768001556396484
# 1
# minmax normal, with depth 1 move takes time:  0.14757609367370605
# 1
# minmax zero, with depth 1 move takes time:  0.007048130035400391
# 2
# minmax normal, with depth 1 move takes time:  0.1755390167236328
# 2
# minmax zero, with depth 1 move takes time:  0.014599084854125977
# 1
# minmax normal, with depth 1 move takes time:  0.1426239013671875
# 1
# minmax zero, with depth 1 move takes time:  0.01768803596496582
# 4
# minmax normal, with depth 1 move takes time:  0.13361406326293945
# 2
# minmax zero, with depth 1 move takes time:  0.024726152420043945
# 1
# minmax normal, with depth 1 move takes time:  0.10624885559082031
# 1
# minmax zero, with depth 1 move takes time:  0.08463382720947266
# 1
# minmax normal, with depth 1 move takes time:  0.13158798217773438
# 2
# minmax zero, with depth 1 move takes time:  0.02237105369567871
# 1
# minmax normal, with depth 1 move takes time:  0.15059590339660645
# 1
# minmax zero, with depth 1 move takes time:  0.007995128631591797
# 2
# minmax normal, with depth 1 move takes time:  0.15820789337158203
# 1
# minmax zero, with depth 1 move takes time:  0.059754133224487305
# 1
# minmax normal, with depth 1 move takes time:  0.12796807289123535
# 1
# minmax zero, with depth 1 move takes time:  0.03946995735168457
# 3
# minmax normal, with depth 1 move takes time:  0.18104815483093262
# 2
# minmax zero, with depth 1 move takes time:  0.016813993453979492
# 1
# minmax normal, with depth 1 move takes time:  0.17064785957336426
# 1
# minmax zero, with depth 1 move takes time:  0.05519509315490723
# 1
# minmax normal, with depth 1 move takes time:  0.13068222999572754
# 3
# minmax zero, with depth 1 move takes time:  0.03993415832519531
# 1
# minmax normal, with depth 1 move takes time:  0.1670389175415039
# 2
# minmax zero, with depth 1 move takes time:  0.0189969539642334
# 1
# minmax normal, with depth 1 move takes time:  0.15677404403686523
# 1
# minmax zero, with depth 1 move takes time:  0.02236199378967285
# 1
# minmax normal, with depth 1 move takes time:  0.19350886344909668
# 1
# minmax zero, with depth 1 move takes time:  0.02004384994506836
# 2
# minmax normal, with depth 1 move takes time:  0.16324996948242188
# 2
# minmax zero, with depth 1 move takes time:  0.037583112716674805
# 1
# minmax normal, with depth 1 move takes time:  0.13193392753601074
# 1
# minmax zero, with depth 1 move takes time:  0.015691041946411133
# 1
# minmax normal, with depth 1 move takes time:  0.11071896553039551
# 1
# minmax zero, with depth 1 move takes time:  0.016427993774414062
# 1
# minmax normal, with depth 1 move takes time:  0.11980104446411133
# 1
# minmax zero, with depth 1 move takes time:  0.016957998275756836
# 2
# minmax normal, with depth 1 move takes time:  0.11469697952270508
# 1
# minmax zero, with depth 1 move takes time:  0.01164698600769043
# 2
# minmax normal, with depth 1 move takes time:  0.07438993453979492
# 1
# minmax zero, with depth 1 move takes time:  0.01523900032043457
# 2
# minmax normal, with depth 1 move takes time:  0.05442500114440918
# 1
# minmax zero, with depth 1 move takes time:  0.016637086868286133
# 2
# minmax normal, with depth 1 move takes time:  0.06775093078613281
# 1
# minmax zero, with depth 1 move takes time:  0.007742881774902344
# 2
# minmax normal, with depth 1 move takes time:  0.06284499168395996
# 1
# minmax zero, with depth 1 move takes time:  0.007420063018798828
# 1
# minmax normal, with depth 1 move takes time:  0.04784083366394043
# 1
# minmax zero, with depth 1 move takes time:  0.010931968688964844
# 1
# minmax normal, with depth 1 move takes time:  0.05498003959655762
# 1
# minmax zero, with depth 1 move takes time:  0.007721900939941406
# 1
# minmax normal, with depth 1 move takes time:  0.02473306655883789
# 1
# minmax zero, with depth 1 move takes time:  0.005006074905395508
# 1
# minmax normal, with depth 1 move takes time:  0.020970821380615234
# 1
# minmax zero, with depth 1 move takes time:  0.008092880249023438
# 2
# minmax normal, with depth 1 move takes time:  0.014551877975463867
# 1
# minmax zero, with depth 1 move takes time:  0.004227876663208008
# 1
# minmax normal, with depth 1 move takes time:  0.017602920532226562
# 1
# minmax zero, with depth 1 move takes time:  0.009504079818725586
# 1
# minmax normal, with depth 1 move takes time:  0.011379003524780273
# 1
# minmax zero, with depth 1 move takes time:  0.004332065582275391
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.0464019775390625
# 2
# minmax zero, with depth 1 move takes time:  0.00929880142211914
# 4
# minmax normal, with depth 1 move takes time:  0.06740593910217285
# 1
# minmax zero, with depth 1 move takes time:  0.013811111450195312
# 1
# minmax normal, with depth 1 move takes time:  0.08064007759094238
# 2
# minmax zero, with depth 1 move takes time:  0.014815092086791992
# 1
# minmax normal, with depth 1 move takes time:  0.06943917274475098
# 1
# minmax zero, with depth 1 move takes time:  0.005682945251464844
# 1
# minmax normal, with depth 1 move takes time:  0.04496288299560547
# 4
# minmax zero, with depth 1 move takes time:  0.03746795654296875
# 5
# minmax normal, with depth 1 move takes time:  0.02786397933959961
# 12
# minmax zero, with depth 1 move takes time:  0.020275115966796875
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.04602384567260742
# 2
# minmax zero, with depth 1 move takes time:  0.009644031524658203
# 1
# minmax normal, with depth 1 move takes time:  0.06469392776489258
# 1
# minmax zero, with depth 1 move takes time:  0.012773990631103516
# 2
# minmax normal, with depth 1 move takes time:  0.09387803077697754
# 1
# minmax zero, with depth 1 move takes time:  0.007538795471191406
# 1
# minmax normal, with depth 1 move takes time:  0.0645589828491211
# 1
# minmax zero, with depth 1 move takes time:  0.033566951751708984
# 5
# minmax normal, with depth 1 move takes time:  0.04224514961242676
# 2
# minmax zero, with depth 1 move takes time:  0.049906015396118164
# 1
# minmax normal, with depth 1 move takes time:  0.030801057815551758
# 4
# minmax zero, with depth 1 move takes time:  0.011247873306274414
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.007797956466674805
# 1
# minmax normal, with depth 1 move takes time:  0.0451350212097168
# 2
# minmax zero, with depth 1 move takes time:  0.011427164077758789
# 1
# minmax normal, with depth 1 move takes time:  0.07558107376098633
# 1
# minmax zero, with depth 1 move takes time:  0.008241891860961914
# 2
# minmax normal, with depth 1 move takes time:  0.046672821044921875
# 1
# minmax zero, with depth 1 move takes time:  0.010232210159301758
# 2
# minmax normal, with depth 1 move takes time:  0.025671005249023438
# 3
# minmax zero, with depth 1 move takes time:  0.1159670352935791
# 1
# minmax normal, with depth 1 move takes time:  0.017721891403198242
# 3
# minmax zero, with depth 1 move takes time:  0.07413697242736816
# 1
# minmax normal, with depth 1 move takes time:  0.03701591491699219
# 1
# minmax zero, with depth 1 move takes time:  0.028778076171875
# 1
# minmax normal, with depth 1 move takes time:  0.09595108032226562
# 1
# minmax zero, with depth 1 move takes time:  0.018716096878051758
# 1
# minmax normal, with depth 1 move takes time:  0.15328192710876465
# 1
# minmax zero, with depth 1 move takes time:  0.018878936767578125
# 1
# minmax normal, with depth 1 move takes time:  0.0984659194946289
# 2
# minmax zero, with depth 1 move takes time:  0.014842033386230469
# 1
# minmax normal, with depth 1 move takes time:  0.10768699645996094
# 1
# minmax zero, with depth 1 move takes time:  0.06033182144165039
# 1
# minmax normal, with depth 1 move takes time:  0.16166090965270996
# 1
# minmax zero, with depth 1 move takes time:  0.009865999221801758
# 1
# minmax normal, with depth 1 move takes time:  0.13317203521728516
# 1
# minmax zero, with depth 1 move takes time:  0.012817144393920898
# 1
# minmax normal, with depth 1 move takes time:  0.171036958694458
# 3
# minmax zero, with depth 1 move takes time:  0.058129072189331055
# 1
# minmax normal, with depth 1 move takes time:  0.11855196952819824
# 1
# minmax zero, with depth 1 move takes time:  0.01498103141784668
# 2
# minmax normal, with depth 1 move takes time:  0.15935897827148438
# 1
# minmax zero, with depth 1 move takes time:  0.02552199363708496
# 2
# minmax normal, with depth 1 move takes time:  0.2398538589477539
# 2
# minmax zero, with depth 1 move takes time:  0.022201061248779297
# 2
# minmax normal, with depth 1 move takes time:  0.22379517555236816
# 1
# minmax zero, with depth 1 move takes time:  0.015339851379394531
# 2
# minmax normal, with depth 1 move takes time:  0.22434616088867188
# 1
# minmax zero, with depth 1 move takes time:  0.004961967468261719
# 2
# minmax normal, with depth 1 move takes time:  0.1355581283569336
# 1
# minmax zero, with depth 1 move takes time:  0.02007889747619629
# 1
# minmax normal, with depth 1 move takes time:  0.16600680351257324
# 2
# minmax zero, with depth 1 move takes time:  0.04655289649963379
# 1
# minmax normal, with depth 1 move takes time:  0.14318203926086426
# 2
# minmax zero, with depth 1 move takes time:  0.05747699737548828
# 2
# minmax normal, with depth 1 move takes time:  0.16434693336486816
# 1
# minmax zero, with depth 1 move takes time:  0.0264890193939209
# 1
# minmax normal, with depth 1 move takes time:  0.14465093612670898
# 1
# minmax zero, with depth 1 move takes time:  0.029295921325683594
# 1
# minmax normal, with depth 1 move takes time:  0.15366601943969727
# 1
# minmax zero, with depth 1 move takes time:  0.015537023544311523
# 1
# minmax normal, with depth 1 move takes time:  0.19696903228759766
# 1
# minmax zero, with depth 1 move takes time:  0.04394984245300293
# 1
# minmax normal, with depth 1 move takes time:  0.16558599472045898
# 1
# minmax zero, with depth 1 move takes time:  0.011580944061279297
# 2
# minmax normal, with depth 1 move takes time:  0.16106295585632324
# 2
# minmax zero, with depth 1 move takes time:  0.03966784477233887
# 1
# minmax normal, with depth 1 move takes time:  0.11572885513305664
# 1
# minmax zero, with depth 1 move takes time:  0.020102977752685547
# 1
# minmax normal, with depth 1 move takes time:  0.09988522529602051
# 1
# minmax zero, with depth 1 move takes time:  0.044100046157836914
# 1
# minmax normal, with depth 1 move takes time:  0.052288055419921875
# 3
# minmax zero, with depth 1 move takes time:  0.03101801872253418
# 2
# minmax normal, with depth 1 move takes time:  0.09336400032043457
# 1
# minmax zero, with depth 1 move takes time:  0.0301358699798584
# 2
# minmax normal, with depth 1 move takes time:  0.07871413230895996
# 1
# minmax zero, with depth 1 move takes time:  0.015984058380126953
# 2
# minmax normal, with depth 1 move takes time:  0.11688494682312012
# 1
# minmax zero, with depth 1 move takes time:  0.016794919967651367
# 3
# minmax normal, with depth 1 move takes time:  0.09383201599121094
# 1
# minmax zero, with depth 1 move takes time:  0.0062999725341796875
# 1
# minmax normal, with depth 1 move takes time:  0.08743500709533691
# 2
# minmax zero, with depth 1 move takes time:  0.008643150329589844
# 1
# minmax normal, with depth 1 move takes time:  0.08441519737243652
# 1
# minmax zero, with depth 1 move takes time:  0.009594917297363281
# 1
# minmax normal, with depth 1 move takes time:  0.07691311836242676
# 2
# minmax zero, with depth 1 move takes time:  0.010009050369262695
# 1
# minmax normal, with depth 1 move takes time:  0.04720115661621094
# 1
# minmax zero, with depth 1 move takes time:  0.006299018859863281
# 6
# minmax normal, with depth 1 move takes time:  0.0728139877319336
# 1
# minmax zero, with depth 1 move takes time:  0.005850076675415039
# 4
# minmax normal, with depth 1 move takes time:  0.04256319999694824
# 2
# minmax zero, with depth 1 move takes time:  0.008126974105834961
# 6
# minmax normal, with depth 1 move takes time:  0.05326104164123535
# 2
# minmax zero, with depth 1 move takes time:  0.006757974624633789
# 3
# minmax normal, with depth 1 move takes time:  0.04848003387451172
# 1
# minmax zero, with depth 1 move takes time:  0.003493070602416992
# 25
# minmax normal, with depth 1 move takes time:  0.04966092109680176
# 1
# minmax zero, with depth 1 move takes time:  0.004422903060913086
# 5
# minmax normal, with depth 1 move takes time:  0.010797977447509766
# 3
# minmax zero, with depth 1 move takes time:  0.0067441463470458984
# 2
# minmax normal, with depth 1 move takes time:  0.004951953887939453
# 7
# minmax zero, with depth 1 move takes time:  0.01677083969116211
# 3
# minmax normal, with depth 1 move takes time:  0.009140968322753906
# 1
# minmax zero, with depth 1 move takes time:  0.0022699832916259766
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.04978489875793457
# 2
# minmax zero, with depth 1 move takes time:  0.01050877571105957
# 4
# minmax normal, with depth 1 move takes time:  0.062185049057006836
# 1
# minmax zero, with depth 1 move takes time:  0.01032710075378418
# 2
# minmax normal, with depth 1 move takes time:  0.08456110954284668
# 1
# minmax zero, with depth 1 move takes time:  0.008924007415771484
# 1
# minmax normal, with depth 1 move takes time:  0.06281685829162598
# 2
# minmax zero, with depth 1 move takes time:  0.016109228134155273
# 1
# minmax normal, with depth 1 move takes time:  0.04371905326843262
# 2
# minmax zero, with depth 1 move takes time:  0.04456591606140137
# 1
# minmax normal, with depth 1 move takes time:  0.02728104591369629
# 2
# minmax zero, with depth 1 move takes time:  0.007483005523681641
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.007867813110351562
# 1
# minmax normal, with depth 1 move takes time:  0.04703211784362793
# 1
# minmax zero, with depth 1 move takes time:  0.01099395751953125
# 1
# minmax normal, with depth 1 move takes time:  0.07263016700744629
# 1
# minmax zero, with depth 1 move takes time:  0.021606922149658203
# 1
# minmax normal, with depth 1 move takes time:  0.06798481941223145
# 1
# minmax zero, with depth 1 move takes time:  0.00501704216003418
# 2
# minmax normal, with depth 1 move takes time:  0.04680895805358887
# 2
# minmax zero, with depth 1 move takes time:  0.04056692123413086
# 2
# minmax normal, with depth 1 move takes time:  0.025272130966186523
# 5
# minmax zero, with depth 1 move takes time:  0.023124217987060547
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.011605978012084961
# 1
# minmax normal, with depth 1 move takes time:  0.04641294479370117
# 1
# minmax zero, with depth 1 move takes time:  0.007938146591186523
# 1
# minmax normal, with depth 1 move takes time:  0.07978415489196777
# 1
# minmax zero, with depth 1 move takes time:  0.023808002471923828
# 1
# minmax normal, with depth 1 move takes time:  0.06481099128723145
# 1
# minmax zero, with depth 1 move takes time:  0.0066089630126953125
# 2
# minmax normal, with depth 1 move takes time:  0.04483389854431152
# 2
# minmax zero, with depth 1 move takes time:  0.02701401710510254
# 2
# minmax normal, with depth 1 move takes time:  0.025182008743286133
# 1
# minmax zero, with depth 1 move takes time:  0.09932780265808105
# 1
# minmax normal, with depth 1 move takes time:  0.021238088607788086
# 3
# minmax zero, with depth 1 move takes time:  0.07432007789611816
# 2
# minmax normal, with depth 1 move takes time:  0.03414011001586914
# 3
# minmax zero, with depth 1 move takes time:  0.0687110424041748
# 1
# minmax normal, with depth 1 move takes time:  0.06676197052001953
# 1
# minmax zero, with depth 1 move takes time:  0.005011081695556641
# 1
# minmax normal, with depth 1 move takes time:  0.08060002326965332
# 1
# minmax zero, with depth 1 move takes time:  0.031449079513549805
# 3
# minmax normal, with depth 1 move takes time:  0.18510985374450684
# 1
# minmax zero, with depth 1 move takes time:  0.008372783660888672
# 1
# minmax normal, with depth 1 move takes time:  0.023411035537719727
# 1
# minmax zero, with depth 1 move takes time:  0.0572209358215332
# 3
# minmax normal, with depth 1 move takes time:  0.07704591751098633
# 1
# minmax zero, with depth 1 move takes time:  0.03056812286376953
# 3
# minmax normal, with depth 1 move takes time:  0.1301710605621338
# 1
# minmax zero, with depth 1 move takes time:  0.019565105438232422
# 3
# minmax normal, with depth 1 move takes time:  0.13200998306274414
# 1
# minmax zero, with depth 1 move takes time:  0.08141708374023438
# 1
# minmax normal, with depth 1 move takes time:  0.08705592155456543
# 2
# minmax zero, with depth 1 move takes time:  0.03762102127075195
# 2
# minmax normal, with depth 1 move takes time:  0.1381080150604248
# 3
# minmax zero, with depth 1 move takes time:  0.05807304382324219
# 1
# minmax normal, with depth 1 move takes time:  0.11452484130859375
# 2
# minmax zero, with depth 1 move takes time:  0.07397794723510742
# 1
# minmax normal, with depth 1 move takes time:  0.17487192153930664
# 2
# minmax zero, with depth 1 move takes time:  0.08021402359008789
# 1
# minmax normal, with depth 1 move takes time:  0.1085200309753418
# 2
# minmax zero, with depth 1 move takes time:  0.017962932586669922
# 2
# minmax normal, with depth 1 move takes time:  0.11989688873291016
# 3
# minmax zero, with depth 1 move takes time:  0.0887000560760498
# 1
# minmax normal, with depth 1 move takes time:  0.09437394142150879
# 2
# minmax zero, with depth 1 move takes time:  0.032948970794677734
# 1
# minmax normal, with depth 1 move takes time:  0.1419389247894287
# 2
# minmax zero, with depth 1 move takes time:  0.024171829223632812
# 4
# minmax normal, with depth 1 move takes time:  0.12364792823791504
# 4
# minmax zero, with depth 1 move takes time:  0.06663393974304199
# 2
# minmax normal, with depth 1 move takes time:  0.07160496711730957
# 3
# minmax zero, with depth 1 move takes time:  0.03275322914123535
# 2
# minmax normal, with depth 1 move takes time:  0.1093449592590332
# 1
# minmax zero, with depth 1 move takes time:  0.07738709449768066
# 1
# minmax normal, with depth 1 move takes time:  0.0974571704864502
# 1
# minmax zero, with depth 1 move takes time:  0.014886856079101562
# 3
# minmax normal, with depth 1 move takes time:  0.10262584686279297
# 1
# minmax zero, with depth 1 move takes time:  0.019980907440185547
# 1
# minmax normal, with depth 1 move takes time:  0.10266399383544922
# 4
# minmax zero, with depth 1 move takes time:  0.06856703758239746
# 1
# minmax normal, with depth 1 move takes time:  0.05419611930847168
# 1
# minmax zero, with depth 1 move takes time:  0.041290998458862305
# 1
# minmax normal, with depth 1 move takes time:  0.07271218299865723
# 1
# minmax zero, with depth 1 move takes time:  0.04694318771362305
# 1
# minmax normal, with depth 1 move takes time:  0.04266810417175293
# 1
# minmax zero, with depth 1 move takes time:  0.02940988540649414
# 2
# minmax normal, with depth 1 move takes time:  0.07030916213989258
# 1
# minmax zero, with depth 1 move takes time:  0.04181194305419922
# 1
# minmax normal, with depth 1 move takes time:  0.10920310020446777
# 1
# minmax zero, with depth 1 move takes time:  0.006639003753662109
# 1
# minmax normal, with depth 1 move takes time:  0.11509180068969727
# 1
# minmax zero, with depth 1 move takes time:  0.017926931381225586
# 1
# minmax normal, with depth 1 move takes time:  0.1276090145111084
# 1
# minmax zero, with depth 1 move takes time:  0.014782190322875977
# 1
# minmax normal, with depth 1 move takes time:  0.09530806541442871
# 1
# minmax zero, with depth 1 move takes time:  0.0235750675201416
# 1
# minmax normal, with depth 1 move takes time:  0.06513404846191406
# 1
# minmax zero, with depth 1 move takes time:  0.07189702987670898
# 1
# minmax normal, with depth 1 move takes time:  0.05323600769042969
# 1
# minmax zero, with depth 1 move takes time:  0.012514114379882812
# 3
# minmax normal, with depth 1 move takes time:  0.03799605369567871
# 1
# minmax zero, with depth 1 move takes time:  0.011322975158691406
# 2
# minmax normal, with depth 1 move takes time:  0.03197002410888672
# 1
# minmax zero, with depth 1 move takes time:  0.014369964599609375
# 2
# minmax normal, with depth 1 move takes time:  0.06686282157897949
# 1
# minmax zero, with depth 1 move takes time:  0.03402209281921387
# 1
# minmax normal, with depth 1 move takes time:  0.023739099502563477
# 1
# minmax zero, with depth 1 move takes time:  0.01653313636779785
# 2
# minmax normal, with depth 1 move takes time:  0.019145965576171875
# 2
# minmax zero, with depth 1 move takes time:  0.01665806770324707
# 1
# minmax normal, with depth 1 move takes time:  0.024093151092529297
# 1
# minmax zero, with depth 1 move takes time:  0.01353907585144043
# 3
# minmax normal, with depth 1 move takes time:  0.05760598182678223
# 1
# minmax zero, with depth 1 move takes time:  0.006602048873901367
# 1
# minmax normal, with depth 1 move takes time:  0.09528899192810059
# 2
# minmax zero, with depth 1 move takes time:  0.00734400749206543
# 9
# minmax normal, with depth 1 move takes time:  0.08020401000976562
# 3
# minmax zero, with depth 1 move takes time:  0.007856130599975586
# 3
# minmax normal, with depth 1 move takes time:  0.058938026428222656
# 1
# minmax zero, with depth 1 move takes time:  0.00468897819519043
# 6
# minmax normal, with depth 1 move takes time:  0.06139683723449707
# 1
# minmax zero, with depth 1 move takes time:  0.0035321712493896484
# 17
# minmax normal, with depth 1 move takes time:  0.03507494926452637
# 3
# minmax zero, with depth 1 move takes time:  0.0072939395904541016
# 9
# minmax normal, with depth 1 move takes time:  0.02159881591796875
# 4
# minmax zero, with depth 1 move takes time:  0.010357856750488281
# 6
# minmax normal, with depth 1 move takes time:  0.01238703727722168
# 3
# minmax zero, with depth 1 move takes time:  0.009303092956542969
# 3
# minmax normal, with depth 1 move takes time:  0.011013984680175781
# 1
# minmax zero, with depth 1 move takes time:  0.0022978782653808594
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.007611989974975586
# 1
# minmax normal, with depth 1 move takes time:  0.04997086524963379
# 2
# minmax zero, with depth 1 move takes time:  0.009837150573730469
# 1
# minmax normal, with depth 1 move takes time:  0.07216382026672363
# 1
# minmax zero, with depth 1 move takes time:  0.023472070693969727
# 1
# minmax normal, with depth 1 move takes time:  0.06909918785095215
# 1
# minmax zero, with depth 1 move takes time:  0.005366086959838867
# 2
# minmax normal, with depth 1 move takes time:  0.04549908638000488
# 2
# minmax zero, with depth 1 move takes time:  0.032750844955444336
# 1
# minmax normal, with depth 1 move takes time:  0.022753000259399414
# 5
# minmax zero, with depth 1 move takes time:  0.025660991668701172
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.048593997955322266
# 2
# minmax zero, with depth 1 move takes time:  0.010744094848632812
# 1
# minmax normal, with depth 1 move takes time:  0.06426119804382324
# 1
# minmax zero, with depth 1 move takes time:  0.012677907943725586
# 2
# minmax normal, with depth 1 move takes time:  0.09322190284729004
# 1
# minmax zero, with depth 1 move takes time:  0.01065206527709961
# 1
# minmax normal, with depth 1 move takes time:  0.06976795196533203
# 1
# minmax zero, with depth 1 move takes time:  0.035405874252319336
# 5
# minmax normal, with depth 1 move takes time:  0.0428621768951416
# 2
# minmax zero, with depth 1 move takes time:  0.049009084701538086
# 1
# minmax normal, with depth 1 move takes time:  0.03274416923522949
# 4
# minmax zero, with depth 1 move takes time:  0.009299039840698242
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.04813504219055176
# 2
# minmax zero, with depth 1 move takes time:  0.00957798957824707
# 4
# minmax normal, with depth 1 move takes time:  0.06447505950927734
# 1
# minmax zero, with depth 1 move takes time:  0.013944864273071289
# 1
# minmax normal, with depth 1 move takes time:  0.08365201950073242
# 2
# minmax zero, with depth 1 move takes time:  0.016427040100097656
# 1
# minmax normal, with depth 1 move takes time:  0.07581520080566406
# 1
# minmax zero, with depth 1 move takes time:  0.005431175231933594
# 1
# minmax normal, with depth 1 move takes time:  0.04558587074279785
# 4
# minmax zero, with depth 1 move takes time:  0.03474617004394531
# 1
# minmax normal, with depth 1 move takes time:  0.02710103988647461
# 2
# minmax zero, with depth 1 move takes time:  0.012350082397460938
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.010353803634643555
# 1
# minmax normal, with depth 1 move takes time:  0.04619097709655762
# 2
# minmax zero, with depth 1 move takes time:  0.008342981338500977
# 1
# minmax normal, with depth 1 move takes time:  0.07598519325256348
# 1
# minmax zero, with depth 1 move takes time:  0.007703065872192383
# 2
# minmax normal, with depth 1 move takes time:  0.045076847076416016
# 1
# minmax zero, with depth 1 move takes time:  0.011733055114746094
# 2
# minmax normal, with depth 1 move takes time:  0.023448944091796875
# 3
# minmax zero, with depth 1 move takes time:  0.1137549877166748
# 2
# minmax normal, with depth 1 move takes time:  0.02230215072631836
# 1
# minmax zero, with depth 1 move takes time:  0.07857894897460938
# 2
# minmax normal, with depth 1 move takes time:  0.028112173080444336
# 1
# minmax zero, with depth 1 move takes time:  0.040486812591552734
# 1
# minmax normal, with depth 1 move takes time:  0.06951498985290527
# 1
# minmax zero, with depth 1 move takes time:  0.014734029769897461
# 1
# minmax normal, with depth 1 move takes time:  0.14650201797485352
# 1
# minmax zero, with depth 1 move takes time:  0.007046937942504883
# 1
# minmax normal, with depth 1 move takes time:  0.10680794715881348
# 2
# minmax zero, with depth 1 move takes time:  0.030152082443237305
# 1
# minmax normal, with depth 1 move takes time:  0.14740490913391113
# 2
# minmax zero, with depth 1 move takes time:  0.018446922302246094
# 3
# ...
# 2
# minmax zero, with depth 1 move takes time:  0.009961843490600586
# 4
# minmax normal, with depth 1 move takes time:  0.07155013084411621
# 1
# minmax zero, with depth 1 move takes time:  0.011848926544189453
# 2
# minmax normal, with depth 1 move takes time:  0.08663296699523926
# 1
# minmax zero, with depth 1 move takes time:  0.007494211196899414
# 1
# minmax normal, with depth 1 move takes time:  0.07081198692321777
# 2
# minmax zero, with depth 1 move takes time:  0.012057065963745117
# 1
# minmax normal, with depth 1 move takes time:  0.04382205009460449
# 2
# minmax zero, with depth 1 move takes time:  0.05356097221374512
# 1
# minmax normal, with depth 1 move takes time:  0.025501012802124023
# 2
# minmax zero, with depth 1 move takes time:  0.009987115859985352
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.007963180541992188
# 1
# minmax normal, with depth 1 move takes time:  0.04810309410095215
# 2
# minmax zero, with depth 1 move takes time:  0.0073969364166259766
# 1
# minmax normal, with depth 1 move takes time:  0.0764150619506836
# 1
# minmax zero, with depth 1 move takes time:  0.01052713394165039
# 2
# minmax normal, with depth 1 move takes time:  0.04844093322753906
# 1
# minmax zero, with depth 1 move takes time:  0.011941909790039062
# 2
# minmax normal, with depth 1 move takes time:  0.028458833694458008
# 3
# minmax zero, with depth 1 move takes time:  0.11559391021728516
# 1
# minmax normal, with depth 1 move takes time:  0.017383098602294922
# 3
# minmax zero, with depth 1 move takes time:  0.07850098609924316
# 1
# minmax normal, with depth 1 move takes time:  0.03772902488708496
# 1
# minmax zero, with depth 1 move takes time:  0.0300750732421875
# 1
# minmax normal, with depth 1 move takes time:  0.0921318531036377
# 1
# minmax zero, with depth 1 move takes time:  0.016495943069458008
# 1
# minmax normal, with depth 1 move takes time:  0.15430498123168945
# 1
# minmax zero, with depth 1 move takes time:  0.0229799747467041
# 1
# minmax normal, with depth 1 move takes time:  0.09946608543395996
# 2
# minmax zero, with depth 1 move takes time:  0.0169219970703125
# 1
# minmax normal, with depth 1 move takes time:  0.11653900146484375
# 1
# minmax zero, with depth 1 move takes time:  0.05930805206298828
# 1
# minmax normal, with depth 1 move takes time:  0.16354894638061523
# 1
# minmax zero, with depth 1 move takes time:  0.01073598861694336
# 1
# minmax normal, with depth 1 move takes time:  0.14124202728271484
# 1
# minmax zero, with depth 1 move takes time:  0.01020503044128418
# 1
# minmax normal, with depth 1 move takes time:  0.17878103256225586
# 3
# minmax zero, with depth 1 move takes time:  0.06182384490966797
# 1
# minmax normal, with depth 1 move takes time:  0.12308788299560547
# 1
# minmax zero, with depth 1 move takes time:  0.03533196449279785
# 2
# minmax normal, with depth 1 move takes time:  0.18093109130859375
# 3
# minmax zero, with depth 1 move takes time:  0.012853860855102539
# 1
# minmax normal, with depth 1 move takes time:  0.09180903434753418
# 2
# minmax zero, with depth 1 move takes time:  0.007305145263671875
# 1
# minmax normal, with depth 1 move takes time:  0.10492801666259766
# 2
# minmax zero, with depth 1 move takes time:  0.03659796714782715
# 1
# minmax normal, with depth 1 move takes time:  0.12877178192138672
# 1
# minmax zero, with depth 1 move takes time:  0.03970599174499512
# 1
# minmax normal, with depth 1 move takes time:  0.1545720100402832
# 1
# minmax zero, with depth 1 move takes time:  0.012212038040161133
# 1
# minmax normal, with depth 1 move takes time:  0.1731100082397461
# 1
# minmax zero, with depth 1 move takes time:  0.11541008949279785
# 2
# minmax normal, with depth 1 move takes time:  0.14122891426086426
# 2
# minmax zero, with depth 1 move takes time:  0.0809478759765625
# 1
# minmax normal, with depth 1 move takes time:  0.20760393142700195
# 1
# minmax zero, with depth 1 move takes time:  0.01628398895263672
# 1
# minmax normal, with depth 1 move takes time:  0.1803271770477295
# 1
# minmax zero, with depth 1 move takes time:  0.07035207748413086
# 1
# minmax normal, with depth 1 move takes time:  0.19835209846496582
# 3
# minmax zero, with depth 1 move takes time:  0.022825002670288086
# 1
# minmax normal, with depth 1 move takes time:  0.17393898963928223
# 1
# minmax zero, with depth 1 move takes time:  0.06799697875976562
# 1
# minmax normal, with depth 1 move takes time:  0.19060683250427246
# 2
# minmax zero, with depth 1 move takes time:  0.03216195106506348
# 2
# minmax normal, with depth 1 move takes time:  0.20485615730285645
# 1
# minmax zero, with depth 1 move takes time:  0.02906012535095215
# 4
# minmax normal, with depth 1 move takes time:  0.18018889427185059
# 1
# minmax zero, with depth 1 move takes time:  0.011815071105957031
# 1
# minmax normal, with depth 1 move takes time:  0.20731401443481445
# 1
# minmax zero, with depth 1 move takes time:  0.03086400032043457
# 2
# minmax normal, with depth 1 move takes time:  0.24024200439453125
# 1
# minmax zero, with depth 1 move takes time:  0.025523900985717773
# 1
# minmax normal, with depth 1 move takes time:  0.20169687271118164
# 1
# minmax zero, with depth 1 move takes time:  0.015542984008789062
# 1
# minmax normal, with depth 1 move takes time:  0.17673301696777344
# 1
# minmax zero, with depth 1 move takes time:  0.019044876098632812
# 1
# minmax normal, with depth 1 move takes time:  0.18418288230895996
# 1
# minmax zero, with depth 1 move takes time:  0.020273208618164062
# 2
# minmax normal, with depth 1 move takes time:  0.23158884048461914
# 2
# minmax zero, with depth 1 move takes time:  0.01480412483215332
# 1
# minmax normal, with depth 1 move takes time:  0.20735597610473633
# 3
# minmax zero, with depth 1 move takes time:  0.026354074478149414
# 1
# minmax normal, with depth 1 move takes time:  0.21887922286987305
# 2
# minmax zero, with depth 1 move takes time:  0.04038214683532715
# 6
# minmax normal, with depth 1 move takes time:  0.15963506698608398
# 1
# minmax zero, with depth 1 move takes time:  0.04640793800354004
# 3
# minmax normal, with depth 1 move takes time:  0.15043115615844727
# 2
# minmax zero, with depth 1 move takes time:  0.033766984939575195
# 3
# minmax normal, with depth 1 move takes time:  0.2190399169921875
# 1
# minmax zero, with depth 1 move takes time:  0.05418205261230469
# 1
# minmax normal, with depth 1 move takes time:  0.17171502113342285
# 1
# minmax zero, with depth 1 move takes time:  0.03177189826965332
# 1
# minmax normal, with depth 1 move takes time:  0.2034931182861328
# 1
# minmax zero, with depth 1 move takes time:  0.016627073287963867
# 2
# minmax normal, with depth 1 move takes time:  0.168410062789917
# 2
# minmax zero, with depth 1 move takes time:  0.044805049896240234
# 3
# minmax normal, with depth 1 move takes time:  0.17928004264831543
# 1
# minmax zero, with depth 1 move takes time:  0.03694891929626465
# 2
# minmax normal, with depth 1 move takes time:  0.15971112251281738
# 3
# minmax zero, with depth 1 move takes time:  0.03165292739868164
# 3
# minmax normal, with depth 1 move takes time:  0.11963987350463867
# 1
# minmax zero, with depth 1 move takes time:  0.0214540958404541
# 1
# minmax normal, with depth 1 move takes time:  0.1191568374633789
# 1
# minmax zero, with depth 1 move takes time:  0.035481929779052734
# 1
# minmax normal, with depth 1 move takes time:  0.125014066696167
# 1
# minmax zero, with depth 1 move takes time:  0.011420965194702148
# 1
# minmax normal, with depth 1 move takes time:  0.09972286224365234
# 1
# minmax zero, with depth 1 move takes time:  0.022673845291137695
# 1
# minmax normal, with depth 1 move takes time:  0.10238099098205566
# 1
# minmax zero, with depth 1 move takes time:  0.018681049346923828
# 1
# minmax normal, with depth 1 move takes time:  0.11910605430603027
# 2
# minmax zero, with depth 1 move takes time:  0.02223801612854004
# 2
# minmax normal, with depth 1 move takes time:  0.10575008392333984
# 1
# minmax zero, with depth 1 move takes time:  0.01230621337890625
# 2
# minmax normal, with depth 1 move takes time:  0.09942102432250977
# 1
# minmax zero, with depth 1 move takes time:  0.03273296356201172
# 1
# minmax normal, with depth 1 move takes time:  0.09962892532348633
# 1
# minmax zero, with depth 1 move takes time:  0.01891613006591797
# 5
# minmax normal, with depth 1 move takes time:  0.07674312591552734
# 1
# minmax zero, with depth 1 move takes time:  0.008584976196289062
# 1
# minmax normal, with depth 1 move takes time:  0.04334592819213867
# 1
# minmax zero, with depth 1 move takes time:  0.03361010551452637
# 1
# minmax normal, with depth 1 move takes time:  0.0291440486907959
# 2
# minmax zero, with depth 1 move takes time:  0.012989044189453125
# 1
# minmax normal, with depth 1 move takes time:  0.014024019241333008
# 3
# minmax zero, with depth 1 move takes time:  0.011214017868041992
# 1
# minmax normal, with depth 1 move takes time:  0.05993008613586426
# 1
# minmax zero, with depth 1 move takes time:  0.011017084121704102
# 3
# minmax normal, with depth 1 move takes time:  0.03661990165710449
# 2
# minmax zero, with depth 1 move takes time:  0.011011838912963867
# 1
# minmax normal, with depth 1 move takes time:  0.03502321243286133
# 6
# minmax zero, with depth 1 move takes time:  0.01212000846862793
# 9
# minmax normal, with depth 1 move takes time:  0.036846160888671875
# 2
# minmax zero, with depth 1 move takes time:  0.007400989532470703
# 8
# minmax normal, with depth 1 move takes time:  0.022819042205810547
#
#
#
#
#  minmax normal win!!
#
#
#
#
# zero chose color 1
# 1
# minmax normal, with depth 1 move takes time:  0.05030488967895508
# 2
# minmax zero, with depth 1 move takes time:  0.010699987411499023
# 1
# minmax normal, with depth 1 move takes time:  0.06281614303588867
# 1
# minmax zero, with depth 1 move takes time:  0.015233039855957031
# 2
# minmax normal, with depth 1 move takes time:  0.09589505195617676
# 1
# minmax zero, with depth 1 move takes time:  0.007536888122558594
# 1
# minmax normal, with depth 1 move takes time:  0.0696859359741211
# 1
# minmax zero, with depth 1 move takes time:  0.034451961517333984
# 5
# minmax normal, with depth 1 move takes time:  0.04701805114746094
# 3
# minmax zero, with depth 1 move takes time:  0.062272071838378906
# 4
# minmax normal, with depth 1 move takes time:  0.03395700454711914
# 6
# minmax zero, with depth 1 move takes time:  0.02878880500793457
# 1
# minmax normal, with depth 1 move takes time:  0.043868064880371094
# 1
# minmax zero, with depth 1 move takes time:  0.06041693687438965
# 1
# minmax normal, with depth 1 move takes time:  0.08558297157287598
# 2
# minmax zero, with depth 1 move takes time:  0.029945850372314453
# 1
# minmax normal, with depth 1 move takes time:  0.12101411819458008
# 1
# minmax zero, with depth 1 move takes time:  0.01848888397216797
# 1
# minmax normal, with depth 1 move takes time:  0.1591811180114746
# 4
# minmax zero, with depth 1 move takes time:  0.05508899688720703
# 1
# minmax normal, with depth 1 move takes time:  0.15218806266784668
# 1
# minmax zero, with depth 1 move takes time:  0.007028818130493164
# 1
# minmax normal, with depth 1 move takes time:  0.1072530746459961
# 1
# minmax zero, with depth 1 move takes time:  0.057454824447631836
# 2
# minmax normal, with depth 1 move takes time:  0.07541298866271973
# 1
# minmax zero, with depth 1 move takes time:  0.06538605690002441
# 3
# minmax normal, with depth 1 move takes time:  0.08538007736206055
# 1
# minmax zero, with depth 1 move takes time:  0.014696836471557617
# 1
# minmax normal, with depth 1 move takes time:  0.10220098495483398
# 1
# minmax zero, with depth 1 move takes time:  0.04608511924743652
# 1
# minmax normal, with depth 1 move takes time:  0.1342010498046875
# 1
# minmax zero, with depth 1 move takes time:  0.04770207405090332
# 2
# minmax normal, with depth 1 move takes time:  0.19541597366333008
# 1
# minmax zero, with depth 1 move takes time:  0.020972013473510742
# 1
# minmax normal, with depth 1 move takes time:  0.14639806747436523
# 1
# minmax zero, with depth 1 move takes time:  0.03532600402832031
# 1
# minmax normal, with depth 1 move takes time:  0.18503403663635254
# 3
# minmax zero, with depth 1 move takes time:  0.03153681755065918
# 1
# minmax normal, with depth 1 move takes time:  0.18417882919311523
# 2
# minmax zero, with depth 1 move takes time:  0.008758068084716797
# 2
# minmax normal, with depth 1 move takes time:  0.11352992057800293
# 1
# minmax zero, with depth 1 move takes time:  0.00687098503112793
# 1
# minmax normal, with depth 1 move takes time:  0.21948003768920898
# 1
# minmax zero, with depth 1 move takes time:  0.014709949493408203
# 1
# minmax normal, with depth 1 move takes time:  0.1527860164642334
# 1
# minmax zero, with depth 1 move takes time:  0.013051033020019531
# 1
# minmax normal, with depth 1 move takes time:  0.16385388374328613
# 1
# minmax zero, with depth 1 move takes time:  0.012203216552734375
# 2
# minmax normal, with depth 1 move takes time:  0.12537384033203125
# 1
# minmax zero, with depth 1 move takes time:  0.01903700828552246
# 1
# minmax normal, with depth 1 move takes time:  0.07430195808410645
# 1
# minmax zero, with depth 1 move takes time:  0.006542205810546875
# 1
# minmax normal, with depth 1 move takes time:  0.12062406539916992
# 1
# minmax zero, with depth 1 move takes time:  0.006651878356933594
# 1
# minmax normal, with depth 1 move takes time:  0.08227396011352539
# 2
# minmax zero, with depth 1 move takes time:  0.03471493721008301
# 1
# minmax normal, with depth 1 move takes time:  0.0678558349609375
# 1
# minmax zero, with depth 1 move takes time:  0.007169961929321289
# 2
# minmax normal, with depth 1 move takes time:  0.09864497184753418
# 2
# minmax zero, with depth 1 move takes time:  0.006443023681640625
# 1
# minmax normal, with depth 1 move takes time:  0.07115817070007324
# 1
# minmax zero, with depth 1 move takes time:  0.010709047317504883
# 2
# minmax normal, with depth 1 move takes time:  0.09438896179199219
# 2
# minmax zero, with depth 1 move takes time:  0.012058019638061523
# 9
# minmax normal, with depth 1 move takes time:  0.07754993438720703
# 1
# minmax zero, with depth 1 move takes time:  0.011612176895141602
# 4
# minmax normal, with depth 1 move takes time:  0.04706883430480957
# 5
# minmax zero, with depth 1 move takes time:  0.015224933624267578
# 2
# minmax normal, with depth 1 move takes time:  0.05039691925048828
# 1
# minmax zero, with depth 1 move takes time:  0.0035409927368164062
# 3
# minmax normal, with depth 1 move takes time:  0.05940604209899902
# 4
# minmax zero, with depth 1 move takes time:  0.017779827117919922
# 2
# minmax normal, with depth 1 move takes time:  0.04625296592712402
# 3
# minmax zero, with depth 1 move takes time:  0.008012056350708008
# 3
# minmax normal, with depth 1 move takes time:  0.027654170989990234
# 1
# minmax zero, with depth 1 move takes time:  0.006840229034423828
# 1
# minmax normal, with depth 1 move takes time:  0.017228126525878906
# 1
# minmax zero, with depth 1 move takes time:  0.0031380653381347656
# 1
# minmax normal, with depth 1 move takes time:  0.013371944427490234
# 1
# minmax zero, with depth 1 move takes time:  0.004063844680786133
# 1
# minmax normal, with depth 1 move takes time:  0.0037200450897216797
# 1
# minmax zero, with depth 1 move takes time:  0.008128881454467773
# 2
# minmax normal, with depth 1 move takes time:  0.006940126419067383
# 1
# minmax zero, with depth 1 move takes time:  0.011945962905883789
# 1
# minmax normal, with depth 1 move takes time:  0.0023980140686035156
#
#
#
#
#  minmax zero win!!
#
#
#
#
# zero chose color -1
# 2
# minmax zero, with depth 1 move takes time:  0.00874018669128418
# 1
# minmax normal, with depth 1 move takes time:  0.04938197135925293
# 2
# minmax zero, with depth 1 move takes time:  0.0081329345703125
# 1
# minmax normal, with depth 1 move takes time:  0.08649301528930664
# 1
# minmax zero, with depth 1 move takes time:  0.008962154388427734
# 2
# minmax normal, with depth 1 move takes time:  0.04726600646972656
# 1
# minmax zero, with depth 1 move takes time:  0.007688999176025391
# 2
# minmax normal, with depth 1 move takes time:  0.027595043182373047
# 3
# minmax zero, with depth 1 move takes time:  0.11739015579223633
# 2
# minmax normal, with depth 1 move takes time:  0.017138004302978516
# 1
# minmax zero, with depth 1 move takes time:  0.016376018524169922
#
#
#
#
#  minmax zero win!!
#
#
#
#
# In the previous  100  rounds, zero win ratio is:  0.86
# On average, for minmax normal with depth 1 , each move takes time:  0.104738852859 max time elapsed: 0.278792142868
# On average, for minmax zero with depth 1 , each move takes time:  0.0288695744106 max time elapsed: 0.139946937561

# %%
a = Ataxx()
# %lprun -f minmax_zero.min_max _, best_move = minmax_zero.min_max(a.data, turn, turn, depth=6, pre_move=best_move, t_lim=100)
